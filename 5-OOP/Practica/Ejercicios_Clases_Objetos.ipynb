# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    tipo = 'Electrodomesticos'
    abierta = True

    def __init__(self, nombre: str, direccion: str, numero_de_empleados: int, ventas_ultimos_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.numero_de_empleados = numero_de_empleados
        self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

    def ventas_totales (self):
        return sum(self.ventas_ultimos_3_meses)

    def ventas_por_empleado_3_ultimos_meses (self):
        return (sum(self.ventas_ultimos_3_meses)) / self.numero_de_empleados

    def direccion_tienda (self):
        return self.nombre, self.direccion

    def ventas_ultimo_mes (self):
        return self.ventas_ultimos_3_meses[-1]

    def marketing (self):
        x = int(input('¿Inversión en marketing (en euros)?: '))
        if x < 1000:
            self.ventas_ultimos_3_meses = [venta * 1.2 for venta in self.ventas_ultimos_3_meses]
        else:
            self.ventas_ultimos_3_meses = [venta * 1.5 for venta in self.ventas_ultimos_3_meses]
            return self.ventas_ultimos_3_meses
        
Tienda_1 = Tienda('Tienda_1', 'Calle A CP:10000 Pueblo:A', 1, [1000,1000,1000])
Tienda_2 = Tienda('Tienda_2', 'Calle B CP:20000 Pueblo:B', 2, [2000,2000,2000])
Tienda_3 = Tienda('Tienda_3', 'Calle C CP:30000 Pueblo:C', 3, [3000,3000,3000])
    
print(f'Tipo:{tienda1.tipo}', 'Abierta:{tienda1.abierta}', 'Nombre: {tienda1.nombre}', 'Direccion: {tienda1.direccion}', 'empleados:{tienda1.numero_de_empleados}', 'ventas_ultimos_3_meses: {tienda1.ventas_ultimos_3_meses}')
# Out:
# Tipo:Electrodomésticos Abierta:{tienda1.abierta} Nombre: {tienda1.nombre} Direccion: {tienda1.direccion} empleados:{tienda1.numero_de_empleados} ventas_ultimos_3_meses: {tienda1.ventas_ultimos_3_meses}

# %%
class Tienda:
    """
    Clase que representa una tienda de electrodomésticos.
    Atributos comunes:
        - Tipo: "Electrodomésticos"
        - Abierta: True
    Atributos propios de cada tienda:
        - Nombre: Nombre de la tienda
        - Dirección: Dirección de la tienda
        - Número de empleados: Cantidad de empleados en la tienda
        - Ventas últimos 3 meses: Lista con las ventas de los últimos tres meses
    Métodos:
        - ventas_totales(): Calcula y devuelve las ventas totales de los últimos 3 meses.
        - media_ventas_por_empleado(): Calcula y devuelve la media de ventas por empleado.
        - direccion_tienda(): Devuelve un string con el nombre y dirección de la tienda.
        - ventas_ultimo_mes(): Devuelve las ventas del último mes.
        - marketing(x): Calcula las proyecciones de ventas en base a la inversión en marketing.
    """

    tipo = "Electrodomésticos"  # Atributo común
    abierta = True               # Atributo común

    def __init__(self, nombre: str, direccion: str, numero_de_empleados: int, ventas_ultimos_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.numero_de_empleados = numero_de_empleados
        self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

    def ventas_totales(self):
        """Calcula y devuelve las ventas totales de los últimos 3 meses."""
        return sum(self.ventas_ultimos_3_meses)

    def media_ventas_por_empleado(self):
        """Calcula y devuelve la media de ventas por empleado."""
        if self.numero_de_empleados > 0:
            return self.ventas_totales() / self.numero_de_empleados
        return 0

    def direccion_tienda(self):
        """Devuelve un string con el nombre y dirección de la tienda."""
        return f"Tienda: {self.nombre}, Dirección: {self.direccion}"

    def ventas_ultimo_mes(self):
        """Devuelve las ventas del último mes."""
        return self.ventas_ultimos_3_meses[-1]

    def marketing(self, x):
        """Calcula la proyección de ventas según la inversión en marketing.
        Si x < 1000, las ventas de los últimos 3 meses se multiplican por 1.2.
        Si x >= 1000, las ventas se multiplican por 1.5.
        """
        if x < 1000:
            aumento = 1.2
        else:
            aumento = 1.5

        # Aumentar las ventas en la lista
        self.ventas_ultimos_3_meses = [venta * aumento for venta in self.ventas_ultimos_3_meses]
        return self.ventas_ultimos_3_meses


# 2. Crear tres tiendas con datos inventados
tienda1 = Tienda('Tienda_1', 'Avenida de la Electrónica 1', 5, [10000, 15000, 12000])
tienda2 = Tienda('Tienda_2', 'Calle de los Electrodomésticos 2', 3, [8000, 7000, 9000])
tienda3 = Tienda('Tienda_3', 'Avenida del Progreso 3', 7, [20000, 25000, 30000])

# 3. Comprobación de los métodos en tienda1
print(tienda1.direccion_tienda())  # Imprimir dirección
print(f"Ventas totales: {tienda1.ventas_totales()}")  # Ventas totales
print(f"Media de ventas por empleado: {tienda1.media_ventas_por_empleado():.2f}")  # Media de ventas por empleado
print(f"Ventas del último mes: {tienda1.ventas_ultimo_mes()}")  # Ventas del último mes

# 4. Calcular ventas del último mes de todas las tiendas
for tienda in [tienda1, tienda2, tienda3]:
    print(f"Ventas del último mes en {tienda.nombre}: {tienda.ventas_ultimo_mes()}")

# 5. Imprimir los nombres de las tiendas cuya dirección incluye "Avenida"
for tienda in [tienda1, tienda2, tienda3]:
    if "Avenida" in tienda.direccion:
        print(f"Tienda en Avenida: {tienda.nombre}")
# Out:
# Tienda: Tienda_1, Dirección: Avenida de la Electrónica 1
# Ventas totales: 37000
# Media de ventas por empleado: 7400.00
# Ventas del último mes: 12000
# Ventas del último mes en Tienda_1: 12000
# Ventas del último mes en Tienda_2: 9000
# Ventas del último mes en Tienda_3: 30000
# Tienda en Avenida: Tienda_1
# Tienda en Avenida: Tienda_3

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    """
    Clase que representa un perro.
    
    Atributos:
        - patas: Número de patas del perro (siempre 4).
        - orejas: Número de orejas del perro (siempre 2).
        - ojos: Número de ojos del perro (siempre 2).
        - velocidad: Velocidad del perro (inicialmente 0).
        - raza: Raza del perro (string).
        - pelo: Color del pelo del perro (por defecto "Marrón").
        - dueño: Dueño del perro (por defecto None).
    
    Métodos:
        - andar(aumento_velocidad): Aumenta la velocidad del perro.
        - parar(): Establece la velocidad a 0.
        - ladrar(mensaje): Devuelve un string que simula el ladrido del perro con un mensaje.
    """
    Patas = 4
    Orejas = 2
    Ojos = 2
    Velocidad = 0

    def __init__(self, raza: str = 'Mastin', color_pelo: str = 'Marron', dueño: str = None):
        self.raza = raza
        self.color_pelo = color_pelo
        self.dueño = dueño

        def andar(self, aumento_de_velocidad: int):
            self.velocidad += aumento_de_velocidad

        def parar(self):
            self.velocidad = 0
        
        def ladrar(self, ladrar: str):
            return f'GUAU!, {ladrar}'
        
un_perro = Perro()
print(f"Raza: {un_perro.raza}")
print(f"Color de pelo: {un_perro.color_pelo}")
print(f"Dueño: {un_perro.dueño}")
print(f"Patas: {un_perro.Patas}")
print(f"Orejas: {un_perro.Orejas}")
print(f"Ojos: {un_perro.Ojos}")
print(Perro.__doc__)
print(f"Velocidad inicial: {un_perro.Velocidad}")
un_perro.andar(5)
print(f"Velocidad después de andar: {un_perro.Velocidad}")
# Out:
# Raza: Mastin
# Color de pelo: Marron
# Dueño: None
# Patas: 4
# Orejas: 2
# Ojos: 2
#
#     Clase que representa un perro.
#
#     Atributos:
#         - patas: Número de patas del perro (siempre 4).
#         - orejas: Número de orejas del perro (siempre 2).
#         - ojos: Número de ojos del perro (siempre 2).
#         - velocidad: Velocidad del perro (inicialmente 0).
#         - raza: Raza del perro (string).
#         - pelo: Color del pelo del perro (por defecto "Marrón").
#         - dueño: Dueño del perro (por defecto None).
#
#     Métodos:
#         - andar(aumento_velocidad): Aumenta la velocidad del perro.
#         - parar(): Establece la velocidad a 0.
#         - ladrar(mensaje): Devuelve un string que simula el ladrido del perro con un mensaje.
#
# Velocidad inicial: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 47
# ...

# %%
class Perro:
    """
    Clase que representa un perro.

    Atributos:
        - Patas: Número de patas del perro (siempre 4).
        - Orejas: Número de orejas del perro (siempre 2).
        - Ojos: Número de ojos del perro (siempre 2).
        - Velocidad: Velocidad del perro (inicialmente 0).
        - Raza: Raza del perro (string, por defecto 'Mastin').
        - Color de pelo: Color del pelo del perro (string, por defecto 'Marron').
        - Dueño: Dueño del perro (por defecto None).
    
    Métodos:
        - andar(aumento_velocidad): Aumenta la velocidad del perro.
        - parar(): Establece la velocidad a 0.
        - ladrar(mensaje): Devuelve un string que simula el ladrido del perro con un mensaje.
    """

    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0

    def __init__(self, raza: str = 'Mastin', color_pelo: str = 'Marron', dueño: str = None):
        self.raza = raza
        self.color_pelo = color_pelo
        self.dueño = dueño

    def andar(self, aumento_velocidad: int):
        """Aumenta la velocidad del perro."""
        self.velocidad += aumento_velocidad

    def parar(self):
        """Establece la velocidad del perro a 0."""
        self.velocidad = 0

    def ladrar(self, mensaje: str):
        """Devuelve un ladrido del perro con el mensaje proporcionado."""
        return f"GUAU! {mensaje}"

# Crear un objeto de tipo Perro, sin dueño
mi_perro = Perro()

# Comprobar que están bien todos sus atributos
print(f"Raza: {mi_perro.raza}")
print(f"Color de pelo: {mi_perro.color_pelo}")
print(f"Dueño: {mi_perro.dueño}")
print(f"Patas: {mi_perro.patas}")
print(f"Orejas: {mi_perro.orejas}")
print(f"Ojos: {mi_perro.ojos}")
print(f"Velocidad inicial: {mi_perro.velocidad}")

# Hacer que el perro ande y comprobar su velocidad
mi_perro.andar(5)  # Aumentamos la velocidad en 5
print(f"Velocidad después de andar: {mi_perro.velocidad}")

# Parar el perro
mi_perro.parar()
print(f"Velocidad después de parar: {mi_perro.velocidad}")

# Hacer que el perro ladre
print(mi_perro.ladrar("¡Hola humano!"))
# Out:
# Raza: Mastin
# Color de pelo: Marron
# Dueño: None
# Patas: 4
# Orejas: 2
# Ojos: 2
# Velocidad inicial: 0
# Velocidad después de andar: 5
# Velocidad después de parar: 0
# GUAU! ¡Hola humano!
