# %% [markdown]
# # Importaciones

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
import re
from sklearn import metrics

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Carga de datos

# %%
# Cargar los datos
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
sample_df = pd.read_csv('data/sample_submission.csv')

# %% [markdown]
# # Primeras exploraciones

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           391 non-null    int64
#  1   Price_euros  391 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 6.2 KB

# %%
train_df.head()
# Out:
#      id  laptop_ID Company                                Product  \
# 0   697        705    Asus                        Chromebook Flip
# 1   435        442    Asus                              Rog Strix
# 2   735        743  Lenovo  V310-15IKB (i7-7500U/4GB/1TB/FHD/W10)
# 3   864        875    Dell                                 XPS 13
# 4  1176       1194  Lenovo    B51-80 (i7-6500U/4GB/1008GB/FHD/W7)
#
#              TypeName  Inches                  ScreenResolution  \
# 0  2 in 1 Convertible    12.5   Full HD / Touchscreen 1920x1080
# 1              Gaming    17.3                 Full HD 1920x1080
# 2            Notebook    15.6                 Full HD 1920x1080
# 3           Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 4            Notebook    15.6                 Full HD 1920x1080
#
#                            Cpu   Ram                Memory  \
# 0  Intel Core M M3-6Y30 0.9GHz   4GB    64GB Flash Storage
# 1        AMD Ryzen 1600 3.2GHz   8GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz   4GB               1TB HDD
# 3   Intel Core i7 7660U 2.5GHz  16GB             512GB SSD
# 4   Intel Core i7 6500U 2.5GHz   4GB          1.0TB Hybrid
#
#                             Gpu       OpSys  Weight  Price_euros
# 0         Intel HD Graphics 515   Chrome OS   1.2kg        669.0
# 1             AMD Radeon RX 580  Windows 10   3.2kg       1695.0
# 2         Intel HD Graphics 620  Windows 10  1.85kg        779.0
# 3  Intel Iris Plus Graphics 640  Windows 10  1.29kg       2240.0
# 4         Intel HD Graphics 520   Windows 7  2.32kg        825.0

# %%
test_df.head()
# Out:
#      id  laptop_ID Company                                Product   TypeName  \
# 0   824        833  Lenovo                            ThinkPad X1  Ultrabook
# 1   101        104      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon   Notebook
# 2  1157       1175  Lenovo                         ThinkPad T460s  Ultrabook
# 3   940        954      HP                         Omen 17-W006na     Gaming
# 4   853        864  Lenovo                         ThinkPad T470p  Ultrabook
#
#    Inches             ScreenResolution                           Cpu   Ram  \
# 0    14.0  IPS Panel Full HD 1920x1080    Intel Core i5 7200U 2.5GHz   8GB
# 1    15.6            Full HD 1920x1080  AMD E-Series E2-9000e 1.5GHz   4GB
# 2    14.0            Full HD 1920x1080    Intel Core i7 6600U 2.6GHz  12GB
# 3    17.3  IPS Panel Full HD 1920x1080   Intel Core i5 6300HQ 2.3GHz   8GB
# 4    14.0  IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz   8GB
#
#                  Memory                      Gpu       OpSys  Weight
# 0   256GB Flash Storage    Intel HD Graphics 620  Windows 10  1.13kg
# 1             500GB HDD            AMD Radeon R2  Windows 10   2.1kg
# 2             512GB SSD    Intel HD Graphics 520   Windows 7   1.4kg
# 3  128GB SSD +  1TB HDD  Nvidia GeForce GTX 965M  Windows 10  2.75kg
# 4             256GB SSD  Nvidia GeForce GT 940MX  Windows 10  1.96kg

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                912 non-null    int64
#  1   laptop_ID         912 non-null    int64
#  2   Company           912 non-null    object
#  3   Product           912 non-null    object
#  4   TypeName          912 non-null    object
#  5   Inches            912 non-null    float64
#  6   ScreenResolution  912 non-null    object
#  7   Cpu               912 non-null    object
#  8   Ram               912 non-null    object
#  9   Memory            912 non-null    object
#  10  Gpu               912 non-null    object
#  11  OpSys             912 non-null    object
#  12  Weight            912 non-null    object
#  13  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 99.9+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                391 non-null    int64
#  1   laptop_ID         391 non-null    int64
#  2   Company           391 non-null    object
#  3   Product           391 non-null    object
#  4   TypeName          391 non-null    object
#  5   Inches            391 non-null    float64
#  6   ScreenResolution  391 non-null    object
#  7   Cpu               391 non-null    object
#  8   Ram               391 non-null    object
#  9   Memory            391 non-null    object
#  10  Gpu               391 non-null    object
#  11  OpSys             391 non-null    object
#  12  Weight            391 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 39.8+ KB

# %%
train_df.describe()
# Out:
#                 id    laptop_ID      Inches  Price_euros
# count   912.000000   912.000000  912.000000    912.00000
# mean    652.099781   661.273026   15.060746   1126.92034
# std     375.428905   380.297415    1.412363    696.08887
# min       0.000000     1.000000   10.100000    174.00000
# 25%     332.500000   338.500000   14.000000    589.00000
# 50%     655.500000   663.500000   15.600000    952.00000
# 75%     980.500000   994.500000   15.600000   1499.00000
# max    1301.000000  1319.000000   18.400000   4899.00000

# %%
sns.displot(train_df['Price_euros']);

# %%
train_df[['Price_euros', 'Inches']].corr()
# Out:
#              Price_euros    Inches
# Price_euros     1.000000  0.070152
# Inches          0.070152  1.000000

# %%
sns.displot(train_df['Inches']);

# %%
sns.scatterplot(data=train_df, x='Inches', y='Price_euros')
plt.title("Relación entre Inches y Price_euros")
plt.xlabel("Tamaño de Pantalla (Inches)")
plt.ylabel("Precio €")
plt.show()

# %% [markdown]
# # Limpieza de datos

# %%
train_df['Company'].unique()
# Out:
# array(['Asus', 'Lenovo', 'Dell', 'Mediacom', 'Toshiba', 'HP', 'Acer',
#        'Apple', 'MSI', 'Fujitsu', 'Samsung', 'Chuwi', 'Microsoft',
#        'Razer', 'Xiaomi', 'Huawei', 'Google', 'Vero', 'LG'], dtype=object)

# %%
train_df['Company'].value_counts()
# Out:
# Company
# Dell         218
# HP           197
# Lenovo       193
# Asus         110
# Acer          76
# Toshiba       37
# MSI           36
# Apple         17
# Mediacom       6
# Samsung        5
# Microsoft      4
# Razer          4
# Xiaomi         2
# Huawei         2
# Google         1
# Vero           1
# Fujitsu        1
# Chuwi          1
# LG             1
# Name: count, dtype: int64

# %%
train_df['Product'].value_counts()
# Out:
# Product
# Inspiron 3567                                    24
# XPS 13                                           21
# Vostro 3568                                      15
# 250 G6                                           13
# Inspiron 5570                                    12
# Legion Y520-15IKBN                               12
# Inspiron 5567                                    11
# Alienware 17                                     11
# Latitude 5580                                    10
# Satellite Pro                                    10
# Inspiron 7567                                    10
# ProBook 450                                      10
# Aspire 3                                          9
# MacBook Pro                                       9
# EliteBook 840                                     9
# Vostro 5568                                       8
# EliteBook 820                                     6
# ProBook 470                                       6
# ThinkPad Yoga                                     6
# EliteBook 850                                     6
# ThinkPad X1                                       6
# ProBook 650                                       6
# IdeaPad 320-15IKBN                                6
# XPS 15                                            6
# Inspiron 5770                                     5
# ProBook 440                                       5
# Latitude 5480                                     5
# IdeaPad 320-15ABR                                 5
# IdeaPad 320-15IKB                                 5
# ProBook 430                                       5
# IdeaPad 320-15ISK                                 5
# Aspire 5                                          5
# Inspiron 5379                                     5
# IdeaPad 320-17IKB                                 5
# Inspiron 7577                                     5
# Aspire E5-576G                                    5
# Rog Strix                                         5
# Notebook 9                                        4
# Swift 3                                           4
# EliteBook 1040                                    4
# IdeaPad 100S-14IBR                                4
# ZenBook Flip                                      4
# Spectre x360                                      4
# ZBook 17                                          4
# MacBook 12"                                       4
# ROG Strix                                         4
# Elitebook 820                                     4
# IdeaPad Y700-15ISK                                4
# Surface Laptop                                    4
# IdeaPad 320-15AST                                 4
# Legion Y720-15IKB                                 4
# IdeaPad 320-15IAP                                 4
# Inspiron 3552                                     4
# ZBook 15                                          3
# IdeaPad 310-15IKB                                 3
# Thinkpad P51                                      3
# Chromebook 14                                     3
# Latitude 7280                                     3
# EliteBook x360                                    3
# Latitude 5590                                     3
# Aspire ES1-572                                    3
# Spectre Pro                                       3
# Aspire A515-51G                                   3
# ProBook 640                                       3
# ZBook 15u                                         3
# Inspiron 7570                                     3
# Precision 3520                                    3
# Latitude 7480                                     3
# Yoga 500-14ISK                                    3
# MacBook Air                                       3
# Probook 440                                       3
# Blade Pro                                         3
# Yoga Book                                         3
# Alienware 15                                      3
# Probook 430                                       3
# VivoBook Max                                      3
# Yoga 920-13IKB                                    3
# Probook 450                                       3
# 15-AC110nv (i7-6500U/6GB/1TB/Radeon               3
# VivoBook S15                                      3
# Yoga 900-13ISK                                    3
# Probook 470                                       3
# Inspiron 3576                                     3
# VivoBook Pro                                      3
# IdeaPad 110-15ISK                                 3
# Thinkpad X1                                       3
# IdeaPad 120S-14IAP                                2
# Elitebook 850                                     2
# Probook 650                                       2
# Inspiron 7773                                     2
# Pavilion 15-AW003nv                               2
# Vostro 3559                                       2
# Aspire R7                                         2
# Pavilion X360                                     2
# Elitebook 840                                     2
# IdeaPad 110-17ACL                                 2
# Inspiron 5577                                     2
# ThinkPad L470                                     2
# Inspiron 5579                                     2
# Inspiron 7579                                     2
# ThinkPad T570                                     2
# Stream 11-Y000na                                  2
# Vostro 5468                                       2
# Probook 640                                       2
# Aspire ES1-523                                    2
# Mi Notebook                                       2
# Aspire A315-31                                    2
# GL72M 7RDX                                        2
# ZenBook UX305CA-UBM1                              2
# Thinkpad T570                                     2
# ThinkPad T470s                                    2
# ThinkPad 13                                       2
# Chromebook Flip                                   2
# ThinkPad L570                                     2
# Yoga 520-14IKB                                    2
# ThinkPad E580                                     2
# SmartBook Edge                                    2
# Inspiron 7378                                     2
# Latitude E5270                                    2
# Thinkpad T470p                                    2
# Inspiron 5578                                     2
# Latitude 3580                                     2
# IdeaPad 310-15ISK                                 2
# Thinkpad T460s                                    2
# GL62M 7RD                                         2
# Aspire A315-51                                    2
# ZBook Studio                                      2
# Yoga 500-15ISK                                    2
# GT72S Dominator                                   2
# MateBook X                                        2
# Aspire E5-575                                     2
# GS73VR Stealth                                    2
# Aspire 7                                          2
# IdeaPad 510-15IKB                                 2
# ThinkPad E570                                     2
# Latitude E5570                                    2
# Aspire A517-51G                                   2
# Inspiron 5368                                     2
# Chromebook 11                                     2
# X541NA (N3350/4GB/1TB/Linux)                      1
# Envy x360                                         1
# GT72VR Dominator                                  1
# L502NA-GO052T (N3350/4GB/128GB/W10)               1
# GL62M 7RDX                                        1
# GT73VR Titan                                      1
# TP501UA-CJ131T (i5-7200U/8GB/1TB/W10)             1
# X555BP-XX180T (A9-9420/4GB/1TB/Radeon             1
# VivoBook E403NA                                   1
# Tecra X40-D-10G                                   1
# V330-15IKB (i5-8250U/8GB/256GB/FHD/W10)           1
# Yoga 700-11ISK                                    1
# Zenbook 3                                         1
# Stream 14-AX000nv                                 1
# Inspiron 5568                                     1
# V110-15ISK (i5-6200U/4GB/128GB/W10)               1
# Rog G752VL-GC088D                                 1
# Aspire 1                                          1
# GE73VR 7RF                                        1
# GP62M 7REX                                        1
# Omen 17-W295                                      1
# EliteBook Folio                                   1
# V310-15ISK (i3-6006U/4GB/128GB/FHD/No             1
# Pavilion 15-cb003nv                               1
# Tecra X40-D-10Z                                   1
# VivoBook X540YA-XX519T                            1
# Rog G701VIK-BA060T                                1
# Chromebook X360                                   1
# G752VY-GC162T (i7-6700HQ/16GB/1TB                 1
# Tecra A50-C-1ZV                                   1
# Latitude 3480                                     1
# E5 774G                                           1
# 15-bs005nv (i3-6006U/4GB/1TB                      1
# Latitude 5289                                     1
# Envy 13-AB020nr                                   1
# Tecra Z50-C-144                                   1
# X541NA (N4200/4GB/1TB/W10)                        1
# Tecra Z40-C-12X                                   1
# IdeaPad 110-15IBR                                 1
# V142 (X5-Z8350/2GB/32GB/W10)                      1
# Latitude 7390                                     1
# ThinkPad P70                                      1
# Predator G9-793                                   1
# Portege A30-C-1CZ                                 1
# X541NA-GO121 (N4200/4GB/1TB/Linux)                1
# IdeaPad 320-14IAP                                 1
# Rog GL753VD-GC082T                                1
# GS60 Ghost                                        1
# Ideapad 310-15ISK                                 1
# Rog GL753VD-GC042T                                1
# V110-15ISK (i3-6006U/4GB/1TB/No                   1
# Rog GL702VS-BA023T                                1
# Zenbook UX330UA-AH5Q                              1
# V110-15ISK (i3-6006U/4GB/500GB/W10)               1
# Elitebook Folio                                   1
# Portege X30-D-10L                                 1
# GS70 Stealth                                      1
# Leopard GP72M                                     1
# FX503VM-E4007T (i7-7700HQ/16GB/1TB                1
# Envy 13-ad009n                                    1
# A541NA-GO342 (N3350/4GB/500GB/Linux)              1
# V310-15IKB (i5-7200U/4GB/1TB/FHD/W10)             1
# Aspire F5-573G-510L                               1
# Rog G752VS-BA171T                                 1
# Ideapad 700-15ISK                                 1
# 15-AY023na (N3710/8GB/2TB/W10)                    1
# X540SA-RBPDN09 (N3710/4GB/1TB/W10)                1
# 15-BW004nv (A9-9420/4GB/256GB/Radeon              1
# Thinkpad E470                                     1
# Omen 15-ce007nv                                   1
# Omen 17-an006nv                                   1
# EliteBook 1030                                    1
# 15-ay047nv (i3-6006U/6GB/1TB/Radeon               1
# Blade Stealth                                     1
# Portege Z30-C-16Z                                 1
# 17-bs001nv (i5-7200U/6GB/2TB/Radeon               1
# SP315-51 (i7-7500U/12GB/1TB/FHD/W10)              1
# 15-BS078nr (i7-7500U/8GB/1TB/W10)                 1
# ZenBook UX530UQ-PRO                               1
# 15-bs023nv (i3-6006U/4GB/1TB/FHD/W10)             1
# Swift 7                                           1
# X751SV-TY001T (N3710/4GB/1TB/GeForce              1
# Pro P2540UA-XS51                                  1
# Rog GL502VS                                       1
# Chromebook CB5-571-C1DZ                           1
# Inspiron 5370                                     1
# 14-am079na (N3710/8GB/2TB/W10)                    1
# Yoga 910-13IKB                                    1
# Inspiron 7560                                     1
# Thinkpad L560                                     1
# IdeaPad 310-15ABR                                 1
# ZenBook UX510UX-CN211T                            1
# Thinkpad T460                                     1
# 15-bs018nq (i3-6006U/4GB/500GB/FHD/No             1
# 15-ra044nv (N3060/4GB/500GB/W10)                  1
# Aspire E5-475                                     1
# VivoBook S14                                      1
# Inspiron 5378                                     1
# X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce         1
# Pavilion 15-BC000nv                               1
# Latitude E7270                                    1
# L403NA-GA013TS (N3350/4GB/32GB/W10)               1
# X541NA-GO020T (N3350/4GB/1TB/W10)                 1
# UX410UA-GV097T (i3-7100U/4GB/256GB/FHD/W10)       1
# GE72MVR 7RG                                       1
# ThinkPad T560                                     1
# Tecra A40-C-1E5                                   1
# Stream 14-AX040wm                                 1
# Noteb Pav                                         1
# Tecra Z50-C-140                                   1
# 17-ak001nv (A6-9220/4GB/500GB/Radeon              1
# Thinkpad E570                                     1
# VivoBook E12                                      1
# K756UX-T4340T (i5-7200U/8GB/500GB                 1
# V330-15IKB (i3-7130U/4GB/128GB/FHD/W10)           1
# GS63VR 7RG                                        1
# V110-15IAP (N3350/4GB/128GB/No                    1
# GS63VR 7RF                                        1
# Chromebook 13                                     1
# Yoga 730                                          1
# Ideapad 320-15ISK                                 1
# IdeaPad Y910-17ISK                                1
# Chromebook C738T-C2EJ                             1
# C740-C9QX (3205U/2GB/32GB/Chrome                  1
# CB5-132T-C9KK (N3160/4GB/32GB/Chrome              1
# X555QG-DM242T (A10-9620P/4GB/1TB                  1
# 17-AK091ND (A9-9420/8GB/1TB/W10)                  1
# Tecra A50-D-11D                                   1
# X751NV-TY001 (N4200/4GB/1TB/GeForce               1
# Zbook 15                                          1
# Spectre 13-V100nv                                 1
# ROG G701VO                                        1
# FX753VD-GC007T (i7-7700HQ/8GB/1TB                 1
# 15-bs025nv (i5-7200U/8GB/256GB/W10)               1
# IdeaPad 510s-14IKB                                1
# B51-80 (i5-6200U/8GB/1TB/Radeon                   1
# R417NA-RS01 (N3350/4GB/32GB/W10)                  1
# X541UV-DM1439T (i3-7100U/6GB/256GB/GeForce        1
# Rog GL553VE-DS74                                  1
# Ideapad 320-15IKBN                                1
# Extensa EX2540-58KR                               1
# Laptop MSI                                        1
# FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce         1
# Portege Z30-C-16P                                 1
# Zenbook UX430UA                                   1
# Zenbook Flip                                      1
# Portg Z30-C-16K                                   1
# Aspire A715-71G                                   1
# 15-BS103nv (i5-8250U/6GB/256GB/Radeon             1
# Lenovo IdeaPad                                    1
# ZenBook UX430UN                                   1
# ThinkPad T470                                     1
# Zbook 17                                          1
# Smartbook 142                                     1
# Latitude 3180                                     1
# 17-bs000nv I3                                     1
# Gram 15Z975                                       1
# E402WA-GA007T (E2-6110/4GB/64GB/W10               1
# FX502VM-DM105T (i7-6700HQ/8GB/1TB/GeForce         1
# FX753VE-GC155T (i7-7700HQ/16GB/1TB                1
# GE63VR 7RE                                        1
# GP72M 7REX                                        1
# Thinkpad P51s                                     1
# Pavilion Power                                    1
# A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce          1
# 15-bs012nv (i7-7500U/8GB/1TB/Radeon               1
# Chromebook C202SA                                 1
# Yoga 900S-12ISK                                   1
# ROG GL553VE-FY022                                 1
# LapBook 12.3                                      1
# 15-bw011nv (A6-9220/4GB/1TB/FHD/W10)              1
# GL72M 7REX                                        1
# SmartBook 141                                     1
# GP72VR Leopard                                    1
# SmartBook 130                                     1
# GS73VR 7RF                                        1
# VivoBook Flip                                     1
# Omen -                                            1
# V310-15ISK (i5-6200U/4GB/1TB/FHD/No               1
# N42-20 Chromebook                                 1
# Pro P2540UA-XO0198T                               1
# Thinkpad P71                                      1
# ThinkPad T460                                     1
# Portege X30-D-10X                                 1
# IdeaPad 320-17ISK                                 1
# Aspire E5-774G                                    1
# GP62M 7RDX                                        1
# R558UA-DM966T (i5-7200U/8GB/128GB/FHD/W10)        1
# Rog GL552VW-CN470T                                1
# Vostro 5370                                       1
# V510-15IKB (i5-7200U/8GB/256GB/FHD/No             1
# FX502VM-DM560T (i7-7700HQ/8GB/1TB                 1
# Rog GL702VM-GC017T                                1
# X542UQ-DM117 (i3-7100U/8GB/1TB/GeForce            1
# Zenbook UX410UA-GV027T                            1
# 15-bs015dx (i5-7200U/8GB/1TB/W10)                 1
# Portege X20W-D-10V                                1
# Envy 13-AD007nv                                   1
# Spin SP111-31                                     1
# 15-BW037na (A9-9420/4GB/1TB/Radeon                1
# B51-80 (i5-6200U/8GB/1008GB/Radeon                1
# GT80S 6QF-074US                                   1
# GT62VR 6RD                                        1
# IdeaPad 320-17IKBR                                1
# Thinkpad X270                                     1
# 15-rb013nv (E2-9000e/4GB/500GB/W10)               1
# Ideapad 520-15IKBR                                1
# GT80S 6QE                                         1
# Macbook Air                                       1
# Portege Z30-C-16H                                 1
# Tecra Z40-C-136                                   1
# ThinkPad P51s                                     1
# Omen 17-w212nv                                    1
# Chromebook C731-C78G                              1
# V310-15IKB (i5-7200U/8GB/1TB                      1
# Tecra A40-C-1DF                                   1
# V110-15ISK (i3-6006U/4GB/1TB/Radeon               1
# 15-bs011nv (i7-7500U/4GB/500GB/Radeon             1
# V110-15ISK (3855U/4GB/500GB/W10)                  1
# 15-BW091ND (A9-9420/6GB/1TB                       1
# Portege X30-D-10J                                 1
# Latitude E7470                                    1
# B51-80 (i7-6500U/4GB/1008GB/FHD/W7)               1
# V310-15IKB (i7-7500U/4GB/1TB/FHD/W10)             1
# Omen 15-ce006nv                                   1
# Tecra A40-C-1KF                                   1
# 15-bw002nv (A6-9220/4GB/256GB/Radeon              1
# Latitude 3380                                     1
# TMX349-G2-M-50FS (i5-7200U/8GB/256GB/FHD/W10)     1
# V310-15ISK (i3-6006U/4GB/1TB/FHD/W10)             1
# Precision M5520                                   1
# Yoga 720-15IKB                                    1
# FlexBook Edge                                     1
# Latitude 5490                                     1
# Chromebook 3                                      1
# 15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)           1
# Latitude 3570                                     1
# Aspire F5-573G                                    1
# FX502VM-AS73 (i7-7700HQ/16GB/1TB                  1
# 250 G4                                            1
# ROG Zephyrus                                      1
# 15-cb003na (i5-7300HQ/8GB/1TB                     1
# Portege Z30T-C-133                                1
# Lifebook A557                                     1
# Yoga 11e                                          1
# Thinkpad T470                                     1
# ZenBook Pro                                       1
# IdeaPad Y900-17ISK                                1
# 15-bs017nv (i7-7500U/8GB/256GB/Radeon             1
# Tecra A50-C-21G                                   1
# ThinkPad L460                                     1
# Portege X30-D-10K                                 1
# V310-15ISK (i3-6006U/4GB/500GB/No                 1
# V320-17ISK (i3-6006U/4GB/500GB/FHD/No             1
# IdeaPad 720S-13IKB                                1
# X705UV-BX074T (i3-6006U/4GB/1TB/GeForce           1
# Inspiron 7559                                     1
# Aspire A515-51G-32MX                              1
# V110-15ISK (i5-6200U/4GB/500GB/No                 1
# Inspiron 7779                                     1
# Pavilion x360                                     1
# Stream 14-AX001nv                                 1
# Rog GL702VS-GC095T                                1
# X751NV-TY001T (N4200/4GB/1TB/GeForce              1
# 15-BW094nd (A6-9220/8GB/128GB/W10)                1
# V310-15ISK (i5-7200U/8GB/1TB                      1
# Vivobook X541UV-DM1217T                           1
# GS73VR 7RG                                        1
# Envy 13-AB077cl                                   1
# Omen 17-an012dx                                   1
# TravelMate B117-M                                 1
# Tecra A50-D-11M                                   1
# Q534UX-BHI7T19 (i7-7500U/16GB/2TB                 1
# 15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)           1
# X550VX-XX015D (i5-6300HQ/4GB/1TB/GeForce          1
# Pixelbook (Core                                   1
# V110-15IKB (i5-7200U/4GB/128GB/W10)               1
# ThinkPad P40                                      1
# Omen 17-w207nv                                    1
# X505BP-BR019T (A9-9420/4GB/1TB/Radeon             1
# GT73EVR 7RE                                       1
# ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)          1
# 15-bs190od (i5-8250U/4GB/1TB/W10)                 1
# Rog GL552VW-DM201T                                1
# X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux)      1
# IdeaPad 520s-14IKB                                1
# Tecra Z40-C-161                                   1
# TravelMate P259-G2                                1
# Yoga 510-15IKB                                    1
# 15-BA015wm (E2-7110/4GB/500GB/W10)                1
# X553SA-XX031T (N3050/4GB/500GB/W10)               1
# Aspire A515-51G-37JS                              1
# ZenBook UX310UA-WB71                              1
# ZenBook UX430UA                                   1
# GP62MVR 6RF                                       1
# Aspire ES1-531                                    1
# Vivobook Max                                      1
# Rog GL753VE-DS74                                  1
# G701VO-IH74K (i7-6820HK/32GB/2x                   1
# Thinkpad Yoga                                     1
# GL553VE-FY082T (i7-7700HQ/8GB/1TB                 1
# V330-15IKB (i5-8250U/4GB/256GB/FHD/W10)           1
# FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce         1
# Pavilion 14-BK001nv                               1
# GS43VR 7RE                                        1
# Portege X30-D-10V                                 1
# Thinkpad T470s                                    1
# Thinkpad T560                                     1
# Predator 17                                       1
# E402WA-GA010T (E2-6110/2GB/32GB/W10)              1
# ROG G703VI-E5062T                                 1
# GE63VR 7RF                                        1
# ZenBook UX310UA-FB485T                            1
# Aspire VX5-591G                                   1
# 15-cd005nv (A9-9420/6GB/256GB/Radeon              1
# 17-X047na (i3-6006U/8GB/1TB/W10)                  1
# Precision 7520                                    1
# F756UX-T4201D (i7-7500U/8GB/128GB                 1
# Rog GL753VE-GC070T                                1
# Omen 17-AN010nv                                   1
# 15-bw003nv (A9-Series-9420/4GB/256GB/FHD/W10)     1
# Spectre 13-V111dx                                 1
# GP62M Leopard                                     1
# Portege Z30-C-1CW                                 1
# X541NA-PD1003Y (N4200/4GB/500GB/W10)              1
# Pro P2540UA-XO0192R                               1
# Pavilion 15-CK000nv                               1
# Precision 5520                                    1
# Insprion 5767                                     1
# 15-BS028nv (i3-6006U/4GB/1TB/Radeon               1
# Rog GL702VM-GC354T                                1
# GL62M 7REX                                        1
# TravelMate B                                      1
# 255 G6                                            1
# Extensa EX2540                                    1
# 110-15ACL (A6-7310/4GB/500GB/W10)                 1
# Name: count, dtype: int64

# %%
train_df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              516
# Gaming                143
# Ultrabook             130
# 2 in 1 Convertible     84
# Workstation            22
# Netbook                17
# Name: count, dtype: int64

# %%
train_df['Inches'].value_counts()
# Out:
# Inches
# 15.6    481
# 14.0    129
# 17.3    116
# 13.3    113
# 12.5     26
# 11.6     21
# 12.0      4
# 13.5      4
# 15.4      3
# 13.9      3
# 10.1      3
# 13.0      2
# 12.3      2
# 15.0      2
# 18.4      1
# 11.3      1
# 17.0      1
# Name: count, dtype: int64

# %%
train_df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                362
# 1366x768                                         207
# IPS Panel Full HD 1920x1080                      145
# IPS Panel Full HD / Touchscreen 1920x1080         37
# Full HD / Touchscreen 1920x1080                   34
# 1600x900                                          15
# Quad HD+ / Touchscreen 3200x1800                  10
# Touchscreen 1366x768                               9
# IPS Panel 4K Ultra HD 3840x2160                    9
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      7
# IPS Panel Retina Display 2560x1600                 6
# 4K Ultra HD 3840x2160                              6
# 4K Ultra HD / Touchscreen 3840x2160                6
# IPS Panel 1366x768                                 5
# IPS Panel Retina Display 2304x1440                 4
# IPS Panel Touchscreen 2560x1440                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# Touchscreen 2256x1504                              4
# 1440x900                                           3
# IPS Panel Touchscreen 1920x1200                    3
# IPS Panel Retina Display 2880x1800                 3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# Touchscreen 2560x1440                              2
# IPS Panel Quad HD+ 2560x1440                       2
# 2560x1440                                          2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Retina Display 2736x1824                 1
# Touchscreen 2400x1600                              1
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
train_df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              143
# Intel Core i7 7700HQ 2.8GHz             107
# Intel Core i7 7500U 2.7GHz               87
# Intel Core i3 6006U 2GHz                 51
# Intel Core i7 8550U 1.8GHz               46
# Intel Core i5 8250U 1.6GHz               45
# Intel Core i5 6200U 2.3GHz               43
# Intel Core i7 6500U 2.5GHz               36
# Intel Core i3 7100U 2.4GHz               28
# Intel Core i7 6700HQ 2.6GHz              27
# Intel Core i5 7300HQ 2.5GHz              21
# Intel Celeron Dual Core N3060 1.6GHz     20
# Intel Celeron Dual Core N3350 1.1GHz     19
# Intel Core i3 6006U 2.0GHz               13
# Intel Core i7 6600U 2.6GHz               12
# Intel Core i7 7600U 2.8GHz               11
# Intel Core i5 7300U 2.6GHz               11
# AMD A9-Series 9420 3GHz                  10
# Intel Core i5 6300U 2.4GHz                9
# Intel Pentium Quad Core N4200 1.1GHz      9
# Intel Core i7 6820HK 2.7GHz               8
# Intel Core i3 6100U 2.3GHz                6
# Intel Pentium Quad Core N3710 1.6GHz      6
# AMD A12-Series 9720P 3.6GHz               5
# Intel Core i7 6820HQ 2.7GHz               5
# Intel Core i7 7820HK 2.9GHz               5
# Intel Celeron Quad Core N3450 1.1GHz      5
# Intel Celeron Dual Core N3050 1.6GHz      5
# Intel Core M 6Y75 1.2GHz                  4
# Intel Core i7 7Y75 1.3GHz                 4
# Intel Core i5 6300HQ 2.3GHz               4
# Intel Core i7 7820HQ 2.9GHz               4
# Intel Core i3 7130U 2.7GHz                4
# AMD A8-Series 7410 2.2GHz                 4
# AMD A6-Series 9220 2.5GHz                 3
# Intel Core i5 1.6GHz                      3
# Intel Core i7 7660U 2.5GHz                3
# Intel Core i5 7Y54 1.2GHz                 3
# Intel Atom x5-Z8550 1.44GHz               3
# Intel Core i7 8650U 1.9GHz                2
# Intel Core i7 7560U 2.4GHz                2
# AMD A9-Series A9-9420 3GHz                2
# Intel Celeron Dual Core 3855U 1.6GHz      2
# Intel Xeon E3-1505M V6 3GHz               2
# Intel Celeron Dual Core N3350 2GHz        2
# Intel Core i5 2.3GHz                      2
# Intel Core M 6Y30 0.9GHz                  2
# Intel Core i5 3.1GHz                      2
# Intel Atom x5-Z8350 1.44GHz               2
# AMD Ryzen 1700 3GHz                       2
# AMD E-Series 7110 1.8GHz                  2
# Intel Celeron Quad Core N3160 1.6GHz      2
# AMD A9-Series 9410 2.9GHz                 2
# AMD A6-Series A6-9220 2.5GHz              2
# Intel Core M 1.2GHz                       2
# Intel Celeron Dual Core 3205U 1.5GHz      2
# Intel Core i5 7200U 2.7GHz                1
# Intel Celeron Quad Core N3710 1.6GHz      1
# Intel Atom X5-Z8350 1.44GHz               1
# Intel Core M m7-6Y75 1.2GHz               1
# Intel Core M M7-6Y75 1.2GHz               1
# Intel Core i7 7500U 2.5GHz                1
# AMD A10-Series A10-9620P 2.5GHz           1
# Intel Core M m3 1.2GHz                    1
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Atom Z8350 1.92GHz                  1
# Intel Xeon E3-1535M v5 2.9GHz             1
# Intel Core i7 6500U 2.50GHz               1
# Intel Pentium Quad Core N3700 1.6GHz      1
# Intel Core i7 2.8GHz                      1
# AMD E-Series E2-9000 2.2GHz               1
# Intel Core i7 2.9GHz                      1
# AMD A6-Series 9220 2.9GHz                 1
# Intel Core i7 7700HQ 2.7GHz               1
# Intel Core i5 1.3GHz                      1
# AMD A10-Series 9600P 2.4GHz               1
# Intel Core i5 2.0GHz                      1
# Intel Core M M3-6Y30 0.9GHz               1
# AMD A9-Series 9420 2.9GHz                 1
# AMD E-Series 6110 1.5GHz                  1
# AMD A12-Series 9720P 2.7GHz               1
# AMD E-Series 9000e 1.5GHz                 1
# Intel Core i5 1.8GHz                      1
# Intel Core i5 7200U 2.70GHz               1
# Intel Core i5 6260U 1.8GHz                1
# Intel Pentium Dual Core 4405U 2.1GHz      1
# AMD A10-Series 9620P 2.5GHz               1
# Intel Core i5 7440HQ 2.8GHz               1
# AMD Ryzen 1600 3.2GHz                     1
# Intel Core i7 6920HQ 2.9GHz               1
# Intel Celeron Dual Core N3350 2.0GHz      1
# Intel Core i3 6100U 2.1GHz                1
# AMD E-Series E2-6110 1.5GHz               1
# AMD A4-Series 7210 2.2GHz                 1
# Intel Pentium Dual Core N4200 1.1GHz      1
# AMD E-Series 9000 2.2GHz                  1
# Intel Core i7 2.2GHz                      1
# Intel Core i5 2.9GHz                      1
# Intel Core i3 6006U 2.2GHz                1
# Intel Core i5 7200U 2.50GHz               1
# Intel Xeon E3-1535M v6 3.1GHz             1
# AMD A6-Series 7310 2GHz                   1
# Name: count, dtype: int64

# %%
train_df['Ram'].value_counts()
# Out:
# Ram
# 8GB     428
# 4GB     266
# 16GB    140
# 6GB      31
# 12GB     20
# 2GB      14
# 32GB     11
# 24GB      1
# 64GB      1
# Name: count, dtype: int64

# %%
train_df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        284
# 1TB HDD                          173
# 500GB HDD                         85
# 512GB SSD                         80
# 128GB SSD +  1TB HDD              65
# 128GB SSD                         53
# 256GB SSD +  1TB HDD              50
# 32GB Flash Storage                27
# 512GB SSD +  1TB HDD              11
# 1TB SSD                           10
# 64GB Flash Storage                10
# 2TB HDD                            9
# 256GB SSD +  2TB HDD               9
# 32GB SSD                           6
# 1.0TB Hybrid                       6
# 16GB Flash Storage                 5
# 256GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 128GB Flash Storage                2
# 512GB Flash Storage                2
# 256GB SSD +  256GB SSD             2
# 256GB SSD +  500GB HDD             2
# 32GB HDD                           1
# 1TB SSD +  1TB HDD                 1
# 1TB HDD +  1TB HDD                 1
# 240GB SSD                          1
# 64GB SSD                           1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 128GB SSD +  2TB HDD               1
# 512GB SSD +  512GB SSD             1
# 256GB SSD +  1.0TB Hybrid          1
# 128GB HDD                          1
# 508GB Hybrid                       1
# 180GB SSD                          1
# 8GB SSD                            1
# Name: count, dtype: int64

# %%
train_df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620             191
# Intel HD Graphics 520             132
# Intel UHD Graphics 620             47
# Nvidia GeForce GTX 1050            40
# Nvidia GeForce GTX 1060            39
# Nvidia GeForce 940MX               31
# Intel HD Graphics 500              28
# AMD Radeon 530                     27
# Intel HD Graphics 400              25
# Nvidia GeForce GTX 1070            24
# Nvidia GeForce GTX 1050 Ti         23
# AMD Radeon R5 M430                 19
# Intel HD Graphics                  16
# AMD Radeon 520                     13
# Nvidia GeForce 930MX               13
# Intel HD Graphics 515              11
# AMD Radeon R7 M445                 10
# AMD Radeon R5                      10
# Nvidia GeForce 920MX               10
# Nvidia GeForce MX150                9
# Intel HD Graphics 615               9
# Intel Iris Plus Graphics 640        8
# Intel HD Graphics 505               7
# AMD Radeon R5 M420                  7
# Nvidia GeForce GTX 950M             7
# Nvidia GeForce GTX 980M             6
# Nvidia GeForce GTX 960M             6
# AMD Radeon R5 M330                  5
# Intel HD Graphics 405               5
# Nvidia Quadro M1200                 5
# Intel HD Graphics 6000              4
# Nvidia GeForce 920MX                4
# Nvidia GeForce 920M                 4
# AMD Radeon RX 580                   4
# Nvidia GeForce GT 940MX             4
# AMD Radeon R2 Graphics              4
# Nvidia GeForce MX130                4
# Nvidia GeForce GTX 940MX            4
# Nvidia Quadro M1000M                4
# Nvidia GeForce 930M                 4
# AMD Radeon R5 M420X                 3
# Nvidia GeForce 150MX                3
# Nvidia Quadro M620                  3
# Nvidia GeForce GTX 1080             3
# AMD Radeon R4 Graphics              3
# Intel HD Graphics 630               3
# Nvidia Quadro M2200M                3
# AMD Radeon R7 M440                  3
# AMD Radeon R2                       3
# Nvidia GeForce GTX 970M             3
# Intel HD Graphics 510               3
# Nvidia GeForce 930MX                3
# AMD Radeon RX 550                   2
# Nvidia GeForce GTX 965M             2
# AMD FirePro W4190M                  2
# AMD Radeon R7 M460                  2
# AMD Radeon R4                       2
# AMD Radeon RX 540                   2
# Nvidia Quadro M520M                 2
# Nvidia GeForce GTX 1050Ti           2
# Nvidia Quadro M2200                 2
# Intel Iris Plus Graphics 650        2
# Nvidia GeForce GTX 1050M            2
# Nvidia GeForce GTX1060              1
# Intel Iris Graphics 540             1
# Nvidia Quadro 3000M                 1
# AMD R17M-M1-70                      1
# Nvidia Quadro M3000M                1
# Nvidia GeForce GTX1050 Ti           1
# AMD FirePro W6150M                  1
# Nvidia GeForce GTX 980              1
# Nvidia Quadro M2000M                1
# AMD Radeon Pro 555                  1
# Nvidia GeForce GTX 960              1
# AMD FirePro W4190M                  1
# AMD Radeon Pro 560                  1
# AMD Radeon R5 520                   1
# AMD Radeon R7                       1
# Nvidia Quadro M500M                 1
# Nvidia GTX 980 SLI                  1
# Nvidia GeForce GTX 960<U+039C>      1
# Intel HD Graphics 540               1
# AMD Radeon R5 M315                  1
# Nvidia GeForce GTX1080              1
# Intel Graphics 620                  1
# Intel Iris Graphics 550             1
# Intel Iris Pro Graphics             1
# Intel HD Graphics 5300              1
# AMD Radeon R3                       1
# Nvidia Quadro M620M                 1
# Intel HD Graphics 620               1
# AMD Radeon 540                      1
# Nvidia GeForce 960M                 1
# AMD Radeon R5 430                   1
# Name: count, dtype: int64

# %%
train_df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      745
# Linux            46
# No OS            46
# Windows 7        33
# Chrome OS        18
# macOS            11
# Mac OS X          6
# Windows 10 S      5
# Android           2
# Name: count, dtype: int64

# %%
train_df.head()
# Out:
#      id  laptop_ID Company                                Product  \
# 0   697        705    Asus                        Chromebook Flip
# 1   435        442    Asus                              Rog Strix
# 2   735        743  Lenovo  V310-15IKB (i7-7500U/4GB/1TB/FHD/W10)
# 3   864        875    Dell                                 XPS 13
# 4  1176       1194  Lenovo    B51-80 (i7-6500U/4GB/1008GB/FHD/W7)
#
#              TypeName  Inches                  ScreenResolution  \
# 0  2 in 1 Convertible    12.5   Full HD / Touchscreen 1920x1080
# 1              Gaming    17.3                 Full HD 1920x1080
# 2            Notebook    15.6                 Full HD 1920x1080
# 3           Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 4            Notebook    15.6                 Full HD 1920x1080
#
#                            Cpu   Ram                Memory  \
# 0  Intel Core M M3-6Y30 0.9GHz   4GB    64GB Flash Storage
# 1        AMD Ryzen 1600 3.2GHz   8GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz   4GB               1TB HDD
# 3   Intel Core i7 7660U 2.5GHz  16GB             512GB SSD
# 4   Intel Core i7 6500U 2.5GHz   4GB          1.0TB Hybrid
#
#                             Gpu       OpSys  Weight  Price_euros
# 0         Intel HD Graphics 515   Chrome OS   1.2kg        669.0
# 1             AMD Radeon RX 580  Windows 10   3.2kg       1695.0
# 2         Intel HD Graphics 620  Windows 10  1.85kg        779.0
# 3  Intel Iris Plus Graphics 640  Windows 10  1.29kg       2240.0
# 4         Intel HD Graphics 520   Windows 7  2.32kg        825.0

# %%
# Procesar la columna 'Weight' y convertirla a numérico
train_df['Weight'] = train_df['Weight'].str.replace('kg', '').astype(float)
test_df['Weight'] = test_df['Weight'].str.replace('kg', '').astype(float)

# Procesar la columna 'Ram' y convertirla a numérico
train_df['Ram'] = train_df['Ram'].str.replace('GB', '').astype(int)
test_df['Ram'] = test_df['Ram'].str.replace('GB', '').astype(int)

# Extraer la resolución de pantalla y combinarla en una sola columna 'Resolution'
train_df[['res_width', 'res_height']] = train_df['ScreenResolution'].str.extract(r'(\d{3,4})x(\d{3,4})').astype(float)
test_df[['res_width', 'res_height']] = test_df['ScreenResolution'].str.extract(r'(\d{3,4})x(\d{3,4})').astype(float)

# Combinar 'res_width' y 'res_height' en una sola columna 'Resolution'
train_df['Resolution'] = train_df['res_width'] * train_df['res_height']
test_df['Resolution'] = test_df['res_width'] * test_df['res_height']

# Eliminar las columnas 'res_width' y 'res_height'
train_df = train_df.drop(columns=['res_width', 'res_height'])
test_df = test_df.drop(columns=['res_width', 'res_height'])

# Procesar la columna 'Memory' para separar SSD, HDD, Flash Storage y Hybrid
def parse_memory_details(memory_str):
    if isinstance(memory_str, str):
        memory_str = memory_str.strip().lower()
        ssd, hdd, flash, hybrid = 0, 0, 0, 0
        
        # Detectar y convertir SSD
        if 'ssd' in memory_str:
            matches = re.findall(r'(\d+)(tb|gb) ssd', memory_str)
            for size, unit in matches:
                ssd += int(size) * (1024 if unit == 'tb' else 1)  # Convertir TB a GB
        
        # Detectar y convertir HDD
        if 'hdd' in memory_str:
            matches = re.findall(r'(\d+)(tb|gb) hdd', memory_str)
            for size, unit in matches:
                hdd += int(size) * (1024 if unit == 'tb' else 1)  # Convertir TB a GB
        
        # Detectar Flash Storage
        if 'flash storage' in memory_str:
            flash = 1
        
        # Detectar Hybrid
        if 'hybrid' in memory_str:
            hybrid = 1
        
        return ssd, hdd, flash, hybrid
    
    # Si no es una cadena válida, devolver ceros
    return 0, 0, 0, 0

# Aplicar la función actualizada a la columna 'Memory'
train_df[['Memory_SSD', 'Memory_HDD', 'Flash_Storage', 'Hybrid']] = train_df['Memory'].apply(
    lambda x: pd.Series(parse_memory_details(x))
)
test_df[['Memory_SSD', 'Memory_HDD', 'Flash_Storage', 'Hybrid']] = test_df['Memory'].apply(
    lambda x: pd.Series(parse_memory_details(x))
)

# Eliminar la columna original 'Memory'
train_df = train_df.drop(columns=['Memory'])
test_df = test_df.drop(columns=['Memory'])

# Procesar la columna 'Cpu' para extraer detalles
def parse_cpu_details(cpu_str):
    if isinstance(cpu_str, str):
        cpu_str = cpu_str.strip().lower()
        cores = re.search(r'(\d+)\s*core', cpu_str)
        cores = int(cores.group(1)) if cores else 0
        frequency = re.search(r'(\d+\.?\d*)\s*ghz', cpu_str)
        frequency = float(frequency.group(1)) if frequency else 0.0
        family = 'Intel' if 'intel' in cpu_str else 'AMD' if 'amd' in cpu_str else 'Other'
        series = re.search(r'(i\d|ryzen \d)', cpu_str)
        series = series.group(1) if series else 'Other'
        return cores, frequency, family, series
    return 0, 0.0, 'Other', 'Other'

train_df[['Cpu_Cores', 'Cpu_Frequency', 'Cpu_Family', 'Cpu_Series']] = train_df['Cpu'].apply(
    lambda x: pd.Series(parse_cpu_details(x))
)
test_df[['Cpu_Cores', 'Cpu_Frequency', 'Cpu_Family', 'Cpu_Series']] = test_df['Cpu'].apply(
    lambda x: pd.Series(parse_cpu_details(x))
)

# Eliminar la columna 'Cpu'
train_df = train_df.drop(columns=['Cpu'])
test_df = test_df.drop(columns=['Cpu'])

train_df = pd.get_dummies(train_df, columns=['Cpu_Family', 'Cpu_Series'], drop_first=True)
test_df = pd.get_dummies(test_df, columns=['Cpu_Family', 'Cpu_Series'], drop_first=True)

# Procesar la columna 'Gpu' para extraer detalles
def parse_gpu_details(gpu_str):
    if isinstance(gpu_str, str):
        gpu_str = gpu_str.strip().lower()
        brand = 'NVIDIA' if 'nvidia' in gpu_str else 'AMD' if 'amd' in gpu_str else 'Intel' if 'intel' in gpu_str else 'Other'
        family = re.search(r'(gtx|rtx|radeon|iris|hd graphics)', gpu_str)
        family = family.group(1) if family else 'Other'
        model = re.search(r'\b(\d+)\b', gpu_str)
        model = int(model.group(1)) if model else 0
        return brand, family, model
    return 'Other', 'Other', 0

train_df[['Gpu_Brand', 'Gpu_Family', 'Gpu_Model']] = train_df['Gpu'].apply(
    lambda x: pd.Series(parse_gpu_details(x))
)
test_df[['Gpu_Brand', 'Gpu_Family', 'Gpu_Model']] = test_df['Gpu'].apply(
    lambda x: pd.Series(parse_gpu_details(x))
)

train_df = pd.get_dummies(train_df, columns=['Gpu_Brand', 'Gpu_Family'], drop_first=True)
test_df = pd.get_dummies(test_df, columns=['Gpu_Brand', 'Gpu_Family'], drop_first=True)

# Procesar la columna 'Company' como variable categórica (One-Hot Encoding)
train_companies = pd.get_dummies(train_df['Company'], prefix='Company')
test_companies = pd.get_dummies(test_df['Company'], prefix='Company')

# Asegurar que ambas tablas tengan las mismas columnas
common_cols = train_companies.columns.union(test_companies.columns)
train_companies = train_companies.reindex(columns=common_cols, fill_value=0)
test_companies = test_companies.reindex(columns=common_cols, fill_value=0)

# Agregar las columnas procesadas de 'Company' al conjunto principal
train_df = pd.concat([train_df, train_companies], axis=1)
test_df = pd.concat([test_df, test_companies], axis=1)

# Procesar las columnas 'TypeName' y 'OpSys' como variables categóricas (One-Hot Encoding)
for col in ['TypeName', 'OpSys']:
    train_encoded = pd.get_dummies(train_df[col], prefix=col)
    test_encoded = pd.get_dummies(test_df[col], prefix=col)
    
    # Asegurar columnas comunes
    common_cols = train_encoded.columns.union(test_encoded.columns)
    train_encoded = train_encoded.reindex(columns=common_cols, fill_value=0)
    test_encoded = test_encoded.reindex(columns=common_cols, fill_value=0)
    
    # Agregar al conjunto principal
    train_df = pd.concat([train_df, train_encoded], axis=1)
    test_df = pd.concat([test_df, test_encoded], axis=1)
    
    # Eliminar la columna original
    train_df = train_df.drop(columns=[col])
    test_df = test_df.drop(columns=[col])

# Actualizar las características finales después de asegurar columnas comunes
features_to_use_improved = (
    ['Inches', 'Ram', 'Weight', 'Resolution', 'Memory_SSD', 'Memory_HDD', 'Flash_Storage', 'Hybrid', 'Cpu_Cores', 'Cpu_Frequency', 'Gpu_Model']
    + [col for col in train_df.columns if col.startswith('TypeName_') or col.startswith('OpSys_') or col.startswith('Cpu_Family_') or col.startswith('Cpu_Series_') or col.startswith('Gpu_Brand_') or col.startswith('Gpu_Family_') or col.startswith('Company_')]
)

# Crear los conjuntos de entrenamiento y prueba
X_train_improved = train_df[features_to_use_improved]
X_test_improved = test_df[features_to_use_improved]

# Manejar columnas faltantes en el conjunto de prueba
missing_cols_test = set(X_train_improved.columns) - set(X_test_improved.columns)
for col in missing_cols_test:
    X_test_improved[col] = 0
X_test_improved = X_test_improved[X_train_improved.columns]

# Separar la variable objetivo (target)
y_train = train_df['Price_euros']

# Dividir los datos en conjunto de entrenamiento y validación
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_improved, y_train, test_size=0.2, random_state=42
)

# Aplicar la transformación logarítmica para la variable objetivo
y_train_log = np.log1p(y_train_split)
y_val_log = np.log1p(y_val_split)

print("Preprocesamiento completo. Datos listos para modelar.")
# Out:
# Preprocesamiento completo. Datos listos para modelar.

# %%
y_train_log.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 729 entries, 25 to 102
# Series name: Price_euros
# Non-Null Count  Dtype
# --------------  -----
# 729 non-null    float64
# dtypes: float64(1)
# memory usage: 11.4 KB

# %%
# Visualizar la distribución de y_train_log
sns.displot(y_train_log, kde=True)  # kde=True añade la línea de densidad
plt.title('Distribución de y_train_log')
plt.xlabel('y_train_log')
plt.ylabel('Densidad')
plt.show()

# %%
X_train_improved.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Inches                       912 non-null    float64
#  1   Ram                          912 non-null    int32
#  2   Weight                       912 non-null    float64
#  3   Resolution                   912 non-null    float64
#  4   Memory_SSD                   912 non-null    int64
#  5   Memory_HDD                   912 non-null    int64
#  6   Flash_Storage                912 non-null    int64
#  7   Hybrid                       912 non-null    int64
#  8   Cpu_Cores                    912 non-null    int64
#  9   Cpu_Frequency                912 non-null    float64
#  10  Gpu_Model                    912 non-null    int64
#  11  Cpu_Family_Intel             912 non-null    bool
#  12  Cpu_Series_i3                912 non-null    bool
#  13  Cpu_Series_i5                912 non-null    bool
#  14  Cpu_Series_i7                912 non-null    bool
#  15  Cpu_Series_ryzen 1           912 non-null    bool
#  16  Gpu_Brand_Intel              912 non-null    bool
#  17  Gpu_Brand_NVIDIA             912 non-null    bool
#  18  Gpu_Family_gtx               912 non-null    bool
#  19  Gpu_Family_hd graphics       912 non-null    bool
#  20  Gpu_Family_iris              912 non-null    bool
#  21  Gpu_Family_radeon            912 non-null    bool
#  22  Company_Acer                 912 non-null    bool
#  23  Company_Apple                912 non-null    bool
#  24  Company_Asus                 912 non-null    bool
#  25  Company_Chuwi                912 non-null    bool
#  26  Company_Dell                 912 non-null    bool
#  27  Company_Fujitsu              912 non-null    bool
#  28  Company_Google               912 non-null    bool
#  29  Company_HP                   912 non-null    bool
#  30  Company_Huawei               912 non-null    bool
#  31  Company_LG                   912 non-null    bool
#  32  Company_Lenovo               912 non-null    bool
#  33  Company_MSI                  912 non-null    bool
#  34  Company_Mediacom             912 non-null    bool
#  35  Company_Microsoft            912 non-null    bool
#  36  Company_Razer                912 non-null    bool
#  37  Company_Samsung              912 non-null    bool
#  38  Company_Toshiba              912 non-null    bool
#  39  Company_Vero                 912 non-null    bool
#  40  Company_Xiaomi               912 non-null    bool
#  41  TypeName_2 in 1 Convertible  912 non-null    bool
#  42  TypeName_Gaming              912 non-null    bool
#  43  TypeName_Netbook             912 non-null    bool
#  44  TypeName_Notebook            912 non-null    bool
#  45  TypeName_Ultrabook           912 non-null    bool
#  46  TypeName_Workstation         912 non-null    bool
#  47  OpSys_Android                912 non-null    bool
#  48  OpSys_Chrome OS              912 non-null    bool
#  49  OpSys_Linux                  912 non-null    bool
#  50  OpSys_Mac OS X               912 non-null    bool
#  51  OpSys_No OS                  912 non-null    bool
#  52  OpSys_Windows 10             912 non-null    bool
#  53  OpSys_Windows 10 S           912 non-null    bool
#  54  OpSys_Windows 7              912 non-null    bool
#  55  OpSys_macOS                  912 non-null    bool
# dtypes: bool(45), float64(4), int32(1), int64(6)
# memory usage: 115.0 KB

# %%
X_train_improved.describe()
# Out:
#            Inches         Ram      Weight    Resolution   Memory_SSD  \
# count  912.000000  912.000000  912.000000  9.120000e+02   912.000000
# mean    15.060746    8.357456    2.053658  2.157365e+06   182.785088
# std      1.412363    5.108641    0.659502  1.386117e+06   189.150687
# min     10.100000    2.000000    0.690000  1.049088e+06     0.000000
# 25%     14.000000    4.000000    1.557500  1.440000e+06     0.000000
# 50%     15.600000    8.000000    2.060000  2.073600e+06   210.000000
# 75%     15.600000    8.000000    2.310000  2.073600e+06   256.000000
# max     18.400000   64.000000    4.700000  8.294400e+06  1024.000000
#
#         Memory_HDD  Flash_Storage      Hybrid  Cpu_Cores  Cpu_Frequency  \
# count   912.000000     912.000000  912.000000      912.0     912.000000
# mean    437.486842       0.055921    0.008772        0.0       2.316623
# std     533.515335       0.229895    0.093298        0.0       0.501611
# min       0.000000       0.000000    0.000000        0.0       0.900000
# 25%       0.000000       0.000000    0.000000        0.0       2.000000
# 50%       0.000000       0.000000    0.000000        0.0       2.500000
# 75%    1024.000000       0.000000    0.000000        0.0       2.700000
# max    2048.000000       1.000000    1.000000        0.0       3.600000
#
#          Gpu_Model
# count   912.000000
# mean    512.615132
# std     524.189184
# min       0.000000
# 25%       0.000000
# 50%     520.000000
# 75%     620.000000
# max    6000.000000

# %%
# Seleccionar un subconjunto de variables numéricas clave
subset_columns = ['Price_euros', 'Ram', 'Weight', 'Resolution', 'Memory_SSD', 'Memory_HDD', 'Cpu_Cores', 'Cpu_Frequency', 'Inches','Gpu_Model']

# Crear un dataframe con las columnas seleccionadas
pairplot_df = train_df[subset_columns].copy()

# Crear categorías para 'Price_euros'
bins = [0, 500, 1000, 2000, 5000]  # Rango de precios
labels = ['Low', 'Medium', 'High', 'Very High']  # Etiquetas para las categorías
pairplot_df['Price_Category'] = pd.cut(pairplot_df['Price_euros'], bins=bins, labels=labels)

# Generar el pairplot con hue
sns.pairplot(pairplot_df, diag_kind='kde', hue='Price_Category', plot_kws={'alpha': 0.6})
plt.suptitle("Pairplot de características clave por categoría de precio", y=1.02)
plt.show()

# %%
# Seleccionar las columnas numéricas clave para la matriz de correlación
correlation_columns = ['Price_euros', 'Ram', 'Weight', 'Resolution', 'Memory_SSD', 'Memory_HDD', 'Cpu_Cores', 'Cpu_Frequency']

# Calcular la matriz de correlación
correlation_matrix = train_df[correlation_columns].corr()

# Configurar el tamaño del gráfico
plt.figure(figsize=(10, 8))

# Visualizar la matriz de correlación como un heatmap
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    fmt=".2f", 
    cmap='coolwarm', 
    linewidths=0.5
)

# Título del heatmap
plt.title("Matriz de correlación de características clave", fontsize=16)

# Mostrar el gráfico
plt.show()

# %%
# Definir modelos a usar
models = {
    "Random Forest": RandomForestRegressor(random_state=42, n_jobs=-1),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "XGBoost": XGBRegressor(random_state=42, n_jobs=-1)
}

# Crear un DataFrame para almacenar las importancias de características
feature_importances = pd.DataFrame(index=X_train_improved.columns)

# Iterar sobre los modelos para calcular importancias
for model_name, model in models.items():
    print(f"Entrenando modelo: {model_name}...")
    model.fit(X_train_improved, y_train)  # Entrenar modelo
    
    # Obtener importancias de características y agregarlas a la tabla
    feature_importances[model_name] = model.feature_importances_

# Calcular el promedio de importancias
feature_importances['Average Importance'] = feature_importances.mean(axis=1)

# Ordenar las características por su importancia promedio
feature_importances = feature_importances.sort_values(by='Average Importance', ascending=False)

# Mostrar la tabla de importancias
print("Tabla de Importancia de Características:")
print(feature_importances)

# Visualización de importancias
feature_importances.reset_index(inplace=True)
feature_importances.rename(columns={'index': 'Feature'}, inplace=True)

plt.figure(figsize=(14, 8))

# Crear un gráfico por modelo
sns.barplot(data=feature_importances, x='Average Importance', y='Feature', orient='h')
plt.title("Importancia Promedio de Características")
plt.xlabel("Importancia Promedio")
plt.ylabel("Características")
plt.show()

# Gráfico separado por modelo
for model_name in models.keys():
    plt.figure(figsize=(14, 8))
    sns.barplot(data=feature_importances, x=model_name, y='Feature', orient='h')
    plt.title(f"Importancia de Características según {model_name}")
    plt.xlabel("Importancia")
    plt.ylabel("Características")
    plt.show()
# Out:
# Entrenando modelo: Random Forest...
# Entrenando modelo: Gradient Boosting...
# Entrenando modelo: XGBoost...
# Tabla de Importancia de Características:
#                              Random Forest  Gradient Boosting   XGBoost  \
# Ram                           5.180797e-01           0.395120  0.168193
# TypeName_Notebook             6.541871e-02           0.071211  0.134859
# Memory_SSD                    5.037791e-02           0.144757  0.027523
# Weight                        9.167978e-02           0.093369  0.011240
# Cpu_Series_i7                 1.890457e-02           0.054485  0.116718
# TypeName_Workstation          2.391241e-02           0.028743  0.093176
# Cpu_Frequency                 5.649876e-02           0.051079  0.018769
# Resolution                    3.181150e-02           0.046814  0.026492
# Gpu_Model                     3.572620e-02           0.029785  0.016310
# OpSys_Windows 7               9.747491e-03           0.015106  0.041590
# Cpu_Series_i5                 1.467626e-02           0.012413  0.031958
# Gpu_Family_radeon             2.608852e-03           0.003092  0.046831
# Inches                        2.284178e-02           0.017800  0.010015
# Company_Razer                 2.453106e-03           0.004713  0.030876
# OpSys_No OS                   1.691549e-03           0.004782  0.025366
# Company_Acer                  1.428710e-03           0.002816  0.021401
# Cpu_Family_Intel              9.406775e-04           0.001795  0.017721
# Company_Asus                  5.230416e-03           0.001844  0.010193
# OpSys_Windows 10              4.397753e-03           0.001133  0.010750
# Company_Dell                  3.671526e-03           0.002186  0.009239
# Gpu_Family_hd graphics        1.117174e-03           0.000000  0.012992
# Company_LG                    2.010138e-04           0.001455  0.011088
# Company_HP                    6.231864e-03           0.001315  0.005087
# Memory_HDD                    5.678430e-03           0.001680  0.004985
# TypeName_2 in 1 Convertible   3.028943e-03           0.000435  0.008508
# TypeName_Ultrabook            1.744016e-03           0.001686  0.008227
# Company_Lenovo                4.798523e-03           0.002876  0.003884
# Company_Toshiba               1.854756e-03           0.001231  0.008179
# Company_MSI                   1.883980e-03           0.000305  0.007287
# Company_Huawei                5.619960e-05           0.000044  0.009356
# Gpu_Brand_NVIDIA              2.442764e-03           0.000778  0.006085
# Cpu_Series_ryzen 1            3.158186e-05           0.000000  0.008499
# Gpu_Family_gtx                1.489728e-03           0.001670  0.005204
# Flash_Storage                 2.504173e-04           0.000187  0.007483
# Cpu_Series_i3                 2.070283e-03           0.000307  0.005057
# TypeName_Gaming               2.049130e-03           0.001143  0.003884
# OpSys_Linux                   6.098690e-04           0.001018  0.004641
# Gpu_Brand_Intel               1.299187e-03           0.000104  0.002948
# OpSys_Android                 3.046953e-05           0.000000  0.001525
# Gpu_Family_iris               9.454465e-05           0.000205  0.001256
# OpSys_macOS                   3.976172e-05           0.000000  0.000987
# TypeName_Netbook              1.854570e-04           0.000104  0.000724
# Company_Mediacom              2.503264e-05           0.000161  0.000770
# Company_Fujitsu               2.117763e-05           0.000000  0.000755
# Hybrid                        8.965476e-05           0.000076  0.000312
# OpSys_Chrome OS               3.418019e-05           0.000000  0.000413
# Company_Apple                 1.387165e-04           0.000153  0.000000
# OpSys_Windows 10 S            2.273373e-05           0.000000  0.000234
# Company_Vero                  7.714141e-07           0.000000  0.000246
# Company_Samsung               1.586863e-04           0.000000  0.000066
# OpSys_Mac OS X                1.332173e-04           0.000024  0.000000
# Company_Xiaomi                1.570448e-05           0.000000  0.000099
# Company_Microsoft             5.602169e-05           0.000000  0.000000
# Company_Google                1.288683e-05           0.000000  0.000000
# Company_Chuwi                 5.462855e-06           0.000000  0.000000
# Cpu_Cores                     0.000000e+00           0.000000  0.000000
#
#                              Average Importance
# Ram                                    0.360464
# TypeName_Notebook                      0.090496
# Memory_SSD                             0.074219
# Weight                                 0.065430
# Cpu_Series_i7                          0.063369
# TypeName_Workstation                   0.048610
# Cpu_Frequency                          0.042116
# Resolution                             0.035039
# Gpu_Model                              0.027274
# OpSys_Windows 7                        0.022148
# Cpu_Series_i5                          0.019683
# Gpu_Family_radeon                      0.017511
# Inches                                 0.016886
# Company_Razer                          0.012680
# OpSys_No OS                            0.010613
# Company_Acer                           0.008549
# Cpu_Family_Intel                       0.006819
# Company_Asus                           0.005756
# OpSys_Windows 10                       0.005427
# Company_Dell                           0.005032
# Gpu_Family_hd graphics                 0.004703
# Company_LG                             0.004248
# Company_HP                             0.004211
# Memory_HDD                             0.004114
# TypeName_2 in 1 Convertible            0.003991
# TypeName_Ultrabook                     0.003886
# Company_Lenovo                         0.003853
# Company_Toshiba                        0.003755
# Company_MSI                            0.003159
# Company_Huawei                         0.003152
# Gpu_Brand_NVIDIA                       0.003102
# Cpu_Series_ryzen 1                     0.002844
# Gpu_Family_gtx                         0.002788
# Flash_Storage                          0.002640
# Cpu_Series_i3                          0.002478
# TypeName_Gaming                        0.002359
# OpSys_Linux                            0.002090
# Gpu_Brand_Intel                        0.001450
# OpSys_Android                          0.000519
# Gpu_Family_iris                        0.000518
# OpSys_macOS                            0.000342
# TypeName_Netbook                       0.000338
# Company_Mediacom                       0.000319
# Company_Fujitsu                        0.000259
# Hybrid                                 0.000159
# OpSys_Chrome OS                        0.000149
# Company_Apple                          0.000097
# OpSys_Windows 10 S                     0.000086
# Company_Vero                           0.000082
# Company_Samsung                        0.000075
# OpSys_Mac OS X                         0.000053
# Company_Xiaomi                         0.000038
# Company_Microsoft                      0.000019
# Company_Google                         0.000004
# Company_Chuwi                          0.000002
# Cpu_Cores                              0.000000

# %%
X_test_improved.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Inches                       391 non-null    float64
#  1   Ram                          391 non-null    int32
#  2   Weight                       391 non-null    float64
#  3   Resolution                   391 non-null    float64
#  4   Memory_SSD                   391 non-null    int64
#  5   Memory_HDD                   391 non-null    int64
#  6   Flash_Storage                391 non-null    int64
#  7   Hybrid                       391 non-null    int64
#  8   Cpu_Cores                    391 non-null    int64
#  9   Cpu_Frequency                391 non-null    float64
#  10  Gpu_Model                    391 non-null    int64
#  11  Cpu_Family_Intel             391 non-null    bool
#  12  Cpu_Series_i3                391 non-null    bool
#  13  Cpu_Series_i5                391 non-null    bool
#  14  Cpu_Series_i7                391 non-null    bool
#  15  Cpu_Series_ryzen 1           391 non-null    bool
#  16  Gpu_Brand_Intel              391 non-null    bool
#  17  Gpu_Brand_NVIDIA             391 non-null    bool
#  18  Gpu_Family_gtx               391 non-null    bool
#  19  Gpu_Family_hd graphics       391 non-null    bool
#  20  Gpu_Family_iris              391 non-null    bool
#  21  Gpu_Family_radeon            391 non-null    bool
#  22  Company_Acer                 391 non-null    bool
#  23  Company_Apple                391 non-null    bool
#  24  Company_Asus                 391 non-null    bool
#  25  Company_Chuwi                391 non-null    bool
#  26  Company_Dell                 391 non-null    bool
#  27  Company_Fujitsu              391 non-null    bool
#  28  Company_Google               391 non-null    bool
#  29  Company_HP                   391 non-null    bool
#  30  Company_Huawei               391 non-null    int64
#  31  Company_LG                   391 non-null    bool
#  32  Company_Lenovo               391 non-null    bool
#  33  Company_MSI                  391 non-null    bool
#  34  Company_Mediacom             391 non-null    bool
#  35  Company_Microsoft            391 non-null    bool
#  36  Company_Razer                391 non-null    bool
#  37  Company_Samsung              391 non-null    bool
#  38  Company_Toshiba              391 non-null    bool
#  39  Company_Vero                 391 non-null    bool
#  40  Company_Xiaomi               391 non-null    bool
#  41  TypeName_2 in 1 Convertible  391 non-null    bool
#  42  TypeName_Gaming              391 non-null    bool
#  43  TypeName_Netbook             391 non-null    bool
#  44  TypeName_Notebook            391 non-null    bool
#  45  TypeName_Ultrabook           391 non-null    bool
#  46  TypeName_Workstation         391 non-null    bool
#  47  OpSys_Android                391 non-null    int64
#  48  OpSys_Chrome OS              391 non-null    bool
#  49  OpSys_Linux                  391 non-null    bool
#  50  OpSys_Mac OS X               391 non-null    bool
#  51  OpSys_No OS                  391 non-null    bool
#  52  OpSys_Windows 10             391 non-null    bool
#  53  OpSys_Windows 10 S           391 non-null    bool
#  54  OpSys_Windows 7              391 non-null    bool
#  55  OpSys_macOS                  391 non-null    bool
# dtypes: bool(43), float64(4), int32(1), int64(8)
# memory usage: 54.7 KB

# %%
X_train_improved.head()
# Out:
#    Inches  Ram  Weight  Resolution  Memory_SSD  Memory_HDD  Flash_Storage  \
# 0    12.5    4    1.20   2073600.0           0           0              1
# 1    17.3    8    3.20   2073600.0         256        1024              0
# 2    15.6    4    1.85   2073600.0           0        1024              0
# 3    13.3   16    1.29   5760000.0         512           0              0
# 4    15.6    4    2.32   2073600.0           0           0              0
#
#    Hybrid  Cpu_Cores  Cpu_Frequency  ...  TypeName_Workstation  OpSys_Android  \
# 0       0          0            0.9  ...                 False          False
# 1       0          0            3.2  ...                 False          False
# 2       0          0            2.7  ...                 False          False
# 3       0          0            2.5  ...                 False          False
# 4       1          0            2.5  ...                 False          False
#
#    OpSys_Chrome OS  OpSys_Linux  OpSys_Mac OS X  OpSys_No OS  \
# 0             True        False           False        False
# 1            False        False           False        False
# 2            False        False           False        False
# 3            False        False           False        False
# 4            False        False           False        False
#
#    OpSys_Windows 10  OpSys_Windows 10 S  OpSys_Windows 7  OpSys_macOS
# 0             False               False            False        False
# 1              True               False            False        False
# 2              True               False            False        False
# 3              True               False            False        False
# 4             False               False             True        False
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Definir modelos mas adecuados para predecir y evaluar su rendimiento

# %% [markdown]
# ## Predicciones y archivo salida

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 64 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           391 non-null    int64
#  1   laptop_ID                    391 non-null    int64
#  2   Company                      391 non-null    object
#  3   Product                      391 non-null    object
#  4   Inches                       391 non-null    float64
#  5   ScreenResolution             391 non-null    object
#  6   Ram                          391 non-null    int32
#  7   Gpu                          391 non-null    object
#  8   Weight                       391 non-null    float64
#  9   Resolution                   391 non-null    float64
#  10  Memory_SSD                   391 non-null    int64
#  11  Memory_HDD                   391 non-null    int64
#  12  Flash_Storage                391 non-null    int64
#  13  Hybrid                       391 non-null    int64
#  14  Cpu_Cores                    391 non-null    int64
#  15  Cpu_Frequency                391 non-null    float64
#  16  Cpu_Family_Intel             391 non-null    bool
#  17  Cpu_Family_Other             391 non-null    bool
#  18  Cpu_Series_i3                391 non-null    bool
#  19  Cpu_Series_i5                391 non-null    bool
#  20  Cpu_Series_i7                391 non-null    bool
#  21  Cpu_Series_ryzen 1           391 non-null    bool
#  22  Gpu_Model                    391 non-null    int64
#  23  Gpu_Brand_Intel              391 non-null    bool
#  24  Gpu_Brand_NVIDIA             391 non-null    bool
#  25  Gpu_Brand_Other              391 non-null    bool
#  26  Gpu_Family_gtx               391 non-null    bool
#  27  Gpu_Family_hd graphics       391 non-null    bool
#  28  Gpu_Family_iris              391 non-null    bool
#  29  Gpu_Family_radeon            391 non-null    bool
#  30  Company_Acer                 391 non-null    bool
#  31  Company_Apple                391 non-null    bool
#  32  Company_Asus                 391 non-null    bool
#  33  Company_Chuwi                391 non-null    bool
#  34  Company_Dell                 391 non-null    bool
#  35  Company_Fujitsu              391 non-null    bool
#  36  Company_Google               391 non-null    bool
#  37  Company_HP                   391 non-null    bool
#  38  Company_Huawei               391 non-null    int64
#  39  Company_LG                   391 non-null    bool
#  40  Company_Lenovo               391 non-null    bool
#  41  Company_MSI                  391 non-null    bool
#  42  Company_Mediacom             391 non-null    bool
#  43  Company_Microsoft            391 non-null    bool
#  44  Company_Razer                391 non-null    bool
#  45  Company_Samsung              391 non-null    bool
#  46  Company_Toshiba              391 non-null    bool
#  47  Company_Vero                 391 non-null    bool
#  48  Company_Xiaomi               391 non-null    bool
#  49  TypeName_2 in 1 Convertible  391 non-null    bool
#  50  TypeName_Gaming              391 non-null    bool
#  51  TypeName_Netbook             391 non-null    bool
#  52  TypeName_Notebook            391 non-null    bool
#  53  TypeName_Ultrabook           391 non-null    bool
#  54  TypeName_Workstation         391 non-null    bool
#  55  OpSys_Android                391 non-null    int64
#  56  OpSys_Chrome OS              391 non-null    bool
#  57  OpSys_Linux                  391 non-null    bool
#  58  OpSys_Mac OS X               391 non-null    bool
#  59  OpSys_No OS                  391 non-null    bool
#  60  OpSys_Windows 10             391 non-null    bool
#  61  OpSys_Windows 10 S           391 non-null    bool
#  62  OpSys_Windows 7              391 non-null    bool
#  63  OpSys_macOS                  391 non-null    bool
# dtypes: bool(45), float64(4), int32(1), int64(10), object(4)
# memory usage: 73.8+ KB

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
import numpy as np

# Configuración de preprocesamiento
numeric_features = X_train_improved.select_dtypes(include=['float64', 'int64']).columns
categorical_features = X_train_improved.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), numeric_features),
        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_features)
    ]
)

# Modelos base
elasticnet = ElasticNet(random_state=42)
gbr = GradientBoostingRegressor(random_state=42)

# Modelo combinado
stacking_model = StackingRegressor(
    estimators=[
        ('elasticnet', elasticnet),
        ('gbr', gbr)
    ],
    final_estimator=GradientBoostingRegressor(random_state=42)  # Modelo final
)

# Pipeline completo
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('stacking', stacking_model)
])

# Hiperparámetros para GridSearchCV
param_grid = {
    'stacking__elasticnet__alpha': [0.1, 0.5, 1.0],
    'stacking__elasticnet__l1_ratio': [0.2, 0.5, 0.8],
    'stacking__gbr__n_estimators': [100, 200],
    'stacking__gbr__learning_rate': [0.05, 0.1],
    'stacking__gbr__max_depth': [3, 6],
}

# Configurar GridSearchCV
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=2
)

# Entrenar el modelo
grid_search.fit(X_train_split, y_train_log)

# Evaluar el modelo
best_model = grid_search.best_estimator_
y_pred_log = best_model.predict(X_val_split)
y_pred = np.expm1(y_pred_log)  # Invertir la transformación logarítmica
mae = mean_absolute_error(y_val_split, y_pred)

print(f"Mejores parámetros: {grid_search.best_params_}")
print(f"MAE en validación: {mae}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Mejores parámetros: {'stacking__elasticnet__alpha': 0.1, 'stacking__elasticnet__l1_ratio': 0.2, 'stacking__gbr__learning_rate': 0.05, 'stacking__gbr__max_depth': 6, 'stacking__gbr__n_estimators': 200}
# MAE en validación: 237.5327958107249

# %%
# Predecir en el conjunto de prueba
y_pred_test_log = best_model.predict(X_test_improved)

# Invertir la transformación logarítmica para obtener los valores de precio originales
y_pred_test = np.expm1(y_pred_test_log)

if 'id' in test_df.columns:
    output_df = test_df[['id']].copy()
    output_df['Price_euros'] = y_pred_test
    output_df.to_csv('laptop_price_predictions.csv', index=False)
else:
    output_df = pd.DataFrame({
        'Price_euros': y_pred_test
    })
    output_df.to_csv('laptop_price_predictions.csv', index=False)

print("Archivo de predicciones guardado como laptop_price_predictions.csv")
# Out:
# Archivo de predicciones guardado como laptop_price_predictions.csv

# %%
# Predecir con el modelo entrenado
y_pred_log = best_model.predict(X_val_split)
y_pred = np.expm1(y_pred_log)  # Revertir la transformación logarítmica

# Calcular los errores
errors = y_val_split - y_pred
mae = mean_absolute_error(y_val_split, y_pred)
rmse = np.sqrt(mean_squared_error(y_val_split, y_pred))

# Mostrar métricas de error
print(f"MAE: {mae:.2f}")
print('MSE:', metrics.mean_squared_error(y_val_split, y_pred))
print(f"RMSE: {rmse:.2f}")

# Gráfico 1: Histograma de errores
plt.figure(figsize=(10, 6))
sns.histplot(errors, kde=True, bins=30, color='blue', alpha=0.6)
plt.title("Distribución de errores (y_val_split - y_pred)")
plt.xlabel("Error")
plt.ylabel("Frecuencia")
plt.axvline(x=0, color='red', linestyle='--', label='Sin error')
plt.legend()
plt.show()

# Gráfico 2: Valores predichos vs valores reales
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_val_split, y=y_pred, alpha=0.6, color='green')
plt.plot([y_val_split.min(), y_val_split.max()], [y_val_split.min(), y_val_split.max()], color='red', linestyle='--', label='Perfecto ajuste')
plt.title("Valores Predichos vs Reales")
plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.legend()
plt.show()

# Gráfico 3: Gráfico de dispersión de errores
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_val_split, y=errors, alpha=0.6, color='orange')
plt.axhline(y=0, color='red', linestyle='--', label='Sin error')
plt.title("Errores vs Valores Reales")
plt.xlabel("Valores Reales")
plt.ylabel("Errores")
plt.legend()
plt.show()
# Out:
# MAE: 166.05
# MSE: 66137.15597157374
# RMSE: 257.17
