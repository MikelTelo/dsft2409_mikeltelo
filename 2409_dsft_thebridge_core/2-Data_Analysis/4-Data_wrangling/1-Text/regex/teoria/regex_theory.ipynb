# %% [markdown]
# # REGEX
# ## (Regular Expressions)
# ![](img/regex_cover.png)
#
# Los datos no siempre están organizados, formateados ni estructurados de forma homogénea.
#
# Una parte importante del trabajo de un _Data Scientist_ consiste en limpiar los datos **(Data Cleaning)**
#
# Para ello, existen técnicas como **Regex**
#
# Las expresiones regulares están conformadas por secuencias de caracteres que nos permiten encontrar patrones de búsqueda.
#
# # [¡VAMOS A ELLO!](https://regex101.com/)

# %% [markdown]
# Puedes ayudarte con los siguientes enlaces [RegEx101](https://regex101.com/) y [RegEx Python guide](https://docs.python.org/3/howto/regex.html)

# %%
import re

text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890
Ha HaHa ?Ha
MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )
hegoigaritaonandia*com
hegoigaritaonandia.com
hegoigaritaonandiacom
hegoigaritaonandia hola
321--555-4321
123.555.1234
123*555*1234
800-555-1234
900-555-1234
9005551234
900055501234
Mr. Scha2fer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
Mr. ()

cat
mat
pat
bat 
at
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Utilizamos las raw_strings para obtener la literalidad del texto:
#
# ### `print(r'\tTabulador')`

# %%
print('Tabulador sin raw string: \tTabulador')
print(r'Tabulador con raw string: \tTabulador')
# Out:
# Tabulador sin raw string: 	Tabulador
# Tabulador con raw string: \tTabulador

# %% [markdown]
# ### Buscamos el patrón `abc` en el texto
#
# Para ello utilizamos:
# - `re.compile()`: para introducir el patrón que queremos buscar
# - La función `finditer()`: para buscar el patrón en nuestro texto
# - Iteramos sobre la búsqueda

# %%
mi_string = 'Hola mundo'
mi_string[0]
# Out:
# 'H'

# %%
pattern = re.compile(r'abc')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(1, 4), match='abc'>
# Match found: abc at positions 1-4

# %% [markdown]
# ### Hay que tener en cuenta que cuando específicamos el pattern, se busca la literalidad de ese patrón.
# Por ejemplo, si queremos buscar las letras en distinto orden...

# %%
new_pattern = re.compile(r'cba')
new_matches = new_pattern.finditer(text_to_search)

for match in new_matches:
    print(match) # no se muestra nada por pantalla 
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")

# %% [markdown]
# ## Metacaracteres
# Son aquellos caracteres que no son alfanuméricos:
# - Signos de puntuación, exclamación y admiración
#
# Si queremos obtenerlos, tenemos que "escaparlos"

# %%
# Como veis, aquí se muestran prácticamente todos los caracteres.
pattern = re.compile('.')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='u'>
# <re.Match object; span=(19, 20), match='r'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# <re.Match object; span=(23, 24), match='w'>
# <re.Match object; span=(24, 25), match='x'>
# <re.Match object; span=(25, 26), match='y'>
# <re.Match object; span=(26, 27), match='z'>
# <re.Match object; span=(28, 29), match='A'>
# <re.Match object; span=(29, 30), match='B'>
# <re.Match object; span=(30, 31), match='C'>
# <re.Match object; span=(31, 32), match='D'>
# <re.Match object; span=(32, 33), match='E'>
# <re.Match object; span=(33, 34), match='F'>
# <re.Match object; span=(34, 35), match='G'>
# <re.Match object; span=(35, 36), match='H'>
# <re.Match object; span=(36, 37), match='I'>
# <re.Match object; span=(37, 38), match='J'>
# <re.Match object; span=(38, 39), match='K'>
# <re.Match object; span=(39, 40), match='L'>
# <re.Match object; span=(40, 41), match='M'>
# <re.Match object; span=(41, 42), match='N'>
# <re.Match object; span=(42, 43), match='O'>
# <re.Match object; span=(43, 44), match='P'>
# <re.Match object; span=(44, 45), match='Q'>
# <re.Match object; span=(45, 46), match='R'>
# <re.Match object; span=(46, 47), match='S'>
# <re.Match object; span=(47, 48), match='T'>
# <re.Match object; span=(48, 49), match='U'>
# <re.Match object; span=(49, 50), match='V'>
# <re.Match object; span=(50, 51), match='W'>
# <re.Match object; span=(51, 52), match='X'>
# <re.Match object; span=(52, 53), match='Y'>
# <re.Match object; span=(53, 54), match='Z'>
# <re.Match object; span=(55, 56), match='1'>
# <re.Match object; span=(56, 57), match='2'>
# <re.Match object; span=(57, 58), match='3'>
# <re.Match object; span=(58, 59), match='4'>
# <re.Match object; span=(59, 60), match='5'>
# <re.Match object; span=(60, 61), match='6'>
# <re.Match object; span=(61, 62), match='7'>
# <re.Match object; span=(62, 63), match='8'>
# <re.Match object; span=(63, 64), match='9'>
# <re.Match object; span=(64, 65), match='0'>
# <re.Match object; span=(66, 67), match='H'>
# <re.Match object; span=(67, 68), match='a'>
# <re.Match object; span=(68, 69), match=' '>
# <re.Match object; span=(69, 70), match='H'>
# <re.Match object; span=(70, 71), match='a'>
# <re.Match object; span=(71, 72), match='H'>
# <re.Match object; span=(72, 73), match='a'>
# <re.Match object; span=(73, 74), match=' '>
# <re.Match object; span=(74, 75), match='?'>
# <re.Match object; span=(75, 76), match='H'>
# <re.Match object; span=(76, 77), match='a'>
# <re.Match object; span=(78, 79), match='M'>
# <re.Match object; span=(79, 80), match='e'>
# <re.Match object; span=(80, 81), match='t'>
# <re.Match object; span=(81, 82), match='a'>
# <re.Match object; span=(82, 83), match='C'>
# <re.Match object; span=(83, 84), match='h'>
# <re.Match object; span=(84, 85), match='a'>
# <re.Match object; span=(85, 86), match='r'>
# <re.Match object; span=(86, 87), match='a'>
# <re.Match object; span=(87, 88), match='c'>
# <re.Match object; span=(88, 89), match='t'>
# <re.Match object; span=(89, 90), match='e'>
# <re.Match object; span=(90, 91), match='r'>
# <re.Match object; span=(91, 92), match='s'>
# <re.Match object; span=(92, 93), match=' '>
# <re.Match object; span=(93, 94), match='('>
# <re.Match object; span=(94, 95), match='N'>
# <re.Match object; span=(95, 96), match='e'>
# <re.Match object; span=(96, 97), match='e'>
# <re.Match object; span=(97, 98), match='d'>
# <re.Match object; span=(98, 99), match=' '>
# <re.Match object; span=(99, 100), match='t'>
# <re.Match object; span=(100, 101), match='o'>
# <re.Match object; span=(101, 102), match=' '>
# <re.Match object; span=(102, 103), match='b'>
# <re.Match object; span=(103, 104), match='e'>
# <re.Match object; span=(104, 105), match=' '>
# <re.Match object; span=(105, 106), match='e'>
# <re.Match object; span=(106, 107), match='s'>
# <re.Match object; span=(107, 108), match='c'>
# <re.Match object; span=(108, 109), match='a'>
# <re.Match object; span=(109, 110), match='p'>
# <re.Match object; span=(110, 111), match='e'>
# <re.Match object; span=(111, 112), match='d'>
# <re.Match object; span=(112, 113), match=')'>
# <re.Match object; span=(113, 114), match=':'>
# <re.Match object; span=(115, 116), match='.'>
# <re.Match object; span=(116, 117), match=' '>
# <re.Match object; span=(117, 118), match='^'>
# <re.Match object; span=(118, 119), match=' '>
# <re.Match object; span=(119, 120), match='$'>
# <re.Match object; span=(120, 121), match=' '>
# <re.Match object; span=(121, 122), match='*'>
# <re.Match object; span=(122, 123), match=' '>
# <re.Match object; span=(123, 124), match='+'>
# <re.Match object; span=(124, 125), match=' '>
# <re.Match object; span=(125, 126), match='?'>
# <re.Match object; span=(126, 127), match=' '>
# <re.Match object; span=(127, 128), match='{'>
# <re.Match object; span=(128, 129), match=' '>
# <re.Match object; span=(129, 130), match='}'>
# <re.Match object; span=(130, 131), match=' '>
# <re.Match object; span=(131, 132), match='['>
# <re.Match object; span=(132, 133), match=' '>
# <re.Match object; span=(133, 134), match=']'>
# <re.Match object; span=(134, 135), match=' '>
# <re.Match object; span=(135, 136), match='\\'>
# <re.Match object; span=(136, 137), match=' '>
# <re.Match object; span=(137, 138), match='|'>
# <re.Match object; span=(138, 139), match=' '>
# <re.Match object; span=(139, 140), match='('>
# <re.Match object; span=(140, 141), match=' '>
# <re.Match object; span=(141, 142), match=')'>
# <re.Match object; span=(143, 144), match='h'>
# <re.Match object; span=(144, 145), match='e'>
# <re.Match object; span=(145, 146), match='g'>
# <re.Match object; span=(146, 147), match='o'>
# <re.Match object; span=(147, 148), match='i'>
# <re.Match object; span=(148, 149), match='g'>
# <re.Match object; span=(149, 150), match='a'>
# <re.Match object; span=(150, 151), match='r'>
# <re.Match object; span=(151, 152), match='i'>
# <re.Match object; span=(152, 153), match='t'>
# <re.Match object; span=(153, 154), match='a'>
# <re.Match object; span=(154, 155), match='o'>
# <re.Match object; span=(155, 156), match='n'>
# <re.Match object; span=(156, 157), match='a'>
# <re.Match object; span=(157, 158), match='n'>
# <re.Match object; span=(158, 159), match='d'>
# <re.Match object; span=(159, 160), match='i'>
# <re.Match object; span=(160, 161), match='a'>
# <re.Match object; span=(161, 162), match='*'>
# <re.Match object; span=(162, 163), match='c'>
# <re.Match object; span=(163, 164), match='o'>
# <re.Match object; span=(164, 165), match='m'>
# <re.Match object; span=(166, 167), match='h'>
# <re.Match object; span=(167, 168), match='e'>
# <re.Match object; span=(168, 169), match='g'>
# <re.Match object; span=(169, 170), match='o'>
# <re.Match object; span=(170, 171), match='i'>
# <re.Match object; span=(171, 172), match='g'>
# <re.Match object; span=(172, 173), match='a'>
# <re.Match object; span=(173, 174), match='r'>
# <re.Match object; span=(174, 175), match='i'>
# <re.Match object; span=(175, 176), match='t'>
# <re.Match object; span=(176, 177), match='a'>
# <re.Match object; span=(177, 178), match='o'>
# <re.Match object; span=(178, 179), match='n'>
# <re.Match object; span=(179, 180), match='a'>
# <re.Match object; span=(180, 181), match='n'>
# <re.Match object; span=(181, 182), match='d'>
# <re.Match object; span=(182, 183), match='i'>
# <re.Match object; span=(183, 184), match='a'>
# <re.Match object; span=(184, 185), match='.'>
# <re.Match object; span=(185, 186), match='c'>
# <re.Match object; span=(186, 187), match='o'>
# <re.Match object; span=(187, 188), match='m'>
# <re.Match object; span=(189, 190), match='h'>
# <re.Match object; span=(190, 191), match='e'>
# <re.Match object; span=(191, 192), match='g'>
# <re.Match object; span=(192, 193), match='o'>
# <re.Match object; span=(193, 194), match='i'>
# <re.Match object; span=(194, 195), match='g'>
# <re.Match object; span=(195, 196), match='a'>
# <re.Match object; span=(196, 197), match='r'>
# <re.Match object; span=(197, 198), match='i'>
# <re.Match object; span=(198, 199), match='t'>
# <re.Match object; span=(199, 200), match='a'>
# <re.Match object; span=(200, 201), match='o'>
# <re.Match object; span=(201, 202), match='n'>
# <re.Match object; span=(202, 203), match='a'>
# <re.Match object; span=(203, 204), match='n'>
# <re.Match object; span=(204, 205), match='d'>
# <re.Match object; span=(205, 206), match='i'>
# <re.Match object; span=(206, 207), match='a'>
# <re.Match object; span=(207, 208), match='c'>
# <re.Match object; span=(208, 209), match='o'>
# <re.Match object; span=(209, 210), match='m'>
# <re.Match object; span=(211, 212), match='h'>
# <re.Match object; span=(212, 213), match='e'>
# <re.Match object; span=(213, 214), match='g'>
# <re.Match object; span=(214, 215), match='o'>
# <re.Match object; span=(215, 216), match='i'>
# <re.Match object; span=(216, 217), match='g'>
# <re.Match object; span=(217, 218), match='a'>
# <re.Match object; span=(218, 219), match='r'>
# <re.Match object; span=(219, 220), match='i'>
# <re.Match object; span=(220, 221), match='t'>
# <re.Match object; span=(221, 222), match='a'>
# <re.Match object; span=(222, 223), match='o'>
# <re.Match object; span=(223, 224), match='n'>
# <re.Match object; span=(224, 225), match='a'>
# <re.Match object; span=(225, 226), match='n'>
# <re.Match object; span=(226, 227), match='d'>
# <re.Match object; span=(227, 228), match='i'>
# <re.Match object; span=(228, 229), match='a'>
# <re.Match object; span=(229, 230), match=' '>
# <re.Match object; span=(230, 231), match='h'>
# <re.Match object; span=(231, 232), match='o'>
# <re.Match object; span=(232, 233), match='l'>
# <re.Match object; span=(233, 234), match='a'>
# <re.Match object; span=(235, 236), match='3'>
# <re.Match object; span=(236, 237), match='2'>
# <re.Match object; span=(237, 238), match='1'>
# <re.Match object; span=(238, 239), match='-'>
# <re.Match object; span=(239, 240), match='-'>
# <re.Match object; span=(240, 241), match='5'>
# <re.Match object; span=(241, 242), match='5'>
# <re.Match object; span=(242, 243), match='5'>
# <re.Match object; span=(243, 244), match='-'>
# <re.Match object; span=(244, 245), match='4'>
# <re.Match object; span=(245, 246), match='3'>
# <re.Match object; span=(246, 247), match='2'>
# <re.Match object; span=(247, 248), match='1'>
# <re.Match object; span=(249, 250), match='1'>
# <re.Match object; span=(250, 251), match='2'>
# <re.Match object; span=(251, 252), match='3'>
# <re.Match object; span=(252, 253), match='.'>
# <re.Match object; span=(253, 254), match='5'>
# <re.Match object; span=(254, 255), match='5'>
# <re.Match object; span=(255, 256), match='5'>
# <re.Match object; span=(256, 257), match='.'>
# <re.Match object; span=(257, 258), match='1'>
# <re.Match object; span=(258, 259), match='2'>
# <re.Match object; span=(259, 260), match='3'>
# <re.Match object; span=(260, 261), match='4'>
# <re.Match object; span=(262, 263), match='1'>
# <re.Match object; span=(263, 264), match='2'>
# <re.Match object; span=(264, 265), match='3'>
# <re.Match object; span=(265, 266), match='*'>
# <re.Match object; span=(266, 267), match='5'>
# <re.Match object; span=(267, 268), match='5'>
# <re.Match object; span=(268, 269), match='5'>
# <re.Match object; span=(269, 270), match='*'>
# <re.Match object; span=(270, 271), match='1'>
# <re.Match object; span=(271, 272), match='2'>
# <re.Match object; span=(272, 273), match='3'>
# <re.Match object; span=(273, 274), match='4'>
# <re.Match object; span=(275, 276), match='8'>
# <re.Match object; span=(276, 277), match='0'>
# <re.Match object; span=(277, 278), match='0'>
# <re.Match object; span=(278, 279), match='-'>
# <re.Match object; span=(279, 280), match='5'>
# <re.Match object; span=(280, 281), match='5'>
# <re.Match object; span=(281, 282), match='5'>
# <re.Match object; span=(282, 283), match='-'>
# <re.Match object; span=(283, 284), match='1'>
# <re.Match object; span=(284, 285), match='2'>
# <re.Match object; span=(285, 286), match='3'>
# <re.Match object; span=(286, 287), match='4'>
# <re.Match object; span=(288, 289), match='9'>
# <re.Match object; span=(289, 290), match='0'>
# <re.Match object; span=(290, 291), match='0'>
# <re.Match object; span=(291, 292), match='-'>
# <re.Match object; span=(292, 293), match='5'>
# <re.Match object; span=(293, 294), match='5'>
# <re.Match object; span=(294, 295), match='5'>
# <re.Match object; span=(295, 296), match='-'>
# <re.Match object; span=(296, 297), match='1'>
# <re.Match object; span=(297, 298), match='2'>
# <re.Match object; span=(298, 299), match='3'>
# <re.Match object; span=(299, 300), match='4'>
# <re.Match object; span=(301, 302), match='9'>
# <re.Match object; span=(302, 303), match='0'>
# <re.Match object; span=(303, 304), match='0'>
# <re.Match object; span=(304, 305), match='5'>
# <re.Match object; span=(305, 306), match='5'>
# <re.Match object; span=(306, 307), match='5'>
# <re.Match object; span=(307, 308), match='1'>
# <re.Match object; span=(308, 309), match='2'>
# <re.Match object; span=(309, 310), match='3'>
# <re.Match object; span=(310, 311), match='4'>
# <re.Match object; span=(312, 313), match='9'>
# <re.Match object; span=(313, 314), match='0'>
# <re.Match object; span=(314, 315), match='0'>
# <re.Match object; span=(315, 316), match='0'>
# <re.Match object; span=(316, 317), match='5'>
# <re.Match object; span=(317, 318), match='5'>
# <re.Match object; span=(318, 319), match='5'>
# <re.Match object; span=(319, 320), match='0'>
# <re.Match object; span=(320, 321), match='1'>
# <re.Match object; span=(321, 322), match='2'>
# <re.Match object; span=(322, 323), match='3'>
# <re.Match object; span=(323, 324), match='4'>
# <re.Match object; span=(325, 326), match='M'>
# <re.Match object; span=(326, 327), match='r'>
# <re.Match object; span=(327, 328), match='.'>
# <re.Match object; span=(328, 329), match=' '>
# <re.Match object; span=(329, 330), match='S'>
# <re.Match object; span=(330, 331), match='c'>
# <re.Match object; span=(331, 332), match='h'>
# <re.Match object; span=(332, 333), match='a'>
# <re.Match object; span=(333, 334), match='2'>
# <re.Match object; span=(334, 335), match='f'>
# <re.Match object; span=(335, 336), match='e'>
# <re.Match object; span=(336, 337), match='r'>
# <re.Match object; span=(338, 339), match='M'>
# <re.Match object; span=(339, 340), match='r'>
# <re.Match object; span=(340, 341), match=' '>
# <re.Match object; span=(341, 342), match='S'>
# <re.Match object; span=(342, 343), match='m'>
# <re.Match object; span=(343, 344), match='i'>
# <re.Match object; span=(344, 345), match='t'>
# <re.Match object; span=(345, 346), match='h'>
# <re.Match object; span=(347, 348), match='M'>
# <re.Match object; span=(348, 349), match='s'>
# <re.Match object; span=(349, 350), match=' '>
# <re.Match object; span=(350, 351), match='D'>
# <re.Match object; span=(351, 352), match='a'>
# <re.Match object; span=(352, 353), match='v'>
# <re.Match object; span=(353, 354), match='i'>
# <re.Match object; span=(354, 355), match='s'>
# <re.Match object; span=(356, 357), match='M'>
# <re.Match object; span=(357, 358), match='r'>
# <re.Match object; span=(358, 359), match='s'>
# <re.Match object; span=(359, 360), match='.'>
# <re.Match object; span=(360, 361), match=' '>
# <re.Match object; span=(361, 362), match='R'>
# <re.Match object; span=(362, 363), match='o'>
# <re.Match object; span=(363, 364), match='b'>
# <re.Match object; span=(364, 365), match='i'>
# <re.Match object; span=(365, 366), match='n'>
# <re.Match object; span=(366, 367), match='s'>
# <re.Match object; span=(367, 368), match='o'>
# <re.Match object; span=(368, 369), match='n'>
# <re.Match object; span=(370, 371), match='M'>
# <re.Match object; span=(371, 372), match='r'>
# <re.Match object; span=(372, 373), match='.'>
# <re.Match object; span=(373, 374), match=' '>
# <re.Match object; span=(374, 375), match='T'>
# <re.Match object; span=(376, 377), match='M'>
# <re.Match object; span=(377, 378), match='r'>
# <re.Match object; span=(378, 379), match='.'>
# <re.Match object; span=(379, 380), match=' '>
# <re.Match object; span=(380, 381), match='('>
# <re.Match object; span=(381, 382), match=')'>
# <re.Match object; span=(384, 385), match='c'>
# <re.Match object; span=(385, 386), match='a'>
# <re.Match object; span=(386, 387), match='t'>
# <re.Match object; span=(388, 389), match='m'>
# <re.Match object; span=(389, 390), match='a'>
# <re.Match object; span=(390, 391), match='t'>
# <re.Match object; span=(392, 393), match='p'>
# <re.Match object; span=(393, 394), match='a'>
# <re.Match object; span=(394, 395), match='t'>
# <re.Match object; span=(396, 397), match='b'>
# <re.Match object; span=(397, 398), match='a'>
# <re.Match object; span=(398, 399), match='t'>
# <re.Match object; span=(399, 400), match=' '>
# <re.Match object; span=(401, 402), match='a'>
# <re.Match object; span=(402, 403), match='t'>

# %% [markdown]
# #### Para escaparlos, tienen que ir precedidos de la barra invertida(`\`)

# %%
pattern = re.compile('\.')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(115, 116), match='.'>
# Match found: . at positions 115-116
# <re.Match object; span=(184, 185), match='.'>
# Match found: . at positions 184-185
# <re.Match object; span=(252, 253), match='.'>
# Match found: . at positions 252-253
# <re.Match object; span=(256, 257), match='.'>
# Match found: . at positions 256-257
# <re.Match object; span=(327, 328), match='.'>
# Match found: . at positions 327-328
# <re.Match object; span=(359, 360), match='.'>
# Match found: . at positions 359-360
# <re.Match object; span=(372, 373), match='.'>
# Match found: . at positions 372-373
# <re.Match object; span=(378, 379), match='.'>
# Match found: . at positions 378-379

# %% [markdown]
# Para buscar una página web:

# %%
pattern = re.compile(r'hegoigaritaonandia\.com')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(166, 188), match='hegoigaritaonandia.com'>
# Match found: hegoigaritaonandia.com at positions 166-188

# %% [markdown]
# Lo realmente interesante de regex no es encontrar simplemente una página web o una frase concreta, sino que nos ayuda a encontrar una serie de patrones en los textos.
#
# En este documento podemos ver las principales expresiones regulares para encontrar texto: `snippets.txt`

# %%
pattern = re.compile(r'\S') # matches any non-whitespace character

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(1, 2), match='a'>
# Match found: a at positions 1-2
# <re.Match object; span=(2, 3), match='b'>
# Match found: b at positions 2-3
# <re.Match object; span=(3, 4), match='c'>
# Match found: c at positions 3-4
# <re.Match object; span=(4, 5), match='d'>
# Match found: d at positions 4-5
# <re.Match object; span=(5, 6), match='e'>
# Match found: e at positions 5-6
# <re.Match object; span=(6, 7), match='f'>
# Match found: f at positions 6-7
# <re.Match object; span=(7, 8), match='g'>
# Match found: g at positions 7-8
# <re.Match object; span=(8, 9), match='h'>
# Match found: h at positions 8-9
# <re.Match object; span=(9, 10), match='i'>
# Match found: i at positions 9-10
# <re.Match object; span=(10, 11), match='j'>
# Match found: j at positions 10-11
# <re.Match object; span=(11, 12), match='k'>
# Match found: k at positions 11-12
# <re.Match object; span=(12, 13), match='l'>
# Match found: l at positions 12-13
# <re.Match object; span=(13, 14), match='m'>
# Match found: m at positions 13-14
# <re.Match object; span=(14, 15), match='n'>
# Match found: n at positions 14-15
# <re.Match object; span=(15, 16), match='o'>
# Match found: o at positions 15-16
# <re.Match object; span=(16, 17), match='p'>
# Match found: p at positions 16-17
# <re.Match object; span=(17, 18), match='q'>
# Match found: q at positions 17-18
# <re.Match object; span=(18, 19), match='u'>
# Match found: u at positions 18-19
# <re.Match object; span=(19, 20), match='r'>
# Match found: r at positions 19-20
# <re.Match object; span=(20, 21), match='t'>
# Match found: t at positions 20-21
# <re.Match object; span=(21, 22), match='u'>
# Match found: u at positions 21-22
# <re.Match object; span=(22, 23), match='v'>
# Match found: v at positions 22-23
# <re.Match object; span=(23, 24), match='w'>
# Match found: w at positions 23-24
# <re.Match object; span=(24, 25), match='x'>
# Match found: x at positions 24-25
# <re.Match object; span=(25, 26), match='y'>
# Match found: y at positions 25-26
# <re.Match object; span=(26, 27), match='z'>
# Match found: z at positions 26-27
# <re.Match object; span=(28, 29), match='A'>
# Match found: A at positions 28-29
# <re.Match object; span=(29, 30), match='B'>
# Match found: B at positions 29-30
# <re.Match object; span=(30, 31), match='C'>
# Match found: C at positions 30-31
# <re.Match object; span=(31, 32), match='D'>
# Match found: D at positions 31-32
# <re.Match object; span=(32, 33), match='E'>
# Match found: E at positions 32-33
# <re.Match object; span=(33, 34), match='F'>
# Match found: F at positions 33-34
# <re.Match object; span=(34, 35), match='G'>
# Match found: G at positions 34-35
# <re.Match object; span=(35, 36), match='H'>
# Match found: H at positions 35-36
# <re.Match object; span=(36, 37), match='I'>
# Match found: I at positions 36-37
# <re.Match object; span=(37, 38), match='J'>
# Match found: J at positions 37-38
# <re.Match object; span=(38, 39), match='K'>
# Match found: K at positions 38-39
# <re.Match object; span=(39, 40), match='L'>
# Match found: L at positions 39-40
# <re.Match object; span=(40, 41), match='M'>
# Match found: M at positions 40-41
# <re.Match object; span=(41, 42), match='N'>
# Match found: N at positions 41-42
# <re.Match object; span=(42, 43), match='O'>
# Match found: O at positions 42-43
# <re.Match object; span=(43, 44), match='P'>
# Match found: P at positions 43-44
# <re.Match object; span=(44, 45), match='Q'>
# Match found: Q at positions 44-45
# <re.Match object; span=(45, 46), match='R'>
# Match found: R at positions 45-46
# <re.Match object; span=(46, 47), match='S'>
# Match found: S at positions 46-47
# <re.Match object; span=(47, 48), match='T'>
# Match found: T at positions 47-48
# <re.Match object; span=(48, 49), match='U'>
# Match found: U at positions 48-49
# <re.Match object; span=(49, 50), match='V'>
# Match found: V at positions 49-50
# <re.Match object; span=(50, 51), match='W'>
# Match found: W at positions 50-51
# <re.Match object; span=(51, 52), match='X'>
# Match found: X at positions 51-52
# <re.Match object; span=(52, 53), match='Y'>
# Match found: Y at positions 52-53
# <re.Match object; span=(53, 54), match='Z'>
# Match found: Z at positions 53-54
# <re.Match object; span=(55, 56), match='1'>
# Match found: 1 at positions 55-56
# <re.Match object; span=(56, 57), match='2'>
# Match found: 2 at positions 56-57
# <re.Match object; span=(57, 58), match='3'>
# Match found: 3 at positions 57-58
# <re.Match object; span=(58, 59), match='4'>
# Match found: 4 at positions 58-59
# <re.Match object; span=(59, 60), match='5'>
# Match found: 5 at positions 59-60
# <re.Match object; span=(60, 61), match='6'>
# Match found: 6 at positions 60-61
# <re.Match object; span=(61, 62), match='7'>
# Match found: 7 at positions 61-62
# <re.Match object; span=(62, 63), match='8'>
# Match found: 8 at positions 62-63
# <re.Match object; span=(63, 64), match='9'>
# Match found: 9 at positions 63-64
# <re.Match object; span=(64, 65), match='0'>
# Match found: 0 at positions 64-65
# <re.Match object; span=(66, 67), match='H'>
# Match found: H at positions 66-67
# <re.Match object; span=(67, 68), match='a'>
# Match found: a at positions 67-68
# <re.Match object; span=(69, 70), match='H'>
# Match found: H at positions 69-70
# <re.Match object; span=(70, 71), match='a'>
# Match found: a at positions 70-71
# <re.Match object; span=(71, 72), match='H'>
# Match found: H at positions 71-72
# <re.Match object; span=(72, 73), match='a'>
# Match found: a at positions 72-73
# <re.Match object; span=(74, 75), match='?'>
# Match found: ? at positions 74-75
# <re.Match object; span=(75, 76), match='H'>
# Match found: H at positions 75-76
# <re.Match object; span=(76, 77), match='a'>
# Match found: a at positions 76-77
# <re.Match object; span=(78, 79), match='M'>
# Match found: M at positions 78-79
# <re.Match object; span=(79, 80), match='e'>
# Match found: e at positions 79-80
# <re.Match object; span=(80, 81), match='t'>
# Match found: t at positions 80-81
# <re.Match object; span=(81, 82), match='a'>
# Match found: a at positions 81-82
# <re.Match object; span=(82, 83), match='C'>
# Match found: C at positions 82-83
# <re.Match object; span=(83, 84), match='h'>
# Match found: h at positions 83-84
# <re.Match object; span=(84, 85), match='a'>
# Match found: a at positions 84-85
# <re.Match object; span=(85, 86), match='r'>
# Match found: r at positions 85-86
# <re.Match object; span=(86, 87), match='a'>
# Match found: a at positions 86-87
# <re.Match object; span=(87, 88), match='c'>
# Match found: c at positions 87-88
# <re.Match object; span=(88, 89), match='t'>
# Match found: t at positions 88-89
# <re.Match object; span=(89, 90), match='e'>
# Match found: e at positions 89-90
# <re.Match object; span=(90, 91), match='r'>
# Match found: r at positions 90-91
# <re.Match object; span=(91, 92), match='s'>
# Match found: s at positions 91-92
# <re.Match object; span=(93, 94), match='('>
# Match found: ( at positions 93-94
# <re.Match object; span=(94, 95), match='N'>
# Match found: N at positions 94-95
# <re.Match object; span=(95, 96), match='e'>
# Match found: e at positions 95-96
# <re.Match object; span=(96, 97), match='e'>
# Match found: e at positions 96-97
# <re.Match object; span=(97, 98), match='d'>
# Match found: d at positions 97-98
# <re.Match object; span=(99, 100), match='t'>
# Match found: t at positions 99-100
# <re.Match object; span=(100, 101), match='o'>
# Match found: o at positions 100-101
# <re.Match object; span=(102, 103), match='b'>
# Match found: b at positions 102-103
# <re.Match object; span=(103, 104), match='e'>
# Match found: e at positions 103-104
# <re.Match object; span=(105, 106), match='e'>
# Match found: e at positions 105-106
# <re.Match object; span=(106, 107), match='s'>
# Match found: s at positions 106-107
# <re.Match object; span=(107, 108), match='c'>
# Match found: c at positions 107-108
# <re.Match object; span=(108, 109), match='a'>
# Match found: a at positions 108-109
# <re.Match object; span=(109, 110), match='p'>
# Match found: p at positions 109-110
# <re.Match object; span=(110, 111), match='e'>
# Match found: e at positions 110-111
# <re.Match object; span=(111, 112), match='d'>
# Match found: d at positions 111-112
# <re.Match object; span=(112, 113), match=')'>
# Match found: ) at positions 112-113
# <re.Match object; span=(113, 114), match=':'>
# Match found: : at positions 113-114
# <re.Match object; span=(115, 116), match='.'>
# Match found: . at positions 115-116
# <re.Match object; span=(117, 118), match='^'>
# Match found: ^ at positions 117-118
# <re.Match object; span=(119, 120), match='$'>
# Match found: $ at positions 119-120
# <re.Match object; span=(121, 122), match='*'>
# Match found: * at positions 121-122
# <re.Match object; span=(123, 124), match='+'>
# Match found: + at positions 123-124
# <re.Match object; span=(125, 126), match='?'>
# Match found: ? at positions 125-126
# <re.Match object; span=(127, 128), match='{'>
# Match found: { at positions 127-128
# <re.Match object; span=(129, 130), match='}'>
# Match found: } at positions 129-130
# <re.Match object; span=(131, 132), match='['>
# Match found: [ at positions 131-132
# <re.Match object; span=(133, 134), match=']'>
# Match found: ] at positions 133-134
# <re.Match object; span=(135, 136), match='\\'>
# Match found: \ at positions 135-136
# <re.Match object; span=(137, 138), match='|'>
# Match found: | at positions 137-138
# <re.Match object; span=(139, 140), match='('>
# Match found: ( at positions 139-140
# <re.Match object; span=(141, 142), match=')'>
# Match found: ) at positions 141-142
# <re.Match object; span=(143, 144), match='h'>
# Match found: h at positions 143-144
# <re.Match object; span=(144, 145), match='e'>
# Match found: e at positions 144-145
# <re.Match object; span=(145, 146), match='g'>
# Match found: g at positions 145-146
# <re.Match object; span=(146, 147), match='o'>
# Match found: o at positions 146-147
# <re.Match object; span=(147, 148), match='i'>
# Match found: i at positions 147-148
# <re.Match object; span=(148, 149), match='g'>
# Match found: g at positions 148-149
# <re.Match object; span=(149, 150), match='a'>
# Match found: a at positions 149-150
# <re.Match object; span=(150, 151), match='r'>
# Match found: r at positions 150-151
# <re.Match object; span=(151, 152), match='i'>
# Match found: i at positions 151-152
# <re.Match object; span=(152, 153), match='t'>
# Match found: t at positions 152-153
# <re.Match object; span=(153, 154), match='a'>
# Match found: a at positions 153-154
# <re.Match object; span=(154, 155), match='o'>
# Match found: o at positions 154-155
# <re.Match object; span=(155, 156), match='n'>
# Match found: n at positions 155-156
# <re.Match object; span=(156, 157), match='a'>
# Match found: a at positions 156-157
# <re.Match object; span=(157, 158), match='n'>
# Match found: n at positions 157-158
# <re.Match object; span=(158, 159), match='d'>
# Match found: d at positions 158-159
# <re.Match object; span=(159, 160), match='i'>
# Match found: i at positions 159-160
# <re.Match object; span=(160, 161), match='a'>
# Match found: a at positions 160-161
# <re.Match object; span=(161, 162), match='*'>
# Match found: * at positions 161-162
# <re.Match object; span=(162, 163), match='c'>
# Match found: c at positions 162-163
# <re.Match object; span=(163, 164), match='o'>
# Match found: o at positions 163-164
# <re.Match object; span=(164, 165), match='m'>
# Match found: m at positions 164-165
# <re.Match object; span=(166, 167), match='h'>
# Match found: h at positions 166-167
# <re.Match object; span=(167, 168), match='e'>
# Match found: e at positions 167-168
# <re.Match object; span=(168, 169), match='g'>
# Match found: g at positions 168-169
# <re.Match object; span=(169, 170), match='o'>
# Match found: o at positions 169-170
# <re.Match object; span=(170, 171), match='i'>
# Match found: i at positions 170-171
# <re.Match object; span=(171, 172), match='g'>
# Match found: g at positions 171-172
# <re.Match object; span=(172, 173), match='a'>
# Match found: a at positions 172-173
# <re.Match object; span=(173, 174), match='r'>
# Match found: r at positions 173-174
# <re.Match object; span=(174, 175), match='i'>
# Match found: i at positions 174-175
# <re.Match object; span=(175, 176), match='t'>
# Match found: t at positions 175-176
# <re.Match object; span=(176, 177), match='a'>
# Match found: a at positions 176-177
# <re.Match object; span=(177, 178), match='o'>
# Match found: o at positions 177-178
# <re.Match object; span=(178, 179), match='n'>
# Match found: n at positions 178-179
# <re.Match object; span=(179, 180), match='a'>
# Match found: a at positions 179-180
# <re.Match object; span=(180, 181), match='n'>
# Match found: n at positions 180-181
# <re.Match object; span=(181, 182), match='d'>
# Match found: d at positions 181-182
# <re.Match object; span=(182, 183), match='i'>
# Match found: i at positions 182-183
# <re.Match object; span=(183, 184), match='a'>
# Match found: a at positions 183-184
# <re.Match object; span=(184, 185), match='.'>
# Match found: . at positions 184-185
# <re.Match object; span=(185, 186), match='c'>
# Match found: c at positions 185-186
# <re.Match object; span=(186, 187), match='o'>
# Match found: o at positions 186-187
# <re.Match object; span=(187, 188), match='m'>
# Match found: m at positions 187-188
# <re.Match object; span=(189, 190), match='h'>
# Match found: h at positions 189-190
# <re.Match object; span=(190, 191), match='e'>
# Match found: e at positions 190-191
# <re.Match object; span=(191, 192), match='g'>
# Match found: g at positions 191-192
# <re.Match object; span=(192, 193), match='o'>
# Match found: o at positions 192-193
# <re.Match object; span=(193, 194), match='i'>
# Match found: i at positions 193-194
# <re.Match object; span=(194, 195), match='g'>
# Match found: g at positions 194-195
# <re.Match object; span=(195, 196), match='a'>
# Match found: a at positions 195-196
# <re.Match object; span=(196, 197), match='r'>
# Match found: r at positions 196-197
# <re.Match object; span=(197, 198), match='i'>
# Match found: i at positions 197-198
# <re.Match object; span=(198, 199), match='t'>
# Match found: t at positions 198-199
# <re.Match object; span=(199, 200), match='a'>
# Match found: a at positions 199-200
# <re.Match object; span=(200, 201), match='o'>
# Match found: o at positions 200-201
# <re.Match object; span=(201, 202), match='n'>
# Match found: n at positions 201-202
# <re.Match object; span=(202, 203), match='a'>
# Match found: a at positions 202-203
# <re.Match object; span=(203, 204), match='n'>
# Match found: n at positions 203-204
# <re.Match object; span=(204, 205), match='d'>
# Match found: d at positions 204-205
# <re.Match object; span=(205, 206), match='i'>
# Match found: i at positions 205-206
# <re.Match object; span=(206, 207), match='a'>
# Match found: a at positions 206-207
# <re.Match object; span=(207, 208), match='c'>
# Match found: c at positions 207-208
# <re.Match object; span=(208, 209), match='o'>
# Match found: o at positions 208-209
# <re.Match object; span=(209, 210), match='m'>
# Match found: m at positions 209-210
# <re.Match object; span=(211, 212), match='h'>
# Match found: h at positions 211-212
# <re.Match object; span=(212, 213), match='e'>
# Match found: e at positions 212-213
# <re.Match object; span=(213, 214), match='g'>
# Match found: g at positions 213-214
# <re.Match object; span=(214, 215), match='o'>
# Match found: o at positions 214-215
# <re.Match object; span=(215, 216), match='i'>
# Match found: i at positions 215-216
# <re.Match object; span=(216, 217), match='g'>
# Match found: g at positions 216-217
# <re.Match object; span=(217, 218), match='a'>
# Match found: a at positions 217-218
# <re.Match object; span=(218, 219), match='r'>
# Match found: r at positions 218-219
# <re.Match object; span=(219, 220), match='i'>
# Match found: i at positions 219-220
# <re.Match object; span=(220, 221), match='t'>
# Match found: t at positions 220-221
# <re.Match object; span=(221, 222), match='a'>
# Match found: a at positions 221-222
# <re.Match object; span=(222, 223), match='o'>
# Match found: o at positions 222-223
# <re.Match object; span=(223, 224), match='n'>
# Match found: n at positions 223-224
# <re.Match object; span=(224, 225), match='a'>
# Match found: a at positions 224-225
# <re.Match object; span=(225, 226), match='n'>
# Match found: n at positions 225-226
# <re.Match object; span=(226, 227), match='d'>
# Match found: d at positions 226-227
# <re.Match object; span=(227, 228), match='i'>
# Match found: i at positions 227-228
# <re.Match object; span=(228, 229), match='a'>
# Match found: a at positions 228-229
# <re.Match object; span=(230, 231), match='h'>
# Match found: h at positions 230-231
# <re.Match object; span=(231, 232), match='o'>
# Match found: o at positions 231-232
# <re.Match object; span=(232, 233), match='l'>
# Match found: l at positions 232-233
# <re.Match object; span=(233, 234), match='a'>
# Match found: a at positions 233-234
# <re.Match object; span=(235, 236), match='3'>
# Match found: 3 at positions 235-236
# <re.Match object; span=(236, 237), match='2'>
# Match found: 2 at positions 236-237
# <re.Match object; span=(237, 238), match='1'>
# Match found: 1 at positions 237-238
# <re.Match object; span=(238, 239), match='-'>
# Match found: - at positions 238-239
# <re.Match object; span=(239, 240), match='-'>
# Match found: - at positions 239-240
# <re.Match object; span=(240, 241), match='5'>
# Match found: 5 at positions 240-241
# <re.Match object; span=(241, 242), match='5'>
# Match found: 5 at positions 241-242
# <re.Match object; span=(242, 243), match='5'>
# Match found: 5 at positions 242-243
# <re.Match object; span=(243, 244), match='-'>
# Match found: - at positions 243-244
# <re.Match object; span=(244, 245), match='4'>
# Match found: 4 at positions 244-245
# <re.Match object; span=(245, 246), match='3'>
# Match found: 3 at positions 245-246
# <re.Match object; span=(246, 247), match='2'>
# Match found: 2 at positions 246-247
# <re.Match object; span=(247, 248), match='1'>
# Match found: 1 at positions 247-248
# <re.Match object; span=(249, 250), match='1'>
# Match found: 1 at positions 249-250
# <re.Match object; span=(250, 251), match='2'>
# Match found: 2 at positions 250-251
# <re.Match object; span=(251, 252), match='3'>
# Match found: 3 at positions 251-252
# <re.Match object; span=(252, 253), match='.'>
# Match found: . at positions 252-253
# <re.Match object; span=(253, 254), match='5'>
# Match found: 5 at positions 253-254
# <re.Match object; span=(254, 255), match='5'>
# Match found: 5 at positions 254-255
# <re.Match object; span=(255, 256), match='5'>
# Match found: 5 at positions 255-256
# <re.Match object; span=(256, 257), match='.'>
# Match found: . at positions 256-257
# <re.Match object; span=(257, 258), match='1'>
# Match found: 1 at positions 257-258
# <re.Match object; span=(258, 259), match='2'>
# Match found: 2 at positions 258-259
# <re.Match object; span=(259, 260), match='3'>
# Match found: 3 at positions 259-260
# <re.Match object; span=(260, 261), match='4'>
# Match found: 4 at positions 260-261
# <re.Match object; span=(262, 263), match='1'>
# Match found: 1 at positions 262-263
# <re.Match object; span=(263, 264), match='2'>
# Match found: 2 at positions 263-264
# <re.Match object; span=(264, 265), match='3'>
# Match found: 3 at positions 264-265
# <re.Match object; span=(265, 266), match='*'>
# Match found: * at positions 265-266
# <re.Match object; span=(266, 267), match='5'>
# Match found: 5 at positions 266-267
# <re.Match object; span=(267, 268), match='5'>
# Match found: 5 at positions 267-268
# <re.Match object; span=(268, 269), match='5'>
# Match found: 5 at positions 268-269
# <re.Match object; span=(269, 270), match='*'>
# Match found: * at positions 269-270
# <re.Match object; span=(270, 271), match='1'>
# Match found: 1 at positions 270-271
# <re.Match object; span=(271, 272), match='2'>
# Match found: 2 at positions 271-272
# <re.Match object; span=(272, 273), match='3'>
# Match found: 3 at positions 272-273
# <re.Match object; span=(273, 274), match='4'>
# Match found: 4 at positions 273-274
# <re.Match object; span=(275, 276), match='8'>
# Match found: 8 at positions 275-276
# <re.Match object; span=(276, 277), match='0'>
# Match found: 0 at positions 276-277
# <re.Match object; span=(277, 278), match='0'>
# Match found: 0 at positions 277-278
# <re.Match object; span=(278, 279), match='-'>
# Match found: - at positions 278-279
# <re.Match object; span=(279, 280), match='5'>
# Match found: 5 at positions 279-280
# <re.Match object; span=(280, 281), match='5'>
# Match found: 5 at positions 280-281
# <re.Match object; span=(281, 282), match='5'>
# Match found: 5 at positions 281-282
# <re.Match object; span=(282, 283), match='-'>
# Match found: - at positions 282-283
# <re.Match object; span=(283, 284), match='1'>
# Match found: 1 at positions 283-284
# <re.Match object; span=(284, 285), match='2'>
# Match found: 2 at positions 284-285
# <re.Match object; span=(285, 286), match='3'>
# Match found: 3 at positions 285-286
# <re.Match object; span=(286, 287), match='4'>
# Match found: 4 at positions 286-287
# <re.Match object; span=(288, 289), match='9'>
# Match found: 9 at positions 288-289
# <re.Match object; span=(289, 290), match='0'>
# Match found: 0 at positions 289-290
# <re.Match object; span=(290, 291), match='0'>
# Match found: 0 at positions 290-291
# <re.Match object; span=(291, 292), match='-'>
# Match found: - at positions 291-292
# <re.Match object; span=(292, 293), match='5'>
# Match found: 5 at positions 292-293
# <re.Match object; span=(293, 294), match='5'>
# Match found: 5 at positions 293-294
# <re.Match object; span=(294, 295), match='5'>
# Match found: 5 at positions 294-295
# <re.Match object; span=(295, 296), match='-'>
# Match found: - at positions 295-296
# <re.Match object; span=(296, 297), match='1'>
# Match found: 1 at positions 296-297
# <re.Match object; span=(297, 298), match='2'>
# Match found: 2 at positions 297-298
# <re.Match object; span=(298, 299), match='3'>
# Match found: 3 at positions 298-299
# <re.Match object; span=(299, 300), match='4'>
# Match found: 4 at positions 299-300
# <re.Match object; span=(301, 302), match='9'>
# Match found: 9 at positions 301-302
# <re.Match object; span=(302, 303), match='0'>
# Match found: 0 at positions 302-303
# <re.Match object; span=(303, 304), match='0'>
# Match found: 0 at positions 303-304
# <re.Match object; span=(304, 305), match='5'>
# Match found: 5 at positions 304-305
# <re.Match object; span=(305, 306), match='5'>
# Match found: 5 at positions 305-306
# <re.Match object; span=(306, 307), match='5'>
# Match found: 5 at positions 306-307
# <re.Match object; span=(307, 308), match='1'>
# Match found: 1 at positions 307-308
# <re.Match object; span=(308, 309), match='2'>
# Match found: 2 at positions 308-309
# <re.Match object; span=(309, 310), match='3'>
# Match found: 3 at positions 309-310
# <re.Match object; span=(310, 311), match='4'>
# Match found: 4 at positions 310-311
# <re.Match object; span=(312, 313), match='9'>
# Match found: 9 at positions 312-313
# <re.Match object; span=(313, 314), match='0'>
# Match found: 0 at positions 313-314
# <re.Match object; span=(314, 315), match='0'>
# Match found: 0 at positions 314-315
# <re.Match object; span=(315, 316), match='0'>
# Match found: 0 at positions 315-316
# <re.Match object; span=(316, 317), match='5'>
# Match found: 5 at positions 316-317
# <re.Match object; span=(317, 318), match='5'>
# Match found: 5 at positions 317-318
# <re.Match object; span=(318, 319), match='5'>
# Match found: 5 at positions 318-319
# <re.Match object; span=(319, 320), match='0'>
# Match found: 0 at positions 319-320
# <re.Match object; span=(320, 321), match='1'>
# Match found: 1 at positions 320-321
# <re.Match object; span=(321, 322), match='2'>
# Match found: 2 at positions 321-322
# <re.Match object; span=(322, 323), match='3'>
# Match found: 3 at positions 322-323
# <re.Match object; span=(323, 324), match='4'>
# Match found: 4 at positions 323-324
# <re.Match object; span=(325, 326), match='M'>
# Match found: M at positions 325-326
# <re.Match object; span=(326, 327), match='r'>
# Match found: r at positions 326-327
# <re.Match object; span=(327, 328), match='.'>
# Match found: . at positions 327-328
# <re.Match object; span=(329, 330), match='S'>
# Match found: S at positions 329-330
# <re.Match object; span=(330, 331), match='c'>
# Match found: c at positions 330-331
# <re.Match object; span=(331, 332), match='h'>
# Match found: h at positions 331-332
# <re.Match object; span=(332, 333), match='a'>
# Match found: a at positions 332-333
# <re.Match object; span=(333, 334), match='2'>
# Match found: 2 at positions 333-334
# <re.Match object; span=(334, 335), match='f'>
# Match found: f at positions 334-335
# <re.Match object; span=(335, 336), match='e'>
# Match found: e at positions 335-336
# <re.Match object; span=(336, 337), match='r'>
# Match found: r at positions 336-337
# <re.Match object; span=(338, 339), match='M'>
# Match found: M at positions 338-339
# <re.Match object; span=(339, 340), match='r'>
# Match found: r at positions 339-340
# <re.Match object; span=(341, 342), match='S'>
# Match found: S at positions 341-342
# <re.Match object; span=(342, 343), match='m'>
# Match found: m at positions 342-343
# <re.Match object; span=(343, 344), match='i'>
# Match found: i at positions 343-344
# <re.Match object; span=(344, 345), match='t'>
# Match found: t at positions 344-345
# <re.Match object; span=(345, 346), match='h'>
# Match found: h at positions 345-346
# <re.Match object; span=(347, 348), match='M'>
# Match found: M at positions 347-348
# <re.Match object; span=(348, 349), match='s'>
# Match found: s at positions 348-349
# <re.Match object; span=(350, 351), match='D'>
# Match found: D at positions 350-351
# <re.Match object; span=(351, 352), match='a'>
# Match found: a at positions 351-352
# <re.Match object; span=(352, 353), match='v'>
# Match found: v at positions 352-353
# <re.Match object; span=(353, 354), match='i'>
# Match found: i at positions 353-354
# <re.Match object; span=(354, 355), match='s'>
# Match found: s at positions 354-355
# <re.Match object; span=(356, 357), match='M'>
# Match found: M at positions 356-357
# <re.Match object; span=(357, 358), match='r'>
# Match found: r at positions 357-358
# <re.Match object; span=(358, 359), match='s'>
# Match found: s at positions 358-359
# <re.Match object; span=(359, 360), match='.'>
# Match found: . at positions 359-360
# <re.Match object; span=(361, 362), match='R'>
# Match found: R at positions 361-362
# <re.Match object; span=(362, 363), match='o'>
# Match found: o at positions 362-363
# <re.Match object; span=(363, 364), match='b'>
# Match found: b at positions 363-364
# <re.Match object; span=(364, 365), match='i'>
# Match found: i at positions 364-365
# <re.Match object; span=(365, 366), match='n'>
# Match found: n at positions 365-366
# <re.Match object; span=(366, 367), match='s'>
# Match found: s at positions 366-367
# <re.Match object; span=(367, 368), match='o'>
# Match found: o at positions 367-368
# <re.Match object; span=(368, 369), match='n'>
# Match found: n at positions 368-369
# <re.Match object; span=(370, 371), match='M'>
# Match found: M at positions 370-371
# <re.Match object; span=(371, 372), match='r'>
# Match found: r at positions 371-372
# <re.Match object; span=(372, 373), match='.'>
# Match found: . at positions 372-373
# <re.Match object; span=(374, 375), match='T'>
# Match found: T at positions 374-375
# <re.Match object; span=(376, 377), match='M'>
# Match found: M at positions 376-377
# <re.Match object; span=(377, 378), match='r'>
# Match found: r at positions 377-378
# <re.Match object; span=(378, 379), match='.'>
# Match found: . at positions 378-379
# <re.Match object; span=(380, 381), match='('>
# Match found: ( at positions 380-381
# <re.Match object; span=(381, 382), match=')'>
# Match found: ) at positions 381-382
# <re.Match object; span=(384, 385), match='c'>
# Match found: c at positions 384-385
# <re.Match object; span=(385, 386), match='a'>
# Match found: a at positions 385-386
# <re.Match object; span=(386, 387), match='t'>
# Match found: t at positions 386-387
# <re.Match object; span=(388, 389), match='m'>
# Match found: m at positions 388-389
# <re.Match object; span=(389, 390), match='a'>
# Match found: a at positions 389-390
# <re.Match object; span=(390, 391), match='t'>
# Match found: t at positions 390-391
# <re.Match object; span=(392, 393), match='p'>
# Match found: p at positions 392-393
# <re.Match object; span=(393, 394), match='a'>
# Match found: a at positions 393-394
# <re.Match object; span=(394, 395), match='t'>
# Match found: t at positions 394-395
# <re.Match object; span=(396, 397), match='b'>
# Match found: b at positions 396-397
# <re.Match object; span=(397, 398), match='a'>
# Match found: a at positions 397-398
# <re.Match object; span=(398, 399), match='t'>
# Match found: t at positions 398-399
# <re.Match object; span=(401, 402), match='a'>
# Match found: a at positions 401-402
# <re.Match object; span=(402, 403), match='t'>
# Match found: t at positions 402-403

# %% [markdown]
# ## Anclas
#
# Las anclas no buscan caracteres en concreto, pero delimitan nuestra búsqueda.

# %% [markdown]
# Word Boundaries `\b`: está compuesto por los espacios, tabuladores, nuevas líneas y caracteres no alfanuméricos.

# %%
pattern = re.compile(r'Ha\b')
#\b assert position at a word boundary

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(66, 68), match='Ha'>
# Match found: Ha at positions 66-68
# <re.Match object; span=(71, 73), match='Ha'>
# Match found: Ha at positions 71-73
# <re.Match object; span=(75, 77), match='Ha'>
# Match found: Ha at positions 75-77

# %% [markdown]
# No word boundaries `\B`: lo contrario
#
# Muestra el último Ha, porque delante no tiene los boundaries

# %%
pattern = re.compile(r'\BHa')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(71, 73), match='Ha'>
# Match found: Ha at positions 71-73

# %% [markdown]
# ### `^` Busca solo el principio del string

# %%
sentence = 'Start a sentence and then bring it to an end'

# %%
pattern = re.compile(r'^Start')

matches = pattern.finditer(sentence)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(0, 5), match='Start'>
# Match found: Start at positions 0-5

# %% [markdown]
# ### `$` Solo busca el final del string

# %%
pattern = re.compile(r'end$')

matches = pattern.finditer(sentence)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(41, 44), match='end'>
# Match found: end at positions 41-44

# %% [markdown]
# ## TIME FOR ACTION
#
# A continuación, vamos a tratar de obtener los números de teléfono.
#
# Como podemos ver en el texto, el número de teléfono sigue la misma estructura:
# - 3 números
# - signo de puntuación
# - 3 números
# - signo de puntuación
# - 4 números

# %%
#escribe tu código
pattern = re.compile("\d{3}\W\d{3}\W\d{4}")

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(249, 261), match='123.555.1234'>
# Match found: 123.555.1234 at positions 249-261
# <re.Match object; span=(262, 274), match='123*555*1234'>
# Match found: 123*555*1234 at positions 262-274
# <re.Match object; span=(275, 287), match='800-555-1234'>
# Match found: 800-555-1234 at positions 275-287
# <re.Match object; span=(288, 300), match='900-555-1234'>
# Match found: 900-555-1234 at positions 288-300

# %% [markdown]
# ### Abrimos `fake_info.txt` para empezar a trabajar

# %%
with open('data/fake_info.txt', 'r') as f:
    contents = f.read()

# %%
print(contents)
# Out:
# Dave Martin
# 615-555-7164
# 173 Main St., Springfield RI 55924
# davemartin@bogusemail.com
#
# Charles Harris
# 800-555-5669
# 969 High St., Atlantis VA 34075
# charlesharris@bogusemail.com
#
# Eric Williams
# 560-555-5153
# 806 1st St., Faketown AK 86847
# laurawilliams@bogusemail.com
#
# Corey Jefferson
# 900-555-9340
# 826 Elm St., Epicburg NE 10671
# coreyjefferson@bogusemail.com
#
# Jennifer Martin-White
# 714-555-7405
# 212 Cedar St., Sunnydale CT 74983
# jenniferwhite@bogusemail.com
#
# Erick Davis
# 800-555-6771
# 519 Washington St., Olympus TN 32425
# tomdavis@bogusemail.com
#
# Neil Patterson
# 783-555-4799
# 625 Oak St., Dawnstar IL 61914
# neilpatterson@bogusemail.com
#
# Laura Jefferson
# 516-555-4615
# 890 Main St., Pythonville LA 29947
# laurajefferson@bogusemail.com
#
# Maria Johnson
# 127-555-1867
# 884 High St., Braavosâ€Ž ME 43597
# mariajohnson@bogusemail.com
#
# Michael Arnold
# 608-555-4938
# 249 Elm St., Quahog OR 90938
# michaelarnold@bogusemail.com
#
# Michael Smith
# 568-555-6051
# 619 Park St., Winterfell VA 99000
# michaelsmith@bogusemail.com
#
# Erik Stuart
# 292-555-1875
# 220 Cedar St., Lakeview NY 87282
# robertstuart@bogusemail.com
#
# Laura Martin
# 900-555-3205
# 391 High St., Smalltown WY 28362
# lauramartin@bogusemail.com
#
# Barbara Martin
# 614-555-1166
# 121 Hill St., Braavosâ€Ž UT 92474
# barbaramartin@bogusemail.com
#
# Linda Jackson
# 530-555-2676
# 433 Elm St., Westworld TX 61967
# lindajackson@bogusemail.com
#
# Eric Miller
# 470-555-2750
# 838 Main St., Balmora MT 56526
# stevemiller@bogusemail.com
#
# Dave Arnold
# 800-555-6089
# 732 High St., Valyria KY 97152
# davearnold@bogusemail.com
#
# Jennifer Jacobs
# 880-555-8319
# 217 High St., Old-town IA 82767
# jenniferjacobs@bogusemail.com
#
# Neil Wilson
# 777-555-8378
# 191 Main St., Mordor IL 72160
# neilwilson@bogusemail.com
#
# Kurt Jackson
# 998-555-7385
# 607 Washington St., Blackwater NH 97183
# kurtjackson@bogusemail.com
#
# Mary Jacobs
# 800-555-7100
# 478 Oak St., Bedrock IA 58176
# maryjacobs@bogusemail.com
#
# Michael White
# 903-555-8277
# 906 Elm St., Mordor TX 89212
# michaelwhite@bogusemail.com
#
# Jennifer Jenkins
# 196-555-5674
# 949 Main St., Smalltown SC 96962
# jenniferjenkins@bogusemail.com
#
# Sam Wright
# 900-555-5118
# 835 Pearl St., Smalltown ND 77737
# samwright@bogusemail.com
#
# John Davis
# 905-555-1630
# 451 Lake St., Bedrock GA 34615
# johndavis@bogusemail.com
#
# Eric Davis
# 203-555-3475
# 419 Lake St., Balmora OR 30826
# neildavis@bogusemail.com
#
# Laura Jackson
# 884-555-8444
# 443 Maple St., Quahog MS 29348
# laurajackson@bogusemail.com
#
# John Williams
# 904-555-8559
# 756 Hill St., Valyria KY 94854
# johnwilliams@bogusemail.com
#
# Michael Martin
# 889-555-7393
# 216 High St., Olympus NV 21888
# michaelmartin@bogusemail.com
#
# Maggie Brown
# 195-555-2405
# 806 Lake St., Lakeview MD 59348
# maggiebrown@bogusemail.com
#
# Erik Wilson
# 321-555-9053
# 354 Hill St., Mordor FL 74122
# kurtwilson@bogusemail.com
#
# Elizabeth Arnold
# 133-555-1711
# 805 Maple St., Winterfell NV 99431
# elizabetharnold@bogusemail.com
#
# Jane Martin
# 900-555-5428
# 418 Park St., Metropolis ID 16576
# janemartin@bogusemail.com
#
# Travis Johnson
# 760-555-7147
# 749 Washington St., Braavosâ€Ž SD 25668
# travisjohnson@bogusemail.com
#
# Laura Jefferson
# 391-555-6621
# 122 High St., Metropolis ME 29540
# laurajefferson@bogusemail.com
#
# Tom Williams
# 932-555-7724
# 610 High St., Old-town FL 60758
# tomwilliams@bogusemail.com
#
# Jennifer Taylor
# 609-555-7908
# 332 Main St., Pythonville OH 78172
# jennifertaylor@bogusemail.com
#
# Erick Wright
# 800-555-8810
# 858 Hill St., Blackwater NC 79714
# jenniferwright@bogusemail.com
#
# Steve Doe
# 149-555-7657
# 441 Elm St., Atlantis MS 87195
# stevedoe@bogusemail.com
#
# Kurt Davis
# 130-555-9709
# 404 Oak St., Atlantis ND 85386
# kurtdavis@bogusemail.com
#
# Corey Harris
# 143-555-9295
# 286 Pearl St., Vice City TX 57112
# coreyharris@bogusemail.com
#
# Nicole Taylor
# 903-555-9878
# 465 Hill St., Old-town LA 64102
# nicoletaylor@bogusemail.com
#
# Elizabeth Davis
# 574-555-3194
# 151 Lake St., Eerie SD 17880
# elizabethdavis@bogusemail.com
#
# Maggie Jenkins
# 496-555-7533
# 504 Lake St., Gotham PA 46692
# maggiejenkins@bogusemail.com
#
# Linda Davis
# 210-555-3757
# 201 Pine St., Vice City AR 78455
# lindadavis@bogusemail.com
#
# Dave Moore
# 900-555-9598
# 251 Pine St., Old-town OK 29087
# davemoore@bogusemail.com
#
# Linda Jenkins
# 866-555-9844
# 117 High St., Bedrock NE 11899
# lindajenkins@bogusemail.com
#
# Eric White
# 669-555-7159
# 650 Oak St., Smalltown TN 43281
# samwhite@bogusemail.com
#
# Laura Robinson
# 152-555-7417
# 377 Pine St., Valyria NC 78036
# laurarobinson@bogusemail.com
#
# Charles Patterson
# 893-555-9832
# 416 Pearl St., Valyria AK 62260
# charlespatterson@bogusemail.com
#
# Joe Jackson
# 217-555-7123
# 683 Cedar St., South Park KS 66724
# joejackson@bogusemail.com
#
# Michael Johnson
# 786-555-6544
# 288 Hill St., Smalltown AZ 18586
# michaeljohnson@bogusemail.com
#
# Corey Miller
# 780-555-2574
# 286 High St., Springfield IA 16272
# coreymiller@bogusemail.com
#
# James Moore
# 926-555-8735
# 278 Main St., Gotham KY 89569
# jamesmoore@bogusemail.com
#
# Jennifer Stuart
# 895-555-3539
# 766 Hill St., King's Landing GA 54999
# jenniferstuart@bogusemail.com
#
# Charles Martin
# 874-555-3949
# 775 High St., Faketown PA 89260
# charlesmartin@bogusemail.com
#
# Eric Wilks
# 800-555-2420
# 885 Main St., Blackwater OH 61275
# joewilks@bogusemail.com
#
# Elizabeth Arnold
# 936-555-6340
# 528 Hill St., Atlantis NH 88289
# elizabetharnold@bogusemail.com
#
# John Miller
# 372-555-9809
# 117 Cedar St., Thundera NM 75205
# johnmiller@bogusemail.com
#
# Corey Jackson
# 890-555-5618
# 115 Oak St., Gotham UT 36433
# coreyjackson@bogusemail.com
#
# Sam Thomas
# 670-555-3005
# 743 Lake St., Springfield MS 25473
# samthomas@bogusemail.com
#
# Patricia Thomas
# 509-555-5997
# 381 Hill St., Blackwater CT 30958
# patriciathomas@bogusemail.com
#
# Jennifer Davis
# 721-555-5632
# 125 Main St., Smalltown MT 62155
# jenniferdavis@bogusemail.com
#
# Patricia Brown
# 900-555-3567
# 292 Hill St., Gotham WV 57680
# patriciabrown@bogusemail.com
#
# Barbara Williams
# 147-555-6830
# 514 Park St., Balmora NV 55462
# barbarawilliams@bogusemail.com
#
# James Taylor
# 582-555-3426
# 776 Hill St., Dawnstar MA 51312
# jamestaylor@bogusemail.com
#
# Eric Harris
# 400-555-1706
# 421 Elm St., Smalltown NV 72025
# barbaraharris@bogusemail.com
#
# Travis Anderson
# 525-555-1793
# 937 Cedar St., Thundera WA 78862
# travisanderson@bogusemail.com
#
# Sam Robinson
# 317-555-6700
# 417 Pine St., Lakeview MD 13147
# samrobinson@bogusemail.com
#
# Steve Robinson
# 974-555-8301
# 478 Park St., Springfield NM 92369
# steverobinson@bogusemail.com
#
# Mary Wilson
# 800-555-3216
# 708 Maple St., Braavosâ€Ž UT 29551
# marywilson@bogusemail.com
#
# Sam Wilson
# 746-555-4094
# 557 Pearl St., Westworld KS 23225
# samwilson@bogusemail.com
#
# Charles Jones
# 922-555-1773
# 855 Hill St., Olympus HI 81427
# charlesjones@bogusemail.com
#
# Laura Brown
# 711-555-4427
# 980 Maple St., Smalltown MO 96421
# laurabrown@bogusemail.com
#
# Tom Harris
# 355-555-1872
# 676 Hill St., Blackwater AR 96698
# tomharris@bogusemail.com
#
# Patricia Taylor
# 852-555-6521
# 588 Pine St., Olympus FL 98412
# patriciataylor@bogusemail.com
#
# Barbara Williams
# 691-555-5773
# 351 Elm St., Sunnydale GA 26245
# barbarawilliams@bogusemail.com
#
# Maggie Johnson
# 332-555-5441
# 948 Cedar St., Quahog DE 56449
# maggiejohnson@bogusemail.com
#
# Kurt Miller
# 900-555-7755
# 381 Hill St., Quahog AL 97503
# kurtmiller@bogusemail.com
#
# Neil Stuart
# 379-555-3685
# 496 Cedar St., Sunnydale RI 49113
# neilstuart@bogusemail.com
#
# Linda Patterson
# 127-555-9682
# 736 Cedar St., Lakeview KY 47472
# lindapatterson@bogusemail.com
#
# Charles Davis
# 789-555-7032
# 678 Lake St., Mordor MN 11845
# charlesdavis@bogusemail.com
#
# Jennifer Jefferson
# 783-555-5135
# 289 Park St., Sunnydale WA 74526
# jenniferjefferson@bogusemail.com
#
# Erick Taylor
# 315-555-6507
# 245 Washington St., Bedrock IL 26941
# coreytaylor@bogusemail.com
#
# Robert Wilks
# 481-555-5835
# 573 Elm St., Sunnydale IL 47182
# robertwilks@bogusemail.com
#
# Travis Jackson
# 365-555-8287
# 851 Lake St., Metropolis PA 22772
# travisjackson@bogusemail.com
#
# Travis Jackson
# 911-555-7535
# 489 Oak St., Atlantis HI 73725
# travisjackson@bogusemail.com
#
# Laura Wilks
# 681-555-2460
# 371 Pearl St., Smalltown SC 47466
# laurawilks@bogusemail.com
#
# Neil Arnold
# 274-555-9800
# 504 Oak St., Faketown PA 73860
# neilarnold@bogusemail.com
#
# Linda Johnson
# 800-555-1372
# 667 High St., Balmora IN 82473
# lindajohnson@bogusemail.com
#
# Jennifer Wilson
# 300-555-7821
# 266 Pine St., Westworld DC 58720
# jenniferwilson@bogusemail.com
#
# Nicole White
# 133-555-3889
# 276 High St., Braavosâ€Ž IL 57764
# nicolewhite@bogusemail.com
#
# Maria Arnold
# 705-555-6863
# 491 Elm St., Metropolis PA 31836
# mariaarnold@bogusemail.com
#
# Jennifer Davis
# 215-555-9449
# 859 Cedar St., Old-town MT 31169
# jenniferdavis@bogusemail.com
#
# Mary Patterson
# 988-555-6112
# 956 Park St., Valyria CT 81541
# marypatterson@bogusemail.com
#
# Jane Stuart
# 623-555-3006
# 983 Oak St., Old-town RI 15445
# janestuart@bogusemail.com
#
# Robert Davis
# 192-555-4977
# 789 Maple St., Mordor IN 22215
# robertdavis@bogusemail.com
#
# James Taylor
# 178-555-4899
# 439 Hill St., Olympus NV 39308
# jamestaylor@bogusemail.com
#
# Eric Stuart
# 952-555-3089
# 777 High St., King's Landing AZ 16547
# johnstuart@bogusemail.com
#
# Charles Miller
# 900-555-6426
# 207 Washington St., Blackwater MA 24886
# charlesmiller@bogusemail.com

# %% [markdown]
# Pongamos que queremos obtener solamente los números de teléfono separados por un punto o un guion

# %%
#escribe tu código
#pattern = re.compile(r'\d\d\d[-\.]\d\d\d[-\.]\d\d\d\d')
pattern = re.compile(r'\d\d\d[-]\d\d\d[-]\d\d\d\d')

matches = pattern.finditer(contents)

numeros_telefono = []
for match in matches:
    # print(match.group())
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
    numeros_telefono.append(match.group().replace("-",""))
numeros_telefono
# Out:
# Match found: 615-555-7164 at positions 12-24
# Match found: 800-555-5669 at positions 102-114
# Match found: 560-555-5153 at positions 191-203
# Match found: 900-555-9340 at positions 281-293
# Match found: 714-555-7405 at positions 378-390
# Match found: 800-555-6771 at positions 467-479
# Match found: 783-555-4799 at positions 557-569
# Match found: 516-555-4615 at positions 647-659
# Match found: 127-555-1867 at positions 740-752
# Match found: 608-555-4938 at positions 831-843
# Match found: 568-555-6051 at positions 917-929
# Match found: 292-555-1875 at positions 1005-1017
# Match found: 900-555-3205 at positions 1093-1105
# Match found: 614-555-1166 at positions 1182-1194
# Match found: 530-555-2676 at positions 1273-1285
# Match found: 470-555-2750 at positions 1359-1371
# Match found: 800-555-6089 at positions 1443-1455
# Match found: 880-555-8319 at positions 1530-1542
# Match found: 777-555-8378 at positions 1618-1630
# Match found: 998-555-7385 at positions 1701-1713
# Match found: 800-555-7100 at positions 1794-1806
# Match found: 903-555-8277 at positions 1878-1890
# Match found: 196-555-5674 at positions 1966-1978
# Match found: 900-555-5118 at positions 2055-2067
# Match found: 905-555-1630 at positions 2139-2151
# Match found: 203-555-3475 at positions 2220-2232
# Match found: 884-555-8444 at positions 2304-2316
# Match found: 904-555-8559 at positions 2391-2403
# Match found: 889-555-7393 at positions 2479-2491
# Match found: 195-555-2405 at positions 2566-2578
# Match found: 321-555-9053 at positions 2651-2663
# Match found: 133-555-1711 at positions 2738-2750
# Match found: 900-555-5428 at positions 2830-2842
# Match found: 760-555-7147 at positions 2919-2931
# Match found: 391-555-6621 at positions 3018-3030
# Match found: 932-555-7724 at positions 3109-3121
# Match found: 609-555-7908 at positions 3198-3210
# Match found: 800-555-8810 at positions 3290-3302
# Match found: 149-555-7657 at positions 3378-3390
# Match found: 130-555-9709 at positions 3458-3470
# Match found: 143-555-9295 at positions 3541-3553
# Match found: 903-555-9878 at positions 3630-3642
# Match found: 574-555-3194 at positions 3720-3732
# Match found: 496-555-7533 at positions 3808-3820
# Match found: 210-555-3757 at positions 3893-3905
# Match found: 900-555-9598 at positions 3977-3989
# Match found: 866-555-9844 at positions 4062-4074
# Match found: 669-555-7159 at positions 4146-4158
# Match found: 152-555-7417 at positions 4231-4243
# Match found: 893-555-9832 at positions 4323-4335
# Match found: 217-555-7123 at positions 4413-4425
# Match found: 786-555-6544 at positions 4504-4516
# Match found: 780-555-2574 at positions 4594-4606
# Match found: 926-555-8735 at positions 4682-4694
# Match found: 895-555-3539 at positions 4768-4780
# Match found: 874-555-3949 at positions 4865-4877
# Match found: 800-555-2420 at positions 4951-4963
# Match found: 936-555-6340 at positions 5040-5052
# Match found: 372-555-9809 at positions 5129-5141
# Match found: 890-555-5618 at positions 5216-5228
# Match found: 670-555-3005 at positions 5298-5310
# Match found: 509-555-5997 at positions 5388-5400
# Match found: 721-555-5632 at positions 5481-5493
# Match found: 900-555-3567 at positions 5572-5584
# Match found: 147-555-6830 at positions 5662-5674
# Match found: 582-555-3426 at positions 5751-5763
# Match found: 400-555-1706 at positions 5836-5848
# Match found: 525-555-1793 at positions 5927-5939
# Match found: 317-555-6700 at positions 6017-6029
# Match found: 974-555-8301 at positions 6105-6117
# Match found: 800-555-3216 at positions 6195-6207
# Match found: 746-555-4094 at positions 6281-6293
# Match found: 922-555-1773 at positions 6368-6380
# Match found: 711-555-4427 at positions 6453-6465
# Match found: 355-555-1872 at positions 6538-6550
# Match found: 852-555-6521 at positions 6627-6639
# Match found: 691-555-5773 at positions 6719-6731
# Match found: 332-555-5441 at positions 6811-6823
# Match found: 900-555-7755 at positions 6897-6909
# Match found: 379-555-3685 at positions 6979-6991
# Match found: 127-555-9682 at positions 7069-7081
# Match found: 789-555-7032 at positions 7160-7172
# Match found: 783-555-5135 at positions 7251-7263
# Match found: 315-555-6507 at positions 7344-7356
# Match found: 481-555-5835 at positions 7435-7447
# Match found: 365-555-8287 at positions 7523-7535
# Match found: 911-555-7535 at positions 7615-7627
# Match found: 681-555-2460 at positions 7701-7713
# Match found: 274-555-9800 at positions 7787-7799
# Match found: 800-555-1372 at positions 7872-7884
# Match found: 300-555-7821 at positions 7961-7973
# Match found: 133-555-3889 at positions 8051-8063
# Match found: 705-555-6863 at positions 8139-8151
# Match found: 215-555-9449 at positions 8228-8240
# Match found: 988-555-6112 at positions 8319-8331
# Match found: 623-555-3006 at positions 8405-8417
# Match found: 192-555-4977 at positions 8489-8501
# Match found: 178-555-4899 at positions 8574-8586
# Match found: 952-555-3089 at positions 8658-8670
# Match found: 900-555-6426 at positions 8751-8763
# ['6155557164',
#  '8005555669',
#  '5605555153',
#  '9005559340',
#  '7145557405',
#  '8005556771',
#  '7835554799',
#  '5165554615',
#  '1275551867',
#  '6085554938',
#  '5685556051',
#  '2925551875',
#  '9005553205',
#  '6145551166',
#  '5305552676',
#  '4705552750',
#  '8005556089',
#  '8805558319',
#  '7775558378',
#  '9985557385',
#  '8005557100',
#  '9035558277',
#  '1965555674',
#  '9005555118',
#  '9055551630',
#  '2035553475',
#  '8845558444',
#  '9045558559',
#  '8895557393',
#  '1955552405',
#  '3215559053',
#  '1335551711',
#  '9005555428',
#  '7605557147',
#  '3915556621',
#  '9325557724',
#  '6095557908',
#  '8005558810',
#  '1495557657',
#  '1305559709',
#  '1435559295',
#  '9035559878',
#  '5745553194',
#  '4965557533',
#  '2105553757',
#  '9005559598',
#  '8665559844',
#  '6695557159',
#  '1525557417',
#  '8935559832',
#  '2175557123',
#  '7865556544',
#  '7805552574',
#  '9265558735',
#  '8955553539',
#  '8745553949',
#  '8005552420',
#  '9365556340',
#  '3725559809',
#  '8905555618',
#  '6705553005',
#  '5095555997',
#  '7215555632',
#  '9005553567',
#  '1475556830',
#  '5825553426',
#  '4005551706',
#  '5255551793',
#  '3175556700',
#  '9745558301',
#  '8005553216',
#  '7465554094',
#  '9225551773',
#  '7115554427',
#  '3555551872',
#  '8525556521',
#  '6915555773',
#  '3325555441',
#  '9005557755',
#  '3795553685',
#  '1275559682',
#  '7895557032',
#  '7835555135',
#  '3155556507',
#  '4815555835',
#  '3655558287',
#  '9115557535',
#  '6815552460',
#  '2745559800',
#  '8005551372',
#  '3005557821',
#  '1335553889',
#  '7055556863',
#  '2155559449',
#  '9885556112',
#  '6235553006',
#  '1925554977',
#  '1785554899',
#  '9525553089',
#  '9005556426']

# %%
#escribe tu código
pattern = re.compile(r'\d+[*.-]*\d+[*.-]\d+')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(235, 248), match='321--555-4321'>
# Match found: 321--555-4321 at positions 235-248
# <re.Match object; span=(249, 261), match='123.555.1234'>
# Match found: 123.555.1234 at positions 249-261
# <re.Match object; span=(262, 274), match='123*555*1234'>
# Match found: 123*555*1234 at positions 262-274
# <re.Match object; span=(275, 287), match='800-555-1234'>
# Match found: 800-555-1234 at positions 275-287
# <re.Match object; span=(288, 300), match='900-555-1234'>
# Match found: 900-555-1234 at positions 288-300

# %% [markdown]
# ## Character sets
# Sirven para concretar nuestra búsqueda.
#
# #### ¡CUIDADO! En ocasiones suele haber confusión con los character sets, porque no cogen más de un elemento.

# %%
# Para encontrar todos los números que empiecen por centenas:
# 800 - 900

pattern = re.compile(r'[89]00\D\d\d\d\D\d\d\d\d') # [89] es un character set que incluye al "8" y al "9"

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(275, 287), match='800-555-1234'>
# Match found: 800-555-1234 at positions 275-287
# <re.Match object; span=(288, 300), match='900-555-1234'>
# Match found: 900-555-1234 at positions 288-300

# %% [markdown]
# ## Los guiones no solamente sirven para encontrar ese caracter especial, sino que además nos permiten establecer rangos
#
# Por ejemplo, para mostrar los números entre el 1 y el 5 de todo el texto

# %%
pattern = re.compile(r'[1-5]')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(55, 56), match='1'>
# Match found: 1 at positions 55-56
# <re.Match object; span=(56, 57), match='2'>
# Match found: 2 at positions 56-57
# <re.Match object; span=(57, 58), match='3'>
# Match found: 3 at positions 57-58
# <re.Match object; span=(58, 59), match='4'>
# Match found: 4 at positions 58-59
# <re.Match object; span=(59, 60), match='5'>
# Match found: 5 at positions 59-60
# <re.Match object; span=(235, 236), match='3'>
# Match found: 3 at positions 235-236
# <re.Match object; span=(236, 237), match='2'>
# Match found: 2 at positions 236-237
# <re.Match object; span=(237, 238), match='1'>
# Match found: 1 at positions 237-238
# <re.Match object; span=(240, 241), match='5'>
# Match found: 5 at positions 240-241
# <re.Match object; span=(241, 242), match='5'>
# Match found: 5 at positions 241-242
# <re.Match object; span=(242, 243), match='5'>
# Match found: 5 at positions 242-243
# <re.Match object; span=(244, 245), match='4'>
# Match found: 4 at positions 244-245
# <re.Match object; span=(245, 246), match='3'>
# Match found: 3 at positions 245-246
# <re.Match object; span=(246, 247), match='2'>
# Match found: 2 at positions 246-247
# <re.Match object; span=(247, 248), match='1'>
# Match found: 1 at positions 247-248
# <re.Match object; span=(249, 250), match='1'>
# Match found: 1 at positions 249-250
# <re.Match object; span=(250, 251), match='2'>
# Match found: 2 at positions 250-251
# <re.Match object; span=(251, 252), match='3'>
# Match found: 3 at positions 251-252
# <re.Match object; span=(253, 254), match='5'>
# Match found: 5 at positions 253-254
# <re.Match object; span=(254, 255), match='5'>
# Match found: 5 at positions 254-255
# <re.Match object; span=(255, 256), match='5'>
# Match found: 5 at positions 255-256
# <re.Match object; span=(257, 258), match='1'>
# Match found: 1 at positions 257-258
# <re.Match object; span=(258, 259), match='2'>
# Match found: 2 at positions 258-259
# <re.Match object; span=(259, 260), match='3'>
# Match found: 3 at positions 259-260
# <re.Match object; span=(260, 261), match='4'>
# Match found: 4 at positions 260-261
# <re.Match object; span=(262, 263), match='1'>
# Match found: 1 at positions 262-263
# <re.Match object; span=(263, 264), match='2'>
# Match found: 2 at positions 263-264
# <re.Match object; span=(264, 265), match='3'>
# Match found: 3 at positions 264-265
# <re.Match object; span=(266, 267), match='5'>
# Match found: 5 at positions 266-267
# <re.Match object; span=(267, 268), match='5'>
# Match found: 5 at positions 267-268
# <re.Match object; span=(268, 269), match='5'>
# Match found: 5 at positions 268-269
# <re.Match object; span=(270, 271), match='1'>
# Match found: 1 at positions 270-271
# <re.Match object; span=(271, 272), match='2'>
# Match found: 2 at positions 271-272
# <re.Match object; span=(272, 273), match='3'>
# Match found: 3 at positions 272-273
# <re.Match object; span=(273, 274), match='4'>
# Match found: 4 at positions 273-274
# <re.Match object; span=(279, 280), match='5'>
# Match found: 5 at positions 279-280
# <re.Match object; span=(280, 281), match='5'>
# Match found: 5 at positions 280-281
# <re.Match object; span=(281, 282), match='5'>
# Match found: 5 at positions 281-282
# <re.Match object; span=(283, 284), match='1'>
# Match found: 1 at positions 283-284
# <re.Match object; span=(284, 285), match='2'>
# Match found: 2 at positions 284-285
# <re.Match object; span=(285, 286), match='3'>
# Match found: 3 at positions 285-286
# <re.Match object; span=(286, 287), match='4'>
# Match found: 4 at positions 286-287
# <re.Match object; span=(292, 293), match='5'>
# Match found: 5 at positions 292-293
# <re.Match object; span=(293, 294), match='5'>
# Match found: 5 at positions 293-294
# <re.Match object; span=(294, 295), match='5'>
# Match found: 5 at positions 294-295
# <re.Match object; span=(296, 297), match='1'>
# Match found: 1 at positions 296-297
# <re.Match object; span=(297, 298), match='2'>
# Match found: 2 at positions 297-298
# <re.Match object; span=(298, 299), match='3'>
# Match found: 3 at positions 298-299
# <re.Match object; span=(299, 300), match='4'>
# Match found: 4 at positions 299-300
# <re.Match object; span=(304, 305), match='5'>
# Match found: 5 at positions 304-305
# <re.Match object; span=(305, 306), match='5'>
# Match found: 5 at positions 305-306
# <re.Match object; span=(306, 307), match='5'>
# Match found: 5 at positions 306-307
# <re.Match object; span=(307, 308), match='1'>
# Match found: 1 at positions 307-308
# <re.Match object; span=(308, 309), match='2'>
# Match found: 2 at positions 308-309
# <re.Match object; span=(309, 310), match='3'>
# Match found: 3 at positions 309-310
# <re.Match object; span=(310, 311), match='4'>
# Match found: 4 at positions 310-311
# <re.Match object; span=(316, 317), match='5'>
# Match found: 5 at positions 316-317
# <re.Match object; span=(317, 318), match='5'>
# Match found: 5 at positions 317-318
# <re.Match object; span=(318, 319), match='5'>
# Match found: 5 at positions 318-319
# <re.Match object; span=(320, 321), match='1'>
# Match found: 1 at positions 320-321
# <re.Match object; span=(321, 322), match='2'>
# Match found: 2 at positions 321-322
# <re.Match object; span=(322, 323), match='3'>
# Match found: 3 at positions 322-323
# <re.Match object; span=(323, 324), match='4'>
# Match found: 4 at positions 323-324
# <re.Match object; span=(333, 334), match='2'>
# Match found: 2 at positions 333-334

# %% [markdown]
# ### Para Mostrar letras mayúsculas y minúsculas, basta con poner los rangos juntos.

# %%
pattern = re.compile(r'[a-zA-Z]')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(1, 2), match='a'>
# Match found: a at positions 1-2
# <re.Match object; span=(2, 3), match='b'>
# Match found: b at positions 2-3
# <re.Match object; span=(3, 4), match='c'>
# Match found: c at positions 3-4
# <re.Match object; span=(4, 5), match='d'>
# Match found: d at positions 4-5
# <re.Match object; span=(5, 6), match='e'>
# Match found: e at positions 5-6
# <re.Match object; span=(6, 7), match='f'>
# Match found: f at positions 6-7
# <re.Match object; span=(7, 8), match='g'>
# Match found: g at positions 7-8
# <re.Match object; span=(8, 9), match='h'>
# Match found: h at positions 8-9
# <re.Match object; span=(9, 10), match='i'>
# Match found: i at positions 9-10
# <re.Match object; span=(10, 11), match='j'>
# Match found: j at positions 10-11
# <re.Match object; span=(11, 12), match='k'>
# Match found: k at positions 11-12
# <re.Match object; span=(12, 13), match='l'>
# Match found: l at positions 12-13
# <re.Match object; span=(13, 14), match='m'>
# Match found: m at positions 13-14
# <re.Match object; span=(14, 15), match='n'>
# Match found: n at positions 14-15
# <re.Match object; span=(15, 16), match='o'>
# Match found: o at positions 15-16
# <re.Match object; span=(16, 17), match='p'>
# Match found: p at positions 16-17
# <re.Match object; span=(17, 18), match='q'>
# Match found: q at positions 17-18
# <re.Match object; span=(18, 19), match='u'>
# Match found: u at positions 18-19
# <re.Match object; span=(19, 20), match='r'>
# Match found: r at positions 19-20
# <re.Match object; span=(20, 21), match='t'>
# Match found: t at positions 20-21
# <re.Match object; span=(21, 22), match='u'>
# Match found: u at positions 21-22
# <re.Match object; span=(22, 23), match='v'>
# Match found: v at positions 22-23
# <re.Match object; span=(23, 24), match='w'>
# Match found: w at positions 23-24
# <re.Match object; span=(24, 25), match='x'>
# Match found: x at positions 24-25
# <re.Match object; span=(25, 26), match='y'>
# Match found: y at positions 25-26
# <re.Match object; span=(26, 27), match='z'>
# Match found: z at positions 26-27
# <re.Match object; span=(28, 29), match='A'>
# Match found: A at positions 28-29
# <re.Match object; span=(29, 30), match='B'>
# Match found: B at positions 29-30
# <re.Match object; span=(30, 31), match='C'>
# Match found: C at positions 30-31
# <re.Match object; span=(31, 32), match='D'>
# Match found: D at positions 31-32
# <re.Match object; span=(32, 33), match='E'>
# Match found: E at positions 32-33
# <re.Match object; span=(33, 34), match='F'>
# Match found: F at positions 33-34
# <re.Match object; span=(34, 35), match='G'>
# Match found: G at positions 34-35
# <re.Match object; span=(35, 36), match='H'>
# Match found: H at positions 35-36
# <re.Match object; span=(36, 37), match='I'>
# Match found: I at positions 36-37
# <re.Match object; span=(37, 38), match='J'>
# Match found: J at positions 37-38
# <re.Match object; span=(38, 39), match='K'>
# Match found: K at positions 38-39
# <re.Match object; span=(39, 40), match='L'>
# Match found: L at positions 39-40
# <re.Match object; span=(40, 41), match='M'>
# Match found: M at positions 40-41
# <re.Match object; span=(41, 42), match='N'>
# Match found: N at positions 41-42
# <re.Match object; span=(42, 43), match='O'>
# Match found: O at positions 42-43
# <re.Match object; span=(43, 44), match='P'>
# Match found: P at positions 43-44
# <re.Match object; span=(44, 45), match='Q'>
# Match found: Q at positions 44-45
# <re.Match object; span=(45, 46), match='R'>
# Match found: R at positions 45-46
# <re.Match object; span=(46, 47), match='S'>
# Match found: S at positions 46-47
# <re.Match object; span=(47, 48), match='T'>
# Match found: T at positions 47-48
# <re.Match object; span=(48, 49), match='U'>
# Match found: U at positions 48-49
# <re.Match object; span=(49, 50), match='V'>
# Match found: V at positions 49-50
# <re.Match object; span=(50, 51), match='W'>
# Match found: W at positions 50-51
# <re.Match object; span=(51, 52), match='X'>
# Match found: X at positions 51-52
# <re.Match object; span=(52, 53), match='Y'>
# Match found: Y at positions 52-53
# <re.Match object; span=(53, 54), match='Z'>
# Match found: Z at positions 53-54
# <re.Match object; span=(66, 67), match='H'>
# Match found: H at positions 66-67
# <re.Match object; span=(67, 68), match='a'>
# Match found: a at positions 67-68
# <re.Match object; span=(69, 70), match='H'>
# Match found: H at positions 69-70
# <re.Match object; span=(70, 71), match='a'>
# Match found: a at positions 70-71
# <re.Match object; span=(71, 72), match='H'>
# Match found: H at positions 71-72
# <re.Match object; span=(72, 73), match='a'>
# Match found: a at positions 72-73
# <re.Match object; span=(75, 76), match='H'>
# Match found: H at positions 75-76
# <re.Match object; span=(76, 77), match='a'>
# Match found: a at positions 76-77
# <re.Match object; span=(78, 79), match='M'>
# Match found: M at positions 78-79
# <re.Match object; span=(79, 80), match='e'>
# Match found: e at positions 79-80
# <re.Match object; span=(80, 81), match='t'>
# Match found: t at positions 80-81
# <re.Match object; span=(81, 82), match='a'>
# Match found: a at positions 81-82
# <re.Match object; span=(82, 83), match='C'>
# Match found: C at positions 82-83
# <re.Match object; span=(83, 84), match='h'>
# Match found: h at positions 83-84
# <re.Match object; span=(84, 85), match='a'>
# Match found: a at positions 84-85
# <re.Match object; span=(85, 86), match='r'>
# Match found: r at positions 85-86
# <re.Match object; span=(86, 87), match='a'>
# Match found: a at positions 86-87
# <re.Match object; span=(87, 88), match='c'>
# Match found: c at positions 87-88
# <re.Match object; span=(88, 89), match='t'>
# Match found: t at positions 88-89
# <re.Match object; span=(89, 90), match='e'>
# Match found: e at positions 89-90
# <re.Match object; span=(90, 91), match='r'>
# Match found: r at positions 90-91
# <re.Match object; span=(91, 92), match='s'>
# Match found: s at positions 91-92
# <re.Match object; span=(94, 95), match='N'>
# Match found: N at positions 94-95
# <re.Match object; span=(95, 96), match='e'>
# Match found: e at positions 95-96
# <re.Match object; span=(96, 97), match='e'>
# Match found: e at positions 96-97
# <re.Match object; span=(97, 98), match='d'>
# Match found: d at positions 97-98
# <re.Match object; span=(99, 100), match='t'>
# Match found: t at positions 99-100
# <re.Match object; span=(100, 101), match='o'>
# Match found: o at positions 100-101
# <re.Match object; span=(102, 103), match='b'>
# Match found: b at positions 102-103
# <re.Match object; span=(103, 104), match='e'>
# Match found: e at positions 103-104
# <re.Match object; span=(105, 106), match='e'>
# Match found: e at positions 105-106
# <re.Match object; span=(106, 107), match='s'>
# Match found: s at positions 106-107
# <re.Match object; span=(107, 108), match='c'>
# Match found: c at positions 107-108
# <re.Match object; span=(108, 109), match='a'>
# Match found: a at positions 108-109
# <re.Match object; span=(109, 110), match='p'>
# Match found: p at positions 109-110
# <re.Match object; span=(110, 111), match='e'>
# Match found: e at positions 110-111
# <re.Match object; span=(111, 112), match='d'>
# Match found: d at positions 111-112
# <re.Match object; span=(143, 144), match='h'>
# Match found: h at positions 143-144
# <re.Match object; span=(144, 145), match='e'>
# Match found: e at positions 144-145
# <re.Match object; span=(145, 146), match='g'>
# Match found: g at positions 145-146
# <re.Match object; span=(146, 147), match='o'>
# Match found: o at positions 146-147
# <re.Match object; span=(147, 148), match='i'>
# Match found: i at positions 147-148
# <re.Match object; span=(148, 149), match='g'>
# Match found: g at positions 148-149
# <re.Match object; span=(149, 150), match='a'>
# Match found: a at positions 149-150
# <re.Match object; span=(150, 151), match='r'>
# Match found: r at positions 150-151
# <re.Match object; span=(151, 152), match='i'>
# Match found: i at positions 151-152
# <re.Match object; span=(152, 153), match='t'>
# Match found: t at positions 152-153
# <re.Match object; span=(153, 154), match='a'>
# Match found: a at positions 153-154
# <re.Match object; span=(154, 155), match='o'>
# Match found: o at positions 154-155
# <re.Match object; span=(155, 156), match='n'>
# Match found: n at positions 155-156
# <re.Match object; span=(156, 157), match='a'>
# Match found: a at positions 156-157
# <re.Match object; span=(157, 158), match='n'>
# Match found: n at positions 157-158
# <re.Match object; span=(158, 159), match='d'>
# Match found: d at positions 158-159
# <re.Match object; span=(159, 160), match='i'>
# Match found: i at positions 159-160
# <re.Match object; span=(160, 161), match='a'>
# Match found: a at positions 160-161
# <re.Match object; span=(162, 163), match='c'>
# Match found: c at positions 162-163
# <re.Match object; span=(163, 164), match='o'>
# Match found: o at positions 163-164
# <re.Match object; span=(164, 165), match='m'>
# Match found: m at positions 164-165
# <re.Match object; span=(166, 167), match='h'>
# Match found: h at positions 166-167
# <re.Match object; span=(167, 168), match='e'>
# Match found: e at positions 167-168
# <re.Match object; span=(168, 169), match='g'>
# Match found: g at positions 168-169
# <re.Match object; span=(169, 170), match='o'>
# Match found: o at positions 169-170
# <re.Match object; span=(170, 171), match='i'>
# Match found: i at positions 170-171
# <re.Match object; span=(171, 172), match='g'>
# Match found: g at positions 171-172
# <re.Match object; span=(172, 173), match='a'>
# Match found: a at positions 172-173
# <re.Match object; span=(173, 174), match='r'>
# Match found: r at positions 173-174
# <re.Match object; span=(174, 175), match='i'>
# Match found: i at positions 174-175
# <re.Match object; span=(175, 176), match='t'>
# Match found: t at positions 175-176
# <re.Match object; span=(176, 177), match='a'>
# Match found: a at positions 176-177
# <re.Match object; span=(177, 178), match='o'>
# Match found: o at positions 177-178
# <re.Match object; span=(178, 179), match='n'>
# Match found: n at positions 178-179
# <re.Match object; span=(179, 180), match='a'>
# Match found: a at positions 179-180
# <re.Match object; span=(180, 181), match='n'>
# Match found: n at positions 180-181
# <re.Match object; span=(181, 182), match='d'>
# Match found: d at positions 181-182
# <re.Match object; span=(182, 183), match='i'>
# Match found: i at positions 182-183
# <re.Match object; span=(183, 184), match='a'>
# Match found: a at positions 183-184
# <re.Match object; span=(185, 186), match='c'>
# Match found: c at positions 185-186
# <re.Match object; span=(186, 187), match='o'>
# Match found: o at positions 186-187
# <re.Match object; span=(187, 188), match='m'>
# Match found: m at positions 187-188
# <re.Match object; span=(189, 190), match='h'>
# Match found: h at positions 189-190
# <re.Match object; span=(190, 191), match='e'>
# Match found: e at positions 190-191
# <re.Match object; span=(191, 192), match='g'>
# Match found: g at positions 191-192
# <re.Match object; span=(192, 193), match='o'>
# Match found: o at positions 192-193
# <re.Match object; span=(193, 194), match='i'>
# Match found: i at positions 193-194
# <re.Match object; span=(194, 195), match='g'>
# Match found: g at positions 194-195
# <re.Match object; span=(195, 196), match='a'>
# Match found: a at positions 195-196
# <re.Match object; span=(196, 197), match='r'>
# Match found: r at positions 196-197
# <re.Match object; span=(197, 198), match='i'>
# Match found: i at positions 197-198
# <re.Match object; span=(198, 199), match='t'>
# Match found: t at positions 198-199
# <re.Match object; span=(199, 200), match='a'>
# Match found: a at positions 199-200
# <re.Match object; span=(200, 201), match='o'>
# Match found: o at positions 200-201
# <re.Match object; span=(201, 202), match='n'>
# Match found: n at positions 201-202
# <re.Match object; span=(202, 203), match='a'>
# Match found: a at positions 202-203
# <re.Match object; span=(203, 204), match='n'>
# Match found: n at positions 203-204
# <re.Match object; span=(204, 205), match='d'>
# Match found: d at positions 204-205
# <re.Match object; span=(205, 206), match='i'>
# Match found: i at positions 205-206
# <re.Match object; span=(206, 207), match='a'>
# Match found: a at positions 206-207
# <re.Match object; span=(207, 208), match='c'>
# Match found: c at positions 207-208
# <re.Match object; span=(208, 209), match='o'>
# Match found: o at positions 208-209
# <re.Match object; span=(209, 210), match='m'>
# Match found: m at positions 209-210
# <re.Match object; span=(211, 212), match='h'>
# Match found: h at positions 211-212
# <re.Match object; span=(212, 213), match='e'>
# Match found: e at positions 212-213
# <re.Match object; span=(213, 214), match='g'>
# Match found: g at positions 213-214
# <re.Match object; span=(214, 215), match='o'>
# Match found: o at positions 214-215
# <re.Match object; span=(215, 216), match='i'>
# Match found: i at positions 215-216
# <re.Match object; span=(216, 217), match='g'>
# Match found: g at positions 216-217
# <re.Match object; span=(217, 218), match='a'>
# Match found: a at positions 217-218
# <re.Match object; span=(218, 219), match='r'>
# Match found: r at positions 218-219
# <re.Match object; span=(219, 220), match='i'>
# Match found: i at positions 219-220
# <re.Match object; span=(220, 221), match='t'>
# Match found: t at positions 220-221
# <re.Match object; span=(221, 222), match='a'>
# Match found: a at positions 221-222
# <re.Match object; span=(222, 223), match='o'>
# Match found: o at positions 222-223
# <re.Match object; span=(223, 224), match='n'>
# Match found: n at positions 223-224
# <re.Match object; span=(224, 225), match='a'>
# Match found: a at positions 224-225
# <re.Match object; span=(225, 226), match='n'>
# Match found: n at positions 225-226
# <re.Match object; span=(226, 227), match='d'>
# Match found: d at positions 226-227
# <re.Match object; span=(227, 228), match='i'>
# Match found: i at positions 227-228
# <re.Match object; span=(228, 229), match='a'>
# Match found: a at positions 228-229
# <re.Match object; span=(230, 231), match='h'>
# Match found: h at positions 230-231
# <re.Match object; span=(231, 232), match='o'>
# Match found: o at positions 231-232
# <re.Match object; span=(232, 233), match='l'>
# Match found: l at positions 232-233
# <re.Match object; span=(233, 234), match='a'>
# Match found: a at positions 233-234
# <re.Match object; span=(325, 326), match='M'>
# Match found: M at positions 325-326
# <re.Match object; span=(326, 327), match='r'>
# Match found: r at positions 326-327
# <re.Match object; span=(329, 330), match='S'>
# Match found: S at positions 329-330
# <re.Match object; span=(330, 331), match='c'>
# Match found: c at positions 330-331
# <re.Match object; span=(331, 332), match='h'>
# Match found: h at positions 331-332
# <re.Match object; span=(332, 333), match='a'>
# Match found: a at positions 332-333
# <re.Match object; span=(334, 335), match='f'>
# Match found: f at positions 334-335
# <re.Match object; span=(335, 336), match='e'>
# Match found: e at positions 335-336
# <re.Match object; span=(336, 337), match='r'>
# Match found: r at positions 336-337
# <re.Match object; span=(338, 339), match='M'>
# Match found: M at positions 338-339
# <re.Match object; span=(339, 340), match='r'>
# Match found: r at positions 339-340
# <re.Match object; span=(341, 342), match='S'>
# Match found: S at positions 341-342
# <re.Match object; span=(342, 343), match='m'>
# Match found: m at positions 342-343
# <re.Match object; span=(343, 344), match='i'>
# Match found: i at positions 343-344
# <re.Match object; span=(344, 345), match='t'>
# Match found: t at positions 344-345
# <re.Match object; span=(345, 346), match='h'>
# Match found: h at positions 345-346
# <re.Match object; span=(347, 348), match='M'>
# Match found: M at positions 347-348
# <re.Match object; span=(348, 349), match='s'>
# Match found: s at positions 348-349
# <re.Match object; span=(350, 351), match='D'>
# Match found: D at positions 350-351
# <re.Match object; span=(351, 352), match='a'>
# Match found: a at positions 351-352
# <re.Match object; span=(352, 353), match='v'>
# Match found: v at positions 352-353
# <re.Match object; span=(353, 354), match='i'>
# Match found: i at positions 353-354
# <re.Match object; span=(354, 355), match='s'>
# Match found: s at positions 354-355
# <re.Match object; span=(356, 357), match='M'>
# Match found: M at positions 356-357
# <re.Match object; span=(357, 358), match='r'>
# Match found: r at positions 357-358
# <re.Match object; span=(358, 359), match='s'>
# Match found: s at positions 358-359
# <re.Match object; span=(361, 362), match='R'>
# Match found: R at positions 361-362
# <re.Match object; span=(362, 363), match='o'>
# Match found: o at positions 362-363
# <re.Match object; span=(363, 364), match='b'>
# Match found: b at positions 363-364
# <re.Match object; span=(364, 365), match='i'>
# Match found: i at positions 364-365
# <re.Match object; span=(365, 366), match='n'>
# Match found: n at positions 365-366
# <re.Match object; span=(366, 367), match='s'>
# Match found: s at positions 366-367
# <re.Match object; span=(367, 368), match='o'>
# Match found: o at positions 367-368
# <re.Match object; span=(368, 369), match='n'>
# Match found: n at positions 368-369
# <re.Match object; span=(370, 371), match='M'>
# Match found: M at positions 370-371
# <re.Match object; span=(371, 372), match='r'>
# Match found: r at positions 371-372
# <re.Match object; span=(374, 375), match='T'>
# Match found: T at positions 374-375
# <re.Match object; span=(376, 377), match='M'>
# Match found: M at positions 376-377
# <re.Match object; span=(377, 378), match='r'>
# Match found: r at positions 377-378
# <re.Match object; span=(384, 385), match='c'>
# Match found: c at positions 384-385
# <re.Match object; span=(385, 386), match='a'>
# Match found: a at positions 385-386
# <re.Match object; span=(386, 387), match='t'>
# Match found: t at positions 386-387
# <re.Match object; span=(388, 389), match='m'>
# Match found: m at positions 388-389
# <re.Match object; span=(389, 390), match='a'>
# Match found: a at positions 389-390
# <re.Match object; span=(390, 391), match='t'>
# Match found: t at positions 390-391
# <re.Match object; span=(392, 393), match='p'>
# Match found: p at positions 392-393
# <re.Match object; span=(393, 394), match='a'>
# Match found: a at positions 393-394
# <re.Match object; span=(394, 395), match='t'>
# Match found: t at positions 394-395
# <re.Match object; span=(396, 397), match='b'>
# Match found: b at positions 396-397
# <re.Match object; span=(397, 398), match='a'>
# Match found: a at positions 397-398
# <re.Match object; span=(398, 399), match='t'>
# Match found: t at positions 398-399
# <re.Match object; span=(401, 402), match='a'>
# Match found: a at positions 401-402
# <re.Match object; span=(402, 403), match='t'>
# Match found: t at positions 402-403

# %% [markdown]
# ## Importante
# Al poner el símbolo `^` dentro de los corchetes `[]`, significa que **NO** queremos lo que está dentro de él.
#
# En este caso, al ejecutar, se muestran solo los caracteres numéricos, los espacios en blanco, los saltos de línea y los caracteres numéricos.
#
# **Se niega el set**

# %%
pattern = re.compile(r'[^a-zA-Z]')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# Match found:
#  at positions 0-1
# <re.Match object; span=(27, 28), match='\n'>
# Match found:
#  at positions 27-28
# <re.Match object; span=(54, 55), match='\n'>
# Match found:
#  at positions 54-55
# <re.Match object; span=(55, 56), match='1'>
# Match found: 1 at positions 55-56
# <re.Match object; span=(56, 57), match='2'>
# Match found: 2 at positions 56-57
# <re.Match object; span=(57, 58), match='3'>
# Match found: 3 at positions 57-58
# <re.Match object; span=(58, 59), match='4'>
# Match found: 4 at positions 58-59
# <re.Match object; span=(59, 60), match='5'>
# Match found: 5 at positions 59-60
# <re.Match object; span=(60, 61), match='6'>
# Match found: 6 at positions 60-61
# <re.Match object; span=(61, 62), match='7'>
# Match found: 7 at positions 61-62
# <re.Match object; span=(62, 63), match='8'>
# Match found: 8 at positions 62-63
# <re.Match object; span=(63, 64), match='9'>
# Match found: 9 at positions 63-64
# <re.Match object; span=(64, 65), match='0'>
# Match found: 0 at positions 64-65
# <re.Match object; span=(65, 66), match='\n'>
# Match found:
#  at positions 65-66
# <re.Match object; span=(68, 69), match=' '>
# Match found:   at positions 68-69
# <re.Match object; span=(73, 74), match=' '>
# Match found:   at positions 73-74
# <re.Match object; span=(74, 75), match='?'>
# Match found: ? at positions 74-75
# <re.Match object; span=(77, 78), match='\n'>
# Match found:
#  at positions 77-78
# <re.Match object; span=(92, 93), match=' '>
# Match found:   at positions 92-93
# <re.Match object; span=(93, 94), match='('>
# Match found: ( at positions 93-94
# <re.Match object; span=(98, 99), match=' '>
# Match found:   at positions 98-99
# <re.Match object; span=(101, 102), match=' '>
# Match found:   at positions 101-102
# <re.Match object; span=(104, 105), match=' '>
# Match found:   at positions 104-105
# <re.Match object; span=(112, 113), match=')'>
# Match found: ) at positions 112-113
# <re.Match object; span=(113, 114), match=':'>
# Match found: : at positions 113-114
# <re.Match object; span=(114, 115), match='\n'>
# Match found:
#  at positions 114-115
# <re.Match object; span=(115, 116), match='.'>
# Match found: . at positions 115-116
# <re.Match object; span=(116, 117), match=' '>
# Match found:   at positions 116-117
# <re.Match object; span=(117, 118), match='^'>
# Match found: ^ at positions 117-118
# <re.Match object; span=(118, 119), match=' '>
# Match found:   at positions 118-119
# <re.Match object; span=(119, 120), match='$'>
# Match found: $ at positions 119-120
# <re.Match object; span=(120, 121), match=' '>
# Match found:   at positions 120-121
# <re.Match object; span=(121, 122), match='*'>
# Match found: * at positions 121-122
# <re.Match object; span=(122, 123), match=' '>
# Match found:   at positions 122-123
# <re.Match object; span=(123, 124), match='+'>
# Match found: + at positions 123-124
# <re.Match object; span=(124, 125), match=' '>
# Match found:   at positions 124-125
# <re.Match object; span=(125, 126), match='?'>
# Match found: ? at positions 125-126
# <re.Match object; span=(126, 127), match=' '>
# Match found:   at positions 126-127
# <re.Match object; span=(127, 128), match='{'>
# Match found: { at positions 127-128
# <re.Match object; span=(128, 129), match=' '>
# Match found:   at positions 128-129
# <re.Match object; span=(129, 130), match='}'>
# Match found: } at positions 129-130
# <re.Match object; span=(130, 131), match=' '>
# Match found:   at positions 130-131
# <re.Match object; span=(131, 132), match='['>
# Match found: [ at positions 131-132
# <re.Match object; span=(132, 133), match=' '>
# Match found:   at positions 132-133
# <re.Match object; span=(133, 134), match=']'>
# Match found: ] at positions 133-134
# <re.Match object; span=(134, 135), match=' '>
# Match found:   at positions 134-135
# <re.Match object; span=(135, 136), match='\\'>
# Match found: \ at positions 135-136
# <re.Match object; span=(136, 137), match=' '>
# Match found:   at positions 136-137
# <re.Match object; span=(137, 138), match='|'>
# Match found: | at positions 137-138
# <re.Match object; span=(138, 139), match=' '>
# Match found:   at positions 138-139
# <re.Match object; span=(139, 140), match='('>
# Match found: ( at positions 139-140
# <re.Match object; span=(140, 141), match=' '>
# Match found:   at positions 140-141
# <re.Match object; span=(141, 142), match=')'>
# Match found: ) at positions 141-142
# <re.Match object; span=(142, 143), match='\n'>
# Match found:
#  at positions 142-143
# <re.Match object; span=(161, 162), match='*'>
# Match found: * at positions 161-162
# <re.Match object; span=(165, 166), match='\n'>
# Match found:
#  at positions 165-166
# <re.Match object; span=(184, 185), match='.'>
# Match found: . at positions 184-185
# <re.Match object; span=(188, 189), match='\n'>
# Match found:
#  at positions 188-189
# <re.Match object; span=(210, 211), match='\n'>
# Match found:
#  at positions 210-211
# <re.Match object; span=(229, 230), match=' '>
# Match found:   at positions 229-230
# <re.Match object; span=(234, 235), match='\n'>
# Match found:
#  at positions 234-235
# <re.Match object; span=(235, 236), match='3'>
# Match found: 3 at positions 235-236
# <re.Match object; span=(236, 237), match='2'>
# Match found: 2 at positions 236-237
# <re.Match object; span=(237, 238), match='1'>
# Match found: 1 at positions 237-238
# <re.Match object; span=(238, 239), match='-'>
# Match found: - at positions 238-239
# <re.Match object; span=(239, 240), match='-'>
# Match found: - at positions 239-240
# <re.Match object; span=(240, 241), match='5'>
# Match found: 5 at positions 240-241
# <re.Match object; span=(241, 242), match='5'>
# Match found: 5 at positions 241-242
# <re.Match object; span=(242, 243), match='5'>
# Match found: 5 at positions 242-243
# <re.Match object; span=(243, 244), match='-'>
# Match found: - at positions 243-244
# <re.Match object; span=(244, 245), match='4'>
# Match found: 4 at positions 244-245
# <re.Match object; span=(245, 246), match='3'>
# Match found: 3 at positions 245-246
# <re.Match object; span=(246, 247), match='2'>
# Match found: 2 at positions 246-247
# <re.Match object; span=(247, 248), match='1'>
# Match found: 1 at positions 247-248
# <re.Match object; span=(248, 249), match='\n'>
# Match found:
#  at positions 248-249
# <re.Match object; span=(249, 250), match='1'>
# Match found: 1 at positions 249-250
# <re.Match object; span=(250, 251), match='2'>
# Match found: 2 at positions 250-251
# <re.Match object; span=(251, 252), match='3'>
# Match found: 3 at positions 251-252
# <re.Match object; span=(252, 253), match='.'>
# Match found: . at positions 252-253
# <re.Match object; span=(253, 254), match='5'>
# Match found: 5 at positions 253-254
# <re.Match object; span=(254, 255), match='5'>
# Match found: 5 at positions 254-255
# <re.Match object; span=(255, 256), match='5'>
# Match found: 5 at positions 255-256
# <re.Match object; span=(256, 257), match='.'>
# Match found: . at positions 256-257
# <re.Match object; span=(257, 258), match='1'>
# Match found: 1 at positions 257-258
# <re.Match object; span=(258, 259), match='2'>
# Match found: 2 at positions 258-259
# <re.Match object; span=(259, 260), match='3'>
# Match found: 3 at positions 259-260
# <re.Match object; span=(260, 261), match='4'>
# Match found: 4 at positions 260-261
# <re.Match object; span=(261, 262), match='\n'>
# Match found:
#  at positions 261-262
# <re.Match object; span=(262, 263), match='1'>
# Match found: 1 at positions 262-263
# <re.Match object; span=(263, 264), match='2'>
# Match found: 2 at positions 263-264
# <re.Match object; span=(264, 265), match='3'>
# Match found: 3 at positions 264-265
# <re.Match object; span=(265, 266), match='*'>
# Match found: * at positions 265-266
# <re.Match object; span=(266, 267), match='5'>
# Match found: 5 at positions 266-267
# <re.Match object; span=(267, 268), match='5'>
# Match found: 5 at positions 267-268
# <re.Match object; span=(268, 269), match='5'>
# Match found: 5 at positions 268-269
# <re.Match object; span=(269, 270), match='*'>
# Match found: * at positions 269-270
# <re.Match object; span=(270, 271), match='1'>
# Match found: 1 at positions 270-271
# <re.Match object; span=(271, 272), match='2'>
# Match found: 2 at positions 271-272
# <re.Match object; span=(272, 273), match='3'>
# Match found: 3 at positions 272-273
# <re.Match object; span=(273, 274), match='4'>
# Match found: 4 at positions 273-274
# <re.Match object; span=(274, 275), match='\n'>
# Match found:
#  at positions 274-275
# <re.Match object; span=(275, 276), match='8'>
# Match found: 8 at positions 275-276
# <re.Match object; span=(276, 277), match='0'>
# Match found: 0 at positions 276-277
# <re.Match object; span=(277, 278), match='0'>
# Match found: 0 at positions 277-278
# <re.Match object; span=(278, 279), match='-'>
# Match found: - at positions 278-279
# <re.Match object; span=(279, 280), match='5'>
# Match found: 5 at positions 279-280
# <re.Match object; span=(280, 281), match='5'>
# Match found: 5 at positions 280-281
# <re.Match object; span=(281, 282), match='5'>
# Match found: 5 at positions 281-282
# <re.Match object; span=(282, 283), match='-'>
# Match found: - at positions 282-283
# <re.Match object; span=(283, 284), match='1'>
# Match found: 1 at positions 283-284
# <re.Match object; span=(284, 285), match='2'>
# Match found: 2 at positions 284-285
# <re.Match object; span=(285, 286), match='3'>
# Match found: 3 at positions 285-286
# <re.Match object; span=(286, 287), match='4'>
# Match found: 4 at positions 286-287
# <re.Match object; span=(287, 288), match='\n'>
# Match found:
#  at positions 287-288
# <re.Match object; span=(288, 289), match='9'>
# Match found: 9 at positions 288-289
# <re.Match object; span=(289, 290), match='0'>
# Match found: 0 at positions 289-290
# <re.Match object; span=(290, 291), match='0'>
# Match found: 0 at positions 290-291
# <re.Match object; span=(291, 292), match='-'>
# Match found: - at positions 291-292
# <re.Match object; span=(292, 293), match='5'>
# Match found: 5 at positions 292-293
# <re.Match object; span=(293, 294), match='5'>
# Match found: 5 at positions 293-294
# <re.Match object; span=(294, 295), match='5'>
# Match found: 5 at positions 294-295
# <re.Match object; span=(295, 296), match='-'>
# Match found: - at positions 295-296
# <re.Match object; span=(296, 297), match='1'>
# Match found: 1 at positions 296-297
# <re.Match object; span=(297, 298), match='2'>
# Match found: 2 at positions 297-298
# <re.Match object; span=(298, 299), match='3'>
# Match found: 3 at positions 298-299
# <re.Match object; span=(299, 300), match='4'>
# Match found: 4 at positions 299-300
# <re.Match object; span=(300, 301), match='\n'>
# Match found:
#  at positions 300-301
# <re.Match object; span=(301, 302), match='9'>
# Match found: 9 at positions 301-302
# <re.Match object; span=(302, 303), match='0'>
# Match found: 0 at positions 302-303
# <re.Match object; span=(303, 304), match='0'>
# Match found: 0 at positions 303-304
# <re.Match object; span=(304, 305), match='5'>
# Match found: 5 at positions 304-305
# <re.Match object; span=(305, 306), match='5'>
# Match found: 5 at positions 305-306
# <re.Match object; span=(306, 307), match='5'>
# Match found: 5 at positions 306-307
# <re.Match object; span=(307, 308), match='1'>
# Match found: 1 at positions 307-308
# <re.Match object; span=(308, 309), match='2'>
# Match found: 2 at positions 308-309
# <re.Match object; span=(309, 310), match='3'>
# Match found: 3 at positions 309-310
# <re.Match object; span=(310, 311), match='4'>
# Match found: 4 at positions 310-311
# <re.Match object; span=(311, 312), match='\n'>
# Match found:
#  at positions 311-312
# <re.Match object; span=(312, 313), match='9'>
# Match found: 9 at positions 312-313
# <re.Match object; span=(313, 314), match='0'>
# Match found: 0 at positions 313-314
# <re.Match object; span=(314, 315), match='0'>
# Match found: 0 at positions 314-315
# <re.Match object; span=(315, 316), match='0'>
# Match found: 0 at positions 315-316
# <re.Match object; span=(316, 317), match='5'>
# Match found: 5 at positions 316-317
# <re.Match object; span=(317, 318), match='5'>
# Match found: 5 at positions 317-318
# <re.Match object; span=(318, 319), match='5'>
# Match found: 5 at positions 318-319
# <re.Match object; span=(319, 320), match='0'>
# Match found: 0 at positions 319-320
# <re.Match object; span=(320, 321), match='1'>
# Match found: 1 at positions 320-321
# <re.Match object; span=(321, 322), match='2'>
# Match found: 2 at positions 321-322
# <re.Match object; span=(322, 323), match='3'>
# Match found: 3 at positions 322-323
# <re.Match object; span=(323, 324), match='4'>
# Match found: 4 at positions 323-324
# <re.Match object; span=(324, 325), match='\n'>
# Match found:
#  at positions 324-325
# <re.Match object; span=(327, 328), match='.'>
# Match found: . at positions 327-328
# <re.Match object; span=(328, 329), match=' '>
# Match found:   at positions 328-329
# <re.Match object; span=(333, 334), match='2'>
# Match found: 2 at positions 333-334
# <re.Match object; span=(337, 338), match='\n'>
# Match found:
#  at positions 337-338
# <re.Match object; span=(340, 341), match=' '>
# Match found:   at positions 340-341
# <re.Match object; span=(346, 347), match='\n'>
# Match found:
#  at positions 346-347
# <re.Match object; span=(349, 350), match=' '>
# Match found:   at positions 349-350
# <re.Match object; span=(355, 356), match='\n'>
# Match found:
#  at positions 355-356
# <re.Match object; span=(359, 360), match='.'>
# Match found: . at positions 359-360
# <re.Match object; span=(360, 361), match=' '>
# Match found:   at positions 360-361
# <re.Match object; span=(369, 370), match='\n'>
# Match found:
#  at positions 369-370
# <re.Match object; span=(372, 373), match='.'>
# Match found: . at positions 372-373
# <re.Match object; span=(373, 374), match=' '>
# Match found:   at positions 373-374
# <re.Match object; span=(375, 376), match='\n'>
# Match found:
#  at positions 375-376
# <re.Match object; span=(378, 379), match='.'>
# Match found: . at positions 378-379
# <re.Match object; span=(379, 380), match=' '>
# Match found:   at positions 379-380
# <re.Match object; span=(380, 381), match='('>
# Match found: ( at positions 380-381
# <re.Match object; span=(381, 382), match=')'>
# Match found: ) at positions 381-382
# <re.Match object; span=(382, 383), match='\n'>
# Match found:
#  at positions 382-383
# <re.Match object; span=(383, 384), match='\n'>
# Match found:
#  at positions 383-384
# <re.Match object; span=(387, 388), match='\n'>
# Match found:
#  at positions 387-388
# <re.Match object; span=(391, 392), match='\n'>
# Match found:
#  at positions 391-392
# <re.Match object; span=(395, 396), match='\n'>
# Match found:
#  at positions 395-396
# <re.Match object; span=(399, 400), match=' '>
# Match found:   at positions 399-400
# <re.Match object; span=(400, 401), match='\n'>
# Match found:
#  at positions 400-401
# <re.Match object; span=(403, 404), match='\n'>
# Match found:
#  at positions 403-404

# %% [markdown]
# ## Búsquedas de patrones en los textos
# Pongamos que queremos recoger palabras terminadas en at, excepto **bat**
# Especificamos que no queremos los valores que empiecen por b

# %%
pattern = re.compile(r'[^b\s]at')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(384, 387), match='cat'>
# Match found: cat at positions 384-387
# <re.Match object; span=(388, 391), match='mat'>
# Match found: mat at positions 388-391
# <re.Match object; span=(392, 395), match='pat'>
# Match found: pat at positions 392-395

# %% [markdown]
# ## Rangos `{}`
# Como vemos en snippets.txt, las llaves nos permiten establecer rangos.
#
# Volviendo al ejemplo de los números de teléfono, otra forma de obtener los patrones

# %%
pattern = re.compile(r'\d{3}\D\d{3}\D\d{4}')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(249, 261), match='123.555.1234'>
# Match found: 123.555.1234 at positions 249-261
# <re.Match object; span=(262, 274), match='123*555*1234'>
# Match found: 123*555*1234 at positions 262-274
# <re.Match object; span=(275, 287), match='800-555-1234'>
# Match found: 800-555-1234 at positions 275-287
# <re.Match object; span=(288, 300), match='900-555-1234'>
# Match found: 900-555-1234 at positions 288-300

# %%
pattern = re.compile(r'\d{2,4}\D\d{2,4}\D\d{2,4}')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(240, 252), match='555-4321\n123'>
# Match found: 555-4321
# 123 at positions 240-252
# <re.Match object; span=(253, 265), match='555.1234\n123'>
# Match found: 555.1234
# 123 at positions 253-265
# <re.Match object; span=(266, 278), match='555*1234\n800'>
# Match found: 555*1234
# 800 at positions 266-278
# <re.Match object; span=(279, 291), match='555-1234\n900'>
# Match found: 555-1234
# 900 at positions 279-291
# <re.Match object; span=(292, 305), match='555-1234\n9005'>
# Match found: 555-1234
# 9005 at positions 292-305

# %%
## Este ejemplo nos vale porque sabemos exactamente el patrón que se reproduce.

pattern1 = re.compile(r'Mr\.')

matches = pattern1.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")


# Aquí no nos está dando lo que queremos. Solo nos da la secuencia Mr.
# Out:
# <re.Match object; span=(325, 328), match='Mr.'>
# Match found: Mr. at positions 325-328
# <re.Match object; span=(370, 373), match='Mr.'>
# Match found: Mr. at positions 370-373
# <re.Match object; span=(376, 379), match='Mr.'>
# Match found: Mr. at positions 376-379

# %% [markdown]
# ## Operador `?`
# Nos sirve para añadir 0 o 1 a nuestra selección. Así se va a contemplar lo que hay un espacio después

# %%
# Aquí sí aparecen todos los Mr. independientemente de que tengan punto o no
pattern2 = re.compile(r'Mr\.?')

matches = pattern2.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(325, 328), match='Mr.'>
# Match found: Mr. at positions 325-328
# <re.Match object; span=(338, 340), match='Mr'>
# Match found: Mr at positions 338-340
# <re.Match object; span=(356, 358), match='Mr'>
# Match found: Mr at positions 356-358
# <re.Match object; span=(370, 373), match='Mr.'>
# Match found: Mr. at positions 370-373
# <re.Match object; span=(376, 379), match='Mr.'>
# Match found: Mr. at positions 376-379

# %%
# Aquí sí aparecen todos los Mr. independientemente de que tengan punto o no
pattern3 = re.compile(r'Mr\.?\s\w+') # El operador + muestra si hay 1 elemento o más 

matches = pattern3.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")

# Por eso no se imprime Mr. T
# Out:
# <re.Match object; span=(325, 337), match='Mr. Scha2fer'>
# Match found: Mr. Scha2fer at positions 325-337
# <re.Match object; span=(338, 346), match='Mr Smith'>
# Match found: Mr Smith at positions 338-346
# <re.Match object; span=(370, 375), match='Mr. T'>
# Match found: Mr. T at positions 370-375

# %% [markdown]
# ## Ahora sí que sí
# para mostrarlo todo , utilizaremos el cuantificador `*`

# %%
pattern4 = re.compile(r'Mr\.?\s\w*')

matches = pattern4.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(325, 337), match='Mr. Scha2fer'>
# Match found: Mr. Scha2fer at positions 325-337
# <re.Match object; span=(338, 346), match='Mr Smith'>
# Match found: Mr Smith at positions 338-346
# <re.Match object; span=(370, 375), match='Mr. T'>
# Match found: Mr. T at positions 370-375
# <re.Match object; span=(376, 380), match='Mr. '>
# Match found: Mr.  at positions 376-380

# %% [markdown]
# ## Grouping `()`
# Siguiendo con el ejemplo, para ver todos los Mr, Ms y Mrs, podemos utilizar el operador | (or)

# %%
pattern4 = re.compile(r'(Mr|Ms|Mrs)\.?\s\w*')

matches = pattern4.finditer(text_to_search)

for match in matches:
    print(match)
    print(f"Match found: {match.group()} at positions {match.start()}-{match.end()}")
# Out:
# <re.Match object; span=(325, 337), match='Mr. Scha2fer'>
# Match found: Mr. Scha2fer at positions 325-337
# <re.Match object; span=(338, 346), match='Mr Smith'>
# Match found: Mr Smith at positions 338-346
# <re.Match object; span=(347, 355), match='Ms Davis'>
# Match found: Ms Davis at positions 347-355
# <re.Match object; span=(356, 369), match='Mrs. Robinson'>
# Match found: Mrs. Robinson at positions 356-369
# <re.Match object; span=(370, 375), match='Mr. T'>
# Match found: Mr. T at positions 370-375
# <re.Match object; span=(376, 380), match='Mr. '>
# Match found: Mr.  at positions 376-380
