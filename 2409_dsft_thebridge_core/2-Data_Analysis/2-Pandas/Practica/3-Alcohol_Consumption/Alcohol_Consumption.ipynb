# %% [markdown]
# # Ex - GroupBy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"

drinks = pd.read_csv(url)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby("continent")['beer_servings'].mean().idxmax()
# Out:
# 'EU'

# %%
drinks.groupby("continent")['beer_servings'].mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# 84                        Jamaica             82               97
# 109                        Mexico            238               68
# 122                     Nicaragua             78              118
# 130                        Panama            285              104
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 5               45                           4.9       NaN
# 11              51                           6.3       NaN
# 14              36                           6.3       NaN
# 17               8                           6.8       NaN
# 32             100                           8.2       NaN
# 41              11                           4.4       NaN
# 43               5                           4.2       NaN
# 50              26                           6.6       NaN
# 51               9                           6.2       NaN
# 54               2                           2.2       NaN
# 68              28                          11.9       NaN
# 69               2                           2.2       NaN
# 73               1                           5.9       NaN
# 74               2                           3.0       NaN
# 84               9                           3.4       NaN
# 109              5                           5.5       NaN
# 122              1                           3.5       NaN
# 130             18                           7.2       NaN
# 143             32                           7.7       NaN
# 144             71                          10.1       NaN
# 145             11                           6.3       NaN
# 174              7                           6.4       NaN
# 184             84                           8.7       NaN

# %%
drinks[drinks['continent'].isnull()]['continent'] = "NCA"
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\1084179247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drinks[drinks['continent'].isnull()]['continent'] = "NCA"

# %%
drinks.loc[drinks[drinks['continent'].isnull()].index, 'continent'] = "NCA"

# %%
# drinks.fillna("NCA", inplace=True)
# drinks['continent'].fillna("NCA", inplace=True)

# %%
# drinks[drinks['continent'].isnull()]
drinks[drinks['country'] == "Canada"]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 32  Canada            240              122            100
#
#     total_litres_of_pure_alcohol continent
# 32                           8.2       NCA

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.groupby("continent")['beer_servings'].mean()
# Out:
# continent
# AF      61.471698
# AS      37.045455
# EU     193.777778
# NCA    145.434783
# OC      89.687500
# SA     175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# NCA         23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.columns[1:-1]
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.groupby("continent")[drinks.columns[1:-1]].mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NCA           145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# NCA                            5.995652
# OC                             3.381250
# SA                             6.308333

# %%
drinks.groupby("continent")[drinks.columns[1:-1]].mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NCA           145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# NCA                            5.995652
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby("continent")[drinks.columns[1:-1]].median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# NCA                143.0            137.0           11.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# NCA                                6.30
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.

# %%
drinks.groupby("continent")["spirit_servings"].agg([min, "max", np.mean]).sort_values("max", ascending=False)
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\763665711.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   drinks.groupby("continent")["spirit_servings"].agg([min, "max", np.mean]).sort_values("max", ascending=False)
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\763665711.py:1: FutureWarning: The provided callable <function mean at 0x000002CDA4267DC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   drinks.groupby("continent")["spirit_servings"].agg([min, "max", np.mean]).sort_values("max", ascending=False)
#            min  max        mean
# continent
# NCA         68  438  165.739130
# EU           0  373  132.555556
# AS           0  326   60.840909
# SA          25  302  114.750000
# OC           0  254   58.437500
# AF           0  152   16.339623

# %%
drinks.groupby("continent").agg({"beer_servings": [np.mean],
                                 "spirit_servings": [min, "max", np.mean]})
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\1774797397.py:1: FutureWarning: The provided callable <function mean at 0x000002CDA4267DC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   drinks.groupby("continent").agg({"beer_servings": [np.mean],
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\1774797397.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   drinks.groupby("continent").agg({"beer_servings": [np.mean],
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_17116\1774797397.py:1: FutureWarning: The provided callable <function mean at 0x000002CDA4267DC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   drinks.groupby("continent").agg({"beer_servings": [np.mean],
#           beer_servings spirit_servings
#                    mean             min  max        mean
# continent
# AF            61.471698               0  152   16.339623
# AS            37.045455               0  326   60.840909
# EU           193.777778               0  373  132.555556
# NCA          145.434783              68  438  165.739130
# OC            89.687500               0  254   58.437500
# SA           175.083333              25  302  114.750000
