# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadística
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
df_beer = pd.read_csv("./data/datasets_beers.csv")
df_beer
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %%
df_beer.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %%
df_beer.head(10)
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
# 5           5  0.077  NaN  2261         Black Exodus
# 6           6  0.045  NaN  2260  Lake Street Express
# 7           7  0.065  NaN  2259              Foreman
# 8           8  0.055  NaN  2258                 Jade
# 9           9  0.086  NaN  2131         Cone Crusher
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0
# ...

# %%
df_beer.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
print(df_beer.ndim)
print(df_beer.shape)
# Out:
# 2
# (2410, 8)

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df_beer.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df_beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %%
df_beer.to_csv("prueba.csv", index=False)

# %%
df_prueba = pd.read_csv("prueba.csv")
df_prueba
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
print("Filas", df_beer.shape[0])
print("Columnas", df_beer.shape[1])
# Out:
# Filas 2410
# Columnas 7

# %%
print("Filas", len(df_beer))
print("Filas", len(df_beer.index))
print("Columnas", len(df_beer.columns))
# Out:
# Filas 2410
# Filas 2410
# Columnas 7

# %%
df_beer.size
# Out:
# 16870

# %%
2410 * 7
# Out:
# 16870

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
df_beer.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
df_beer[["abv","ibu","ounces"]].describe()
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241
# std       0.013542    25.954066     2.352204
# min       0.001000     4.000000     8.400000
# 25%       0.050000    21.000000    12.000000
# 50%       0.056000    35.000000    12.000000
# 75%       0.067000    64.000000    16.000000
# max       0.128000   138.000000    32.000000

# %%
df_beer[["abv","ibu","ounces"]].agg(['mean','count'])
# Out:
#                abv          ibu       ounces
# mean      0.059773    42.713167    13.592241
# count  2348.000000  1405.000000  2410.000000

# %%
df_beer[["abv","ibu","ounces"]].agg({"abv":['mean','count'],
                                     "ibu": ['max']})
# Out:
#                abv    ibu
# mean      0.059773    NaN
# count  2348.000000    NaN
# max            NaN  138.0

# %%
df_beer.describe(include="all")
# Out:
#                 abv          ibu           id             name         style  \
# count   2348.000000  1405.000000  2410.000000             2410          2405
# unique          NaN          NaN          NaN             2305            99
# top             NaN          NaN          NaN  Nonstop Hef Hop  American IPA
# freq            NaN          NaN          NaN               12           424
# mean       0.059773    42.713167  1431.113278              NaN           NaN
# std        0.013542    25.954066   752.459975              NaN           NaN
# min        0.001000     4.000000     1.000000              NaN           NaN
# 25%        0.050000    21.000000   808.250000              NaN           NaN
# 50%        0.056000    35.000000  1453.500000              NaN           NaN
# 75%        0.067000    64.000000  2075.750000              NaN           NaN
# max        0.128000   138.000000  2692.000000              NaN           NaN
#
#          brewery_id       ounces
# ...

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
len(df_beer['style'].unique())
# Out:
# 100

# %%
df_beer['style'].nunique()
# Out:
# 99

# %%
df_beer['style'].value_counts()
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Wheat Ale                           1
# Grisette                            1
# Flanders Oud Bruin                  1
# Braggot                             1
# Low Alcohol Beer                    1
# Name: count, Length: 99, dtype: int64

# %%
df_beer['style'].value_counts(normalize=True)
# Out:
# style
# American IPA                      0.176299
# American Pale Ale (APA)           0.101871
# American Amber / Red Ale          0.055301
# American Blonde Ale               0.044906
# American Double / Imperial IPA    0.043659
#                                     ...
# Wheat Ale                         0.000416
# Grisette                          0.000416
# Flanders Oud Bruin                0.000416
# Braggot                           0.000416
# Low Alcohol Beer                  0.000416
# Name: proportion, Length: 99, dtype: float64

# %%
df_beer.groupby("style")['name'].count().sort_values(ascending=False)
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Kristalweizen                       1
# Other                               1
# Low Alcohol Beer                    1
# Smoked Beer                         1
# Wheat Ale                           1
# Name: name, Length: 99, dtype: int64

# %%
df_beer['style'].fillna("Missing style", inplace=True)
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_11064\3257819490.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_beer['style'].fillna("Missing style", inplace=True)

# %%
df_beer['style'].value_counts()['Missing style']
# Out:
# np.int64(5)

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
df_beer.iloc[9:20, :]
# Out:
#       abv   ibu    id                         name  \
# 9   0.086   NaN  2131                 Cone Crusher
# 10  0.072   NaN  2099            Sophomoric Saison
# 11  0.073   NaN  2098        Regional Ring Of Fire
# 12  0.069   NaN  2097                   Garce Selé
# 13  0.085   NaN  1980              Troll Destroyer
# 14  0.061  60.0  1979                 Bitter Bitch
# 15  0.060   NaN  2318                  Ginja Ninja
# 16  0.060   NaN  2170                Cherried Away
# 17  0.060   NaN  2169                 Rhubarbarian
# 18  0.060   NaN  1502                  BrightCider
# 19  0.082   NaN  1593  He Said Baltic-Style Porter
#
#                              style  brewery_id  ounces
# 9   American Double / Imperial IPA         177    12.0
# 10          Saison / Farmhouse Ale         177    12.0
# 11          Saison / Farmhouse Ale         177    12.0
# 12          Saison / Farmhouse Ale         177    12.0
# 13                     Belgian IPA         177    12.0
# ...

# %%
print(list(df_beer.columns).index('name'))
print(list(df_beer.columns).index('ounces'))
# Out:
# 3
# 6

# %%
df_beer.iloc[9:20, 3:]
# Out:
#                            name                           style  brewery_id  \
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368
#
#     ounces
# 9     12.0
# 10    12.0
# 11    12.0
# ...

# %%
print(df_beer.iloc[9:20, :].index.min())
print(df_beer.iloc[9:20, :].index.max())
# Out:
# 9
# 19

# %%
df_beer.loc[9:19, "name":"ounces"]
# Out:
#                            name                           style  brewery_id  \
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368
#
#     ounces
# 9     12.0
# 10    12.0
# 11    12.0
# ...

# %%
df_beer.loc[10:20, ["abv",'ibu','ounces']]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
array = df_beer.loc[10:20, ["abv",'ibu','ounces']].values
print(array)
# Out:
# [[ 0.072    nan 12.   ]
#  [ 0.073    nan 12.   ]
#  [ 0.069    nan 12.   ]
#  [ 0.085    nan 12.   ]
#  [ 0.061 60.    12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.082    nan 12.   ]
#  [ 0.082    nan 12.   ]]

# %%
array = df_beer.loc[10:20, ["abv",'ibu','ounces']].to_numpy()
print(array)
# Out:
# [[ 0.072    nan 12.   ]
#  [ 0.073    nan 12.   ]
#  [ 0.069    nan 12.   ]
#  [ 0.085    nan 12.   ]
#  [ 0.061 60.    12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.082    nan 12.   ]
#  [ 0.082    nan 12.   ]]

# %%
array = np.array(df_beer.loc[10:20, ["abv",'ibu','ounces']])
print(array)
# Out:
# [[ 0.072    nan 12.   ]
#  [ 0.073    nan 12.   ]
#  [ 0.069    nan 12.   ]
#  [ 0.085    nan 12.   ]
#  [ 0.061 60.    12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.06     nan 12.   ]
#  [ 0.082    nan 12.   ]
#  [ 0.082    nan 12.   ]]

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
df_beer['ounces'].sum()
# Out:
# np.float64(32757.3)

# %%
df_beer.groupby("style")['ounces'].sum().sort_values(ascending=False)
# Out:
# style
# American IPA                      5758.4
# American Pale Ale (APA)           3233.6
# American Amber / Red Ale          1768.0
# American Double / Imperial IPA    1487.2
# American Blonde Ale               1424.0
#                                    ...
# Low Alcohol Beer                    16.0
# Braggot                             12.0
# Grisette                            12.0
# Other                               12.0
# Kristalweizen                       12.0
# Name: ounces, Length: 100, dtype: float64

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %%
round(len(df_beer[df_beer['ibu'].notnull()]) / len(df_beer) * 100, 2)
# Out:
# 58.3

# %%
round(df_beer['ibu'].mean(), 2)
# Out:
# np.float64(42.71)

# %%
df_beer['ibu'].min()
# Out:
# np.float64(4.0)

# %%
df_beer['ibu'].max()
# Out:
# np.float64(138.0)

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].min()]
# Out:
#        abv  ibu    id                                  name      style  \
# 106  0.056  4.0  1350                       Summer Solstice  Cream Ale
# 112  0.056  4.0   753  Summer Solstice Cerveza Crema (2009)  Cream Ale
# 117  0.056  4.0    77                Summer Solstice (2011)  Cream Ale
#
#      brewery_id  ounces
# 106         171    12.0
# 112         171    12.0
# 117         171    12.0

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].max()]
# Out:
#        abv    ibu   id                       name  \
# 147  0.082  138.0  980  Bitter Bitch Imperial IPA
#
#                               style  brewery_id  ounces
# 147  American Double / Imperial IPA         374    12.0

# %%
# pd.Series(df_beer['ibu'].values, index=df_beer['name']).idxmin()

# %%
# Supongamos que las cervezas de las que no tenemos amargor, van a tener un valor aproximado a la media de los amargores.
# df_beer['ibu'].fillna(df_beer['ibu'].mean())
df_beer['ibu'].fillna(df_beer['ibu'].median())
# df_beer['ibu'].fillna(df_beer['ibu'].mode())
# Out:
# 0       35.0
# 1       35.0
# 2       35.0
# 3       35.0
# 4       35.0
#         ...
# 2405    45.0
# 2406    35.0
# 2407    35.0
# 2408    40.0
# 2409    35.0
# Name: ibu, Length: 2410, dtype: float64

# %%
df_beer['ibu'].std()
# Out:
# np.float64(25.954065911259317)

# %%
median_ibu_styles = df_beer.groupby("style")[['ibu']].median()
median_ibu_styles
# Out:
#                              ibu
# style
# Abbey Single Ale            22.0
# Altbier                     36.5
# American Adjunct Lager       9.0
# American Amber / Red Ale    31.0
# American Amber / Red Lager  23.0
# ...                          ...
# Tripel                      27.5
# Vienna Lager                23.5
# Wheat Ale                   24.0
# Winter Warmer               22.0
# Witbier                     15.5
#
# [100 rows x 1 columns]

# %%
df_beer = df_beer.merge(median_ibu_styles, left_on="style", right_index=True, how="left")
df_beer
# Out:
#         abv  ibu_x    id                  name  \
# 0     0.050    NaN  1436              Pub Beer
# 1     0.066    NaN  2265           Devil's Cup
# 2     0.071    NaN  2264   Rise of the Phoenix
# 3     0.090    NaN  2263              Sinister
# 4     0.075    NaN  2262         Sex and Candy
# ...     ...    ...   ...                   ...
# 2405  0.067   45.0   928             Belgorado
# 2406  0.052    NaN   807         Rail Yard Ale
# 2407  0.055    NaN   620       B3K Black Lager
# 2408  0.055   40.0   145   Silverback Pale Ale
# 2409  0.052    NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  ibu_y
# 0                American Pale Lager         408    12.0   18.5
# 1            American Pale Ale (APA)         177    12.0   44.0
# 2                       American IPA         177    12.0   69.0
# 3     American Double / Imperial IPA         177    12.0   91.0
# 4                       American IPA         177    12.0   69.0
# ...

# %%
df_beer['ibu_filled'] = np.where(df_beer['ibu_x'].isnull(), df_beer['ibu_y'], df_beer['ibu_x'])
df_beer
# Out:
#         abv  ibu_x    id                  name  \
# 0     0.050    NaN  1436              Pub Beer
# 1     0.066    NaN  2265           Devil's Cup
# 2     0.071    NaN  2264   Rise of the Phoenix
# 3     0.090    NaN  2263              Sinister
# 4     0.075    NaN  2262         Sex and Candy
# ...     ...    ...   ...                   ...
# 2405  0.067   45.0   928             Belgorado
# 2406  0.052    NaN   807         Rail Yard Ale
# 2407  0.055    NaN   620       B3K Black Lager
# 2408  0.055   40.0   145   Silverback Pale Ale
# 2409  0.052    NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  ibu_y  ibu_filled
# 0                American Pale Lager         408    12.0   18.5        18.5
# 1            American Pale Ale (APA)         177    12.0   44.0        44.0
# 2                       American IPA         177    12.0   69.0        69.0
# 3     American Double / Imperial IPA         177    12.0   91.0        91.0
# ...

# %%
df_beer[df_beer['ibu_filled'].isnull()]
# Out:
#         abv  ibu_x    id                              name  \
# 15    0.060    NaN  2318                       Ginja Ninja
# 16    0.060    NaN  2170                     Cherried Away
# 17    0.060    NaN  2169                      Rhubarbarian
# 18    0.060    NaN  1502                       BrightCider
# 122   0.050    NaN  1294        Angry Orchard Apple Ginger
# 123   0.050    NaN  1293         Angry Orchard Crisp Apple
# 124   0.050    NaN  1292         Angry Orchard Crisp Apple
# 307   0.059    NaN  1372                     Yellow Collar
# 308   0.059    NaN  1371                      Green Collar
# 392   0.070    NaN  2548                  Beasts A'Burnin'
# 413   0.051    NaN  2101                       Smoky Wheat
# 552   0.069    NaN  1465     Granny Smith Hard Apple Cider
# 553   0.069    NaN  1464              Dry Hard Apple Cider
# 596   0.050    NaN  1342                       First Press
# 597   0.050    NaN  1341                       Magic Apple
# ...

# %%
df_beer['ibu_filled'].fillna(df_beer['ibu_filled'].median(), inplace=True)
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_11064\1390467551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_beer['ibu_filled'].fillna(df_beer['ibu_filled'].median(), inplace=True)

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu_x       1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
#  7   ibu_y       2358 non-null   float64
#  8   ibu_filled  2410 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 169.6+ KB

# %%
df_beer['ibu_x'].mean()
# Out:
# np.float64(42.71316725978647)

# %%
df_beer['ibu_filled'].mean()
# Out:
# np.float64(40.31369294605809)

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
df_beer.drop(columns=['ibu_y'], inplace=True)

# %%
df_beer.rename(columns={"ibu_x":'ibu'}, inplace=True)

# %%
df_beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %%
df_beer['ibu'].var()
# Out:
# np.float64(673.6135373259929)

# %%
df_beer['ibu'].std()
# Out:
# np.float64(25.954065911259317)

# %%
df_beer['ibu'].max() - df_beer['ibu'].min()
# Out:
# np.float64(134.0)

# %%
np.percentile(df_beer['ibu_filled'], 80) - np.percentile(df_beer['ibu_filled'], 20)
# Out:
# np.float64(45.0)

# %%
df_beer['ibu_filled'].std()
# Out:
# np.float64(23.908165834697616)

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonamiento mediante un gráfico

# %%
df_beer[['abv','ibu','ounces']].corr()
# Out:
#              abv       ibu    ounces
# abv     1.000000  0.670621  0.172529
# ibu     0.670621  1.000000  0.054691
# ounces  0.172529  0.054691  1.000000

# %%
import seaborn as sns

sns.heatmap(df_beer[['abv','ibu','ounces']].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
df_beer['abv'].hist(bins=50)
# Out:
# <Axes: >

# %%
# !pip install scipy

# %%
from scipy import stats

# %%
stats.skew(df_beer[df_beer['abv'].notnull()]['abv'])
# Out:
# np.float64(0.9578647103102429)

# %%
df_beer['abv'].skew()
# Out:
# np.float64(0.9584771340361382)

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
import seaborn as sns

# %%
sns.boxplot(x=df_beer['abv'])
# Out:
# <Axes: xlabel='abv'>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
df_beer.groupby("style")['abv'].mean().sort_values(ascending=False)
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
#                             ...
# Berliner Weissbier        0.043909
# English Dark Mild Ale     0.041500
# Light Lager               0.040417
# Radler                    0.040333
# Low Alcohol Beer          0.001000
# Name: abv, Length: 100, dtype: float64

# %%
df_beer.groupby("style")['abv'].agg(['count','mean']).sort_values('mean', ascending=False)
# Out:
#                         count      mean
# style
# English Barleywine          3  0.107667
# Quadrupel (Quad)            4  0.104000
# American Barleywine         3  0.099000
# American Malt Liquor        1  0.099000
# Russian Imperial Stout     11  0.097636
# ...                       ...       ...
# Berliner Weissbier         11  0.043909
# English Dark Mild Ale       4  0.041500
# Light Lager                12  0.040417
# Radler                      3  0.040333
# Low Alcohol Beer            1  0.001000
#
# [100 rows x 2 columns]

# %%
df_grouped = df_beer.groupby("style")['ibu'].agg(['count','mean']).sort_values('mean', ascending=False)
df_grouped[df_grouped['mean'].notnull()]
# Out:
#                                     count       mean
# style
# American Barleywine                     2  96.000000
# American Double / Imperial IPA         75  93.320000
# Russian Imperial Stout                  8  86.500000
# American Double / Imperial Pilsner      1  85.000000
# Belgian Strong Dark Ale                 1  72.000000
# ...                                   ...        ...
# Fruit / Vegetable Beer                 30  14.200000
# Light Lager                             3  11.666667
# American Adjunct Lager                 11  11.000000
# Gose                                    7   9.428571
# Berliner Weissbier                      5   7.800000
#
# [91 rows x 2 columns]

# %%
df_beer.groupby("style")['ibu_filled'].agg(['count','mean']).sort_values('mean', ascending=False)
# Out:
#                                     count       mean
# style
# American Barleywine                     3  96.000000
# American Double / Imperial IPA        105  92.657143
# Russian Imperial Stout                 11  88.545455
# American Double / Imperial Pilsner      2  85.000000
# Belgian Strong Dark Ale                 6  72.000000
# ...                                   ...        ...
# Fruit / Vegetable Beer                 49  14.704082
# Light Lager                            12  11.916667
# American Adjunct Lager                 18  10.222222
# Gose                                   10   9.600000
# Berliner Weissbier                     11   7.909091
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
df_brew = pd.read_csv('data/datasets_breweries.csv')
df_brew
# Out:
#      Unnamed: 0                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
df_brew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  558 non-null    int64
#  1   name        558 non-null    object
#  2   city        558 non-null    object
#  3   state       558 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 17.6+ KB

# %%
df_brew.describe(include="all")
# Out:
#         Unnamed: 0                     name      city state
# count   558.000000                      558       558   558
# unique         NaN                      551       384    51
# top            NaN  Sly Fox Brewing Company  Portland    CO
# freq           NaN                        2        17    47
# mean    278.500000                      NaN       NaN   NaN
# std     161.224998                      NaN       NaN   NaN
# min       0.000000                      NaN       NaN   NaN
# 25%     139.250000                      NaN       NaN   NaN
# 50%     278.500000                      NaN       NaN   NaN
# 75%     417.750000                      NaN       NaN   NaN
# max     557.000000                      NaN       NaN   NaN

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra también la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
df_brew.rename(columns={"Unnamed: 0": "brewery_id", "name":"brewery_name" }, inplace=True)

# %%
df_brew
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
df_beer.rename(columns={"name":"beer_name"}, inplace=True)
df_beer
# Out:
#         abv   ibu    id             beer_name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %%
df_brew
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
df_all = pd.merge(df_beer, df_brew, on="brewery_id", how="outer", indicator=True)
df_all
# Out:
#         abv   ibu    id                  beer_name                    style  \
# 0     0.045  50.0  2692               Get Together             American IPA
# 1     0.049  26.0  2691              Maggie's Leap       Milk / Sweet Stout
# 2     0.048  19.0  2690                 Wall's End        English Brown Ale
# 3     0.060  38.0  2689                    Pumpion              Pumpkin Ale
# 4     0.060  25.0  2688                 Stronghold          American Porter
# ...     ...   ...   ...                        ...                      ...
# 2405  0.049   NaN    52   Heinnieweisse Weissebier               Hefeweizen
# 2406  0.068   NaN    51            Snapperhead IPA             American IPA
# 2407  0.049   NaN    50          Moo Thunder Stout       Milk / Sweet Stout
# 2408  0.043   NaN    49          Porkslap Pale Ale  American Pale Ale (APA)
# 2409  0.049   NaN    30  Urban Wilderness Pale Ale         English Pale Ale
#
# ...

# %%
df_all[df_all['_merge'] != "both"]
# Out:
# Empty DataFrame
# Columns: [abv, ibu, id, beer_name, style, brewery_id, ounces, ibu_filled, brewery_name, city, state, _merge]
# Index: []

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
df_all['state'].nunique()
# Out:
# 51

# %%
df_all['city'].nunique()
# Out:
# 384

# %%
df_all['brewery_name'].nunique()
# Out:
# 551

# %%
df_all['brewery_id'].nunique()
# Out:
# 558

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
df_all.groupby(["state", "city"])['abv'].agg(['mean','median','max'])
# Out:
#                       mean  median    max
# state city
# AK    Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
# AL    Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
# WI    Wilson      0.055000  0.0550  0.055
# WV    Lewisburg   0.062000  0.0620  0.067
# WY    Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
df_all[df_all['state'] == "IN"]
# Out:
# Empty DataFrame
# Columns: [abv, ibu, id, beer_name, style, brewery_id, ounces, ibu_filled, brewery_name, city, state, _merge]
# Index: []

# %%
df_all.head()
# Out:
#      abv   ibu    id      beer_name               style  brewery_id  ounces  \
# 0  0.045  50.0  2692   Get Together        American IPA           0    16.0
# 1  0.049  26.0  2691  Maggie's Leap  Milk / Sweet Stout           0    16.0
# 2  0.048  19.0  2690     Wall's End   English Brown Ale           0    16.0
# 3  0.060  38.0  2689        Pumpion         Pumpkin Ale           0    16.0
# 4  0.060  25.0  2688     Stronghold     American Porter           0    16.0
#
#    ibu_filled        brewery_name         city state _merge
# 0        50.0  NorthGate Brewing   Minneapolis    MN   both
# 1        26.0  NorthGate Brewing   Minneapolis    MN   both
# 2        19.0  NorthGate Brewing   Minneapolis    MN   both
# 3        38.0  NorthGate Brewing   Minneapolis    MN   both
# 4        25.0  NorthGate Brewing   Minneapolis    MN   both

# %%
df_all[df_all['state'].str.contains("IN")].sort_values("ibu", ascending=False)
# Out:
#         abv    ibu    id              beer_name  \
# 145   0.085  115.0  1449  Overlord Imperial IPA
# 166   0.099  115.0  2471       Hopkick Dropkick
# 140   0.060  104.0  1610         Half Cycle IPA
# 203   0.091   91.0   651                   Isis
# 160   0.064   90.0  2610             The Gadget
# ...     ...    ...   ...                    ...
# 1628  0.080    NaN  1787          Floyd's Folly
# 1629  0.063    NaN  1786         Half Court IPA
# 1727  0.040    NaN  1657       Leprechaun Lager
# 1754  0.072    NaN  1623           Lift Off IPA
# 2289  0.047    NaN   780     T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  ibu_filled  \
# 145   American Double / Imperial IPA          17    16.0       115.0
# 166   American Double / Imperial IPA          24    12.0       115.0
# 140                     American IPA          16    16.0       104.0
# 203   American Double / Imperial IPA          25    16.0        91.0
# ...

# %%
df_all.loc[1,'state']
# Out:
# ' MN'

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
df_all['ibu'].describe()
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: ibu, dtype: float64

# %%
df_all[df_all['ibu'].notnull()].groupby("city")['ibu'].describe()
# Out:
#                count        mean        std    min     25%    50%     75%  \
# city
# Abingdon         1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs    3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Afton            4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Albuquerque      4.0   54.250000  38.887659   15.0   26.25   51.0   79.00
# Anchorage       10.0   40.400000  26.563132   10.0   15.50   42.5   63.25
# ...              ...         ...        ...    ...     ...    ...     ...
# Woodbridge       3.0   58.666667  45.610671    6.0   45.50   85.0   85.00
# Woodinville      4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester        1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima           2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# York             4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
#                  max
# city
# Abingdon       135.0
# Abita Springs   52.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame de todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
# todas las cervezas, que venda una cervecería, donde al menos una de ellas sea de 0.07 para arriba

# %%
cervecerias = df_all[df_all['abv'] >= 0.07]['brewery_id'].unique()
cervecerias
# Out:
# array([  1,   2,   3,   5,   6,   7,   8,  10,  12,  15,  17,  18,  20,
#         24,  25,  26,  27,  28,  29,  30,  33,  34,  37,  38,  39,  40,
#         43,  45,  46,  48,  50,  51,  53,  57,  58,  61,  62,  63,  64,
#         65,  67,  68,  69,  71,  72,  74,  75,  76,  80,  83,  86,  91,
#         92,  93,  94,  95,  97,  98,  99, 100, 105, 107, 110, 112, 115,
#        117, 118, 124, 125, 127, 128, 132, 133, 134, 141, 143, 148, 149,
#        152, 159, 161, 164, 165, 166, 168, 171, 172, 173, 174, 175, 177,
#        180, 183, 184, 188, 193, 198, 199, 201, 203, 204, 206, 208, 209,
#        211, 214, 215, 219, 220, 222, 224, 226, 227, 228, 229, 230, 231,
#        233, 235, 236, 240, 242, 248, 252, 256, 257, 260, 262, 263, 264,
#        268, 272, 274, 279, 280, 282, 284, 285, 287, 291, 292, 294, 295,
#        301, 302, 304, 306, 308, 309, 313, 314, 315, 317, 322, 327, 331,
#        332, 336, 343, 346, 350, 353, 354, 355, 356, 358, 359, 360, 361,
# ...

# %%
df_all[df_all['brewery_id'].isin(cervecerias)]
# Out:
#         abv   ibu    id                              beer_name  \
# 6     0.080  68.0  2686                         Citra Ass Down
# 7     0.125  80.0  2685                         London Balling
# 8     0.077  25.0  2684                                   35 K
# 9     0.042  42.0  2683                                 A Beer
# 10    0.050  25.0  2682                        Rules are Rules
# ...     ...   ...   ...                                    ...
# 2347  0.062  42.0    28            Tule Duck Red Ale (Current)
# 2348  0.058  35.0    27  Original Orange Blossom Ale (Current)
# 2349  0.052  40.0    26            Black Noddy Lager (Current)
# 2396  0.072   NaN   324                       Wyoming Pale Ale
# 2397  0.050   NaN   323                  Wind River Blonde Ale
#
#                                style  brewery_id  ounces  ibu_filled  \
# 6     American Double / Imperial IPA           1    16.0        68.0
# ...

# %%
brews = df_all.groupby('brewery_id')['abv'].max()
brews
# Out:
# brewery_id
# 0      0.060
# 1      0.125
# 2      0.072
# 3      0.080
# 4      0.063
#        ...
# 553    0.050
# 554    0.055
# 555    0.055
# 556    0.068
# 557    0.049
# Name: abv, Length: 558, dtype: float64

# %%
cervecerias =  brews[brews >= 0.07].index
cervecerias
# Out:
# Index([  1,   2,   3,   5,   6,   7,   8,  10,  12,  15,
#        ...
#        507, 509, 514, 515, 521, 522, 523, 524, 530, 550],
#       dtype='int64', name='brewery_id', length=227)

# %%
df_all[df_all['brewery_id'].isin(cervecerias)]
# Out:
#         abv   ibu    id                              beer_name  \
# 6     0.080  68.0  2686                         Citra Ass Down
# 7     0.125  80.0  2685                         London Balling
# 8     0.077  25.0  2684                                   35 K
# 9     0.042  42.0  2683                                 A Beer
# 10    0.050  25.0  2682                        Rules are Rules
# ...     ...   ...   ...                                    ...
# 2347  0.062  42.0    28            Tule Duck Red Ale (Current)
# 2348  0.058  35.0    27  Original Orange Blossom Ale (Current)
# 2349  0.052  40.0    26            Black Noddy Lager (Current)
# 2396  0.072   NaN   324                       Wyoming Pale Ale
# 2397  0.050   NaN   323                  Wind River Blonde Ale
#
#                                style  brewery_id  ounces  ibu_filled  \
# 6     American Double / Imperial IPA           1    16.0        68.0
# ...

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
# Las cervezas que se encuentran en aquellos estados, cuya media de amargor, sea superior a la media de amargor total

# %%
df_all['ibu'].mean()
# Out:
# np.float64(42.71316725978647)

# %%
mean_ibu_states = df_all.groupby('state')['ibu'].mean()
mean_ibu_states
# Out:
# state
# AK    40.882353
# AL    51.222222
# AR    39.000000
# AZ    35.208333
# CA    46.281481
# CO    47.431507
# CT    40.833333
# DC    55.250000
# DE    52.000000
# FL    46.756757
# GA    46.285714
# HI    32.666667
# IA    33.200000
# ID    55.117647
# IL    41.461538
# IN    42.989011
# KS    36.684211
# KY    40.714286
# LA    33.000000
# MA    38.000000
# MD    36.800000
# ME    52.857143
# MI    36.736842
# MN    49.956522
# MO    32.482759
# MS    46.454545
# MT    41.695652
# NC    43.300000
# ND    40.333333
# NE    30.666667
# NH    48.500000
# NJ    46.375000
# NM    57.000000
# NV    46.500000
# NY    46.000000
# OH    44.187500
# OK    40.727273
# OR    47.942529
# PA    42.446809
# RI    31.550000
# SC    30.200000
# SD          NaN
# TN    41.600000
# TX    40.393258
# UT    45.545455
# VA    45.371429
# VT    42.294118
# WA    44.976744
# WI    26.547619
# WV    57.500000
# WY    32.083333
# Name: ibu, dtype: float64

# %%
states_filter = mean_ibu_states[mean_ibu_states > df_all['ibu'].mean()].index
states_filter
# Out:
# Index([' AL', ' CA', ' CO', ' DC', ' DE', ' FL', ' GA', ' ID', ' IN', ' ME',
#        ' MN', ' MS', ' NC', ' NH', ' NJ', ' NM', ' NV', ' NY', ' OH', ' OR',
#        ' UT', ' VA', ' WA', ' WV'],
#       dtype='object', name='state')

# %%
df_all[df_all['state'].isin(states_filter)]
# Out:
#         abv   ibu    id                 beer_name                    style  \
# 0     0.045  50.0  2692              Get Together             American IPA
# 1     0.049  26.0  2691             Maggie's Leap       Milk / Sweet Stout
# 2     0.048  19.0  2690                Wall's End        English Brown Ale
# 3     0.060  38.0  2689                   Pumpion              Pumpkin Ale
# 4     0.060  25.0  2688                Stronghold          American Porter
# ...     ...   ...   ...                       ...                      ...
# 2404  0.055   NaN    98             Pilsner Ukiah          German Pilsener
# 2405  0.049   NaN    52  Heinnieweisse Weissebier               Hefeweizen
# 2406  0.068   NaN    51           Snapperhead IPA             American IPA
# 2407  0.049   NaN    50         Moo Thunder Stout       Milk / Sweet Stout
# 2408  0.043   NaN    49         Porkslap Pale Ale  American Pale Ale (APA)
#
# ...
