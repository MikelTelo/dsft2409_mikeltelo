# %% [markdown]
# # Ejercicios de Seaborn

# %%
#python -m pip install --upgrade pip

# %%
# 1. Importa pandas, pyplot y seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame
df = pd.read_csv('data/pokemon.csv')

df.head(1)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Stage  Legendary
# 0     45      1      False

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
df.head(10)
# Out:
#     #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
# 5   6   Charizard   Fire  Flying    534  78      84       78      109
# 6   7    Squirtle  Water     NaN    314  44      48       65       50
# 7   8   Wartortle  Water     NaN    405  59      63       80       65
# 8   9   Blastoise  Water     NaN    530  79      83      100       85
# 9  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False
# 5       85    100      3      False
# 6       64     43      1      False
# 7       80     58      2      False
# 8      105     78      3      False
# 9       20     45      1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data

sns.lmplot(x="Total", y="HP", data=df)

# %%
# y = a*x + b

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a False
sns.lmplot(x="Total", y="HP", data=df, fit_reg=False)

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

sns.lmplot(x="Total", y="HP", data=df, fit_reg=False,hue="Stage")

# %%
# 8. Limita el eje x entre 20 y 100

sns.lmplot(x="Total", y="HP", data=df, fit_reg=False,hue="Stage")
plt.xlim=(20, 100)

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# Seleccionar las columnas numéricas relevantes para el boxplot

df.info()
stats_columns = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Stage']

sns.boxplot(data=df[stats_columns])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB
# <Axes: >

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas
stats_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

sns.boxplot(data=df[stats_columns])
# Out:
# <Axes: >

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

num_unique_types = df['Type 1'].nunique()
print(f"Hay {num_unique_types} tipos diferentes de 'Type 1' en el DataFrame.")
# Out:
# Hay 15 tipos diferentes de 'Type 1' en el DataFrame.

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# Definir los tipos que queremos mantener
tipos_deseados = ['Grass', 'Fire', 'Water']

# Filtrar el DataFrame
df_filtrado = df[df['Type 1'].isin(tipos_deseados)]

# Verificar el resultado
print(f"Número de Pokémon antes del filtrado: {len(df)}")
print(f"Número de Pokémon después del filtrado: {len(df_filtrado)}")

# Mostrar la distribución de los tipos después del filtrado
print("\nDistribución de Pokémon por 'Type 1' después del filtrado:")
print(df_filtrado['Type 1'].value_counts())

df_filtrado
# Out:
# Número de Pokémon antes del filtrado: 151
# Número de Pokémon después del filtrado: 52
#
# Distribución de Pokémon por 'Type 1' después del filtrado:
# Type 1
# Water    28
# Grass    12
# Fire     12
# Name: count, dtype: int64
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass    Poison    318   45      49       49       65
# 1      2     Ivysaur  Grass    Poison    405   60      62       63       80
# 2      3    Venusaur  Grass    Poison    525   80      82       83      100
# 3      4  Charmander   Fire       NaN    309   39      52       43       60
# 4      5  Charmeleon   Fire       NaN    405   58      64       58       80
# 5      6   Charizard   Fire    Flying    534   78      84       78      109
# 6      7    Squirtle  Water       NaN    314   44      48       65       50
# 7      8   Wartortle  Water       NaN    405   59      63       80       65
# 8      9   Blastoise  Water       NaN    530   79      83      100       85
# 36    37      Vulpix   Fire       NaN    299   38      41       40       50
# 37    38   Ninetales   Fire       NaN    505   73      76       75       81
# 42    43      Oddish  Grass    Poison    320   45      50       55       75
# 43    44       Gloom  Grass    Poison    395   60      65       70       85
# 44    45   Vileplume  Grass    Poison    490   75      80       85      110
# 53    54     Psyduck  Water       NaN    320   50      52       48       65
# 54    55     Golduck  Water       NaN    500   80      82       78       95
# 57    58   Growlithe   Fire       NaN    350   55      70       45       70
# 58    59    Arcanine   Fire       NaN    555   90     110       80      100
# 59    60     Poliwag  Water       NaN    300   40      50       40       40
# 60    61   Poliwhirl  Water       NaN    385   65      65       65       50
# 61    62   Poliwrath  Water  Fighting    510   90      95       95       70
# 68    69  Bellsprout  Grass    Poison    300   50      75       35       70
# 69    70  Weepinbell  Grass    Poison    390   65      90       50       85
# 70    71  Victreebel  Grass    Poison    490   80     105       65      100
# 71    72   Tentacool  Water    Poison    335   40      40       35       50
# 72    73  Tentacruel  Water    Poison    515   80      70       65       80
# 76    77      Ponyta   Fire       NaN    410   50      85       55       65
# 77    78    Rapidash   Fire       NaN    500   65     100       70       80
# 78    79    Slowpoke  Water   Psychic    315   90      65       65       40
# 79    80     Slowbro  Water   Psychic    490   95      75      110      100
# 85    86        Seel  Water       NaN    325   65      45       55       45
# 86    87     Dewgong  Water       Ice    475   90      70       80       70
# 89    90    Shellder  Water       NaN    305   30      65      100       45
# 90    91    Cloyster  Water       Ice    525   50      95      180       85
# 97    98      Krabby  Water       NaN    325   30     105       90       25
# 98    99     Kingler  Water       NaN    475   55     130      115       50
# 101  102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 102  103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 113  114     Tangela  Grass       NaN    435   65      55      115      100
# 115  116      Horsea  Water       NaN    295   30      40       70       70
# 116  117      Seadra  Water       NaN    440   55      65       95       95
# 117  118     Goldeen  Water       NaN    320   45      67       60       35
# 118  119     Seaking  Water       NaN    450   80      92       65       65
# 119  120      Staryu  Water       NaN    340   30      45       55       70
# 120  121     Starmie  Water   Psychic    520   60      75       85      100
# 125  126      Magmar   Fire       NaN    495   65      95       57      100
# 128  129    Magikarp  Water       NaN    200   20      10       55       15
# 129  130    Gyarados  Water    Flying    540   95     125       79       60
# 130  131      Lapras  Water       Ice    535  130      85       80       85
# 133  134    Vaporeon  Water       NaN    525  130      65       60      110
# 135  136     Flareon   Fire       NaN    525   65     130       60       95
# 145  146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# 5         85    100      3      False
# 6         64     43      1      False
# 7         80     58      2      False
# 8        105     78      3      False
# 36        65     65      1      False
# 37       100    100      2      False
# 42        65     30      1      False
# 43        75     40      2      False
# 44        90     50      3      False
# 53        50     55      1      False
# 54        80     85      2      False
# 57        50     60      1      False
# 58        80     95      2      False
# 59        40     90      1      False
# 60        50     90      2      False
# 61        90     70      3      False
# 68        30     40      1      False
# 69        45     55      2      False
# 70        70     70      3      False
# 71       100     70      1      False
# 72       120    100      2      False
# 76        65     90      1      False
# 77        80    105      2      False
# 78        40     15      1      False
# 79        80     30      2      False
# 85        70     45      1      False
# 86        95     70      2      False
# 89        25     40      1      False
# 90        45     70      2      False
# 97        25     50      1      False
# 98        50     75      2      False
# 101       45     40      1      False
# 102       65     55      2      False
# 113       40     60      1      False
# 115       25     60      1      False
# 116       45     85      2      False
# 117       50     63      1      False
# 118       80     68      2      False
# 119       55     85      1      False
# 120       85    115      2      False
# 125       85     93      1      False
# 128       20     80      1      False
# 129      100     81      2      False
# 130       95     60      1      False
# 133       95     65      2      False
# 135      110     65      2      False
# 145       85     90      1       True

# %%
# 13. Usa un estilo 'whitegrid'
stats_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

#uso dark porque white no cambia nada
sns.set_style('darkgrid')

sns.boxplot(data=df[stats_columns])
# Out:
# <Axes: >

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

#sns.violinplot(data=df_filtrado ['grass','water','fire'])

sns.catplot(kind='violin', data=df_filtrado, x='Type 1', y="Attack")

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'
# Lista de colores
colores = ['#78C850', '#F08030', '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

sns.catplot(kind='violin', data=df_filtrado, x='Type 1', y="Attack", palette=colores)
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\1977290526.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind='violin', data=df_filtrado, x='Type 1', y="Attack", palette=colores)

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin
sns.catplot(kind='swarm', data=df_filtrado, x='Type 1', y="Attack", palette=colores)
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\1174736043.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind='swarm', data=df_filtrado, x='Type 1', y="Attack", palette=colores)

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

sns.violinplot(data=df_filtrado, x='Type 1', y='Attack', palette=colores, inner=None)
sns.swarmplot(data=df_filtrado, x='Type 1', y='Attack', color='black', alpha=0.9)

# Añadir título y etiquetas usando pyplot
plt.title('Distribución de Ataque por Tipo de Pokémon', fontsize=16)
plt.xlabel('Tipo', fontsize=12)
plt.ylabel('Ataque', fontsize=12)
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\75776154.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_filtrado, x='Type 1', y='Attack', palette=colores, inner=None)
# Text(41.222222222222214, 0.5, 'Ataque')

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

df_filtrado.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
#df_melt = df_filtrado.melt(id_vars=['Name', 'Type 1'], value_vars=['HP','Attack','Defense','Sp. Atk', 'Sp. Def', 'Speed'],var_name='Stat', value_name='Value')
#df_melt.head(5)
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 145
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          52 non-null     int64
#  1   Name       52 non-null     object
#  2   Type 1     52 non-null     object
#  3   Type 2     23 non-null     object
#  4   Total      52 non-null     int64
#  5   HP         52 non-null     int64
#  6   Attack     52 non-null     int64
#  7   Defense    52 non-null     int64
#  8   Sp. Atk    52 non-null     int64
#  9   Sp. Def    52 non-null     int64
#  10  Speed      52 non-null     int64
#  11  Stage      52 non-null     int64
#  12  Legendary  52 non-null     bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 7.4+ KB

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

df_melt2 = df_filtrado.melt(id_vars=['Name', 'Type 1'], value_vars=['Total','HP','Attack','Defense','Sp. Atk', 'Sp. Def', 'Speed', 'Stage'], var_name='New Column')

# %%
df_melt2.head()
# Out:
#          Name Type 1 New Column  value
# 0   Bulbasaur  Grass      Total    318
# 1     Ivysaur  Grass      Total    405
# 2    Venusaur  Grass      Total    525
# 3  Charmander   Fire      Total    309
# 4  Charmeleon   Fire      Total    405

# %%
df_melt2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        416 non-null    object
#  1   Type 1      416 non-null    object
#  2   New Column  416 non-null    object
#  3   value       416 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 13.1+ KB

# %%
df_filtrado.tail()
# Out:
#        #      Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 129  130  Gyarados  Water  Flying    540   95     125       79       60
# 130  131    Lapras  Water     Ice    535  130      85       80       85
# 133  134  Vaporeon  Water     NaN    525  130      65       60      110
# 135  136   Flareon   Fire     NaN    525   65     130       60       95
# 145  146   Moltres   Fire  Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# 129      100     81      2      False
# 130       95     60      1      False
# 133       95     65      2      False
# 135      110     65      2      False
# 145       85     90      1       True

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

sns.violinplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, inner=None)
sns.swarmplot(data=df_melt2, x='Type 1', y='New Column', color='black', alpha=0.9)
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\325896802.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, inner=None)
# C:\Users\mikel\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 39.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Type 1', ylabel='New Column'>
# C:\Users\mikel\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.


# Assuming df_melt2 is your DataFrame and colores is your color palette
plt.figure(figsize=(10, 6))

# Violin plot
sns.violinplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, inner=None)

# Swarm plot with dodge
sns.swarmplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, dodge=True, color='black', alpha=0.9)

# Set y-axis limits
plt.ylim(0, 200)

# Set legend position
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\2218773310.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, inner=None)
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\2218773310.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=df_melt2, x='Type 1', y='New Column', palette=colores, dodge=True, color='black', alpha=0.9)
# C:\Users\mikel\AppData\Local\Temp\ipykernel_9348\2218773310.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1, 1), loc=2)
# C:\Users\mikel\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 14.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\mikel\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 61.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# Supongamos que df es tu DataFrame original
# df = pd.read_csv('tu_archivo.csv')  # Cargar tu DataFrame aquí

# Calcular la matriz de correlación
correlation_matrix = df.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear un mapa de calor
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

# Configurar títulos y etiquetas
plt.title('Matriz de Correlación', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 10
#       1 # 23. Mapas de calor
#       2 # Calcula las correlaciones del primer DataFrame original df
#       3 # Pista: las correlaciones se calculan con el método corr()
#    (...)
#       8
#       9 # Calcular la matriz de correlación
# ---> 10 correlation_matrix = df.corr()
#      12 # Configurar el tamaño de la figura
#      13 plt.figure(figsize=(12, 8))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Bulbasaur'

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original
