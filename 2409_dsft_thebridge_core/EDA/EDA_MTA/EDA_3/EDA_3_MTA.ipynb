# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df_gym = pd.read_csv("data/gym_members_exercise_tracking.csv")

# %%
df_gym
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df_gym.head(20)
# Out:
#     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0    56    Male         88.3        1.71      180      157           60
# 1    46  Female         74.9        1.53      179      151           66
# 2    32  Female         68.1        1.66      167      122           54
# 3    25    Male         53.2        1.70      190      164           56
# 4    38    Male         46.1        1.79      188      158           68
# 5    56  Female         58.0        1.68      168      156           74
# 6    36    Male         70.3        1.72      174      169           73
# 7    40  Female         69.7        1.51      189      141           64
# 8    28    Male        121.7        1.94      185      127           52
# 9    28    Male        101.8        1.84      169      136           64
# 10   41    Male        120.8        1.67      188      146           54
# 11   53    Male         51.7        1.70      175      152           72
# ...

# %%
df_gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
df_gym.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
sns.countplot(data=df_gym, x="Gender")
plt.title("Count Of Gender")
# Out:
# Text(0.5, 1.0, 'Count Of Gender')

# %%
sns.histplot(data=df_gym, x='Age', kde=True)
plt.title("Distrbution Of Age")
# Out:
# Text(0.5, 1.0, 'Distrbution Of Age')

# %%
sns.barplot(data=df_gym, x='Workout_Type', y='Calories_Burned', hue='Gender')
plt.title("Calories Burned For Each Workout Type")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
new = df_gym[['Weight (kg)', 'Height (m)', 'BMI', 'Calories_Burned', 'Session_Duration (hours)', "Gender"]]
sns.pairplot(data=new, hue='Gender', palette='coolwarm')

# %%
sns.scatterplot(data=df_gym, x='Session_Duration (hours)', y='Calories_Burned', hue='Experience_Level', color='set1')
plt.title("Claories Burned By Session Duration And Experience Level")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Compute the correlation matrix
#corr = df_gym.corr()

# Plot heatmap
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(df_gym.corr(),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=-1,
            vmax=1);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       1 # Compute the correlation matrix
#       2 #corr = df_gym.corr()
#       3
#       4 # Plot heatmap
#       5 f, ax = plt.subplots(figsize=(13, 10))
# ----> 6 sns.heatmap(df_gym.corr(),
#       7             annot=True,
#       8             linewidths=.5,
#       9             ax=ax,
#      10             vmin=-1,
#      11             vmax=1);
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
df_MTA = pd.read_csv("data/com_corp_mta.csv")

# %%
df_MTA
# Out:
#             Tiempo     Peso  Cambio   IMC Grasa corporal  \
# 0     Oct 29, 2024      NaN     NaN   NaN            NaN
# 1          7:06 am  75.6 kg  0.2 kg  25.6         15.4 %
# 2     Oct 28, 2024      NaN     NaN   NaN            NaN
# 3          6:19 am  75.4 kg  0.7 kg  25.5         14.7 %
# 4     Oct 27, 2024      NaN     NaN   NaN            NaN
# ..             ...      ...     ...   ...            ...
# 681        7:40 am  79.8 kg  0.4 kg  27.0         25.9 %
# 682    Nov 2, 2023      NaN     NaN   NaN            NaN
# 683        6:15 am  79.4 kg  0.2 kg  26.9         25.7 %
# 684    Nov 1, 2023      NaN     NaN   NaN            NaN
# 685        7:34 am  79.2 kg  0.0 kg  26.8           26 %
#
#     Masa muscular esquelética Masa ósea Agua corporal  Unnamed: 8
# 0                         NaN       NaN           NaN         NaN
# 1                     29.8 kg    4.7 kg        61.7 %         NaN
# 2                         NaN       NaN           NaN         NaN
# ...

# %%
df_MTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Tiempo                     686 non-null    object
#  1   Peso                       412 non-null    object
#  2   Cambio                     412 non-null    object
#  3   IMC                        412 non-null    float64
#  4   Grasa corporal             412 non-null    object
#  5   Masa muscular esquelética  412 non-null    object
#  6   Masa ósea                  412 non-null    object
#  7   Agua corporal              412 non-null    object
#  8   Unnamed: 8                 0 non-null      float64
# dtypes: float64(2), object(7)
# memory usage: 48.4+ KB

# %%
df_MTA.head(10)
# Out:
#           Tiempo     Peso  Cambio   IMC Grasa corporal  \
# 0   Oct 29, 2024      NaN     NaN   NaN            NaN
# 1        7:06 am  75.6 kg  0.2 kg  25.6         15.4 %
# 2   Oct 28, 2024      NaN     NaN   NaN            NaN
# 3        6:19 am  75.4 kg  0.7 kg  25.5         14.7 %
# 4   Oct 27, 2024      NaN     NaN   NaN            NaN
# 5        8:14 am  76.1 kg  0.1 kg  25.7         15.4 %
# 6   Oct 26, 2024      NaN     NaN   NaN            NaN
# 7        8:35 am  76.2 kg  0.5 kg  25.7         15.5 %
# 8   Oct 25, 2024      NaN     NaN   NaN            NaN
# 9        6:57 am  75.7 kg  0.2 kg  25.6           15 %
#
#   Masa muscular esquelética Masa ósea Agua corporal  Unnamed: 8
# 0                       NaN       NaN           NaN         NaN
# 1                   29.8 kg    4.7 kg        61.7 %         NaN
# 2                       NaN       NaN           NaN         NaN
# 3                   29.7 kg    4.7 kg        62.3 %         NaN
# ...
