# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.
# keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")

# %%
dataset = keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset
# Out:
# 'C:\\Users\\hegoi\\.keras\\datasets\\auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
column_names = ["MPG", "Cylinders", "Displacement", "Horsepower", "Weight", "Acceleration", "Model Year", "Origin", "Car name"]

# %%
df = pd.read_csv(dataset, names=column_names, delim_whitespace=True)
df
# Out:
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_1556\4045023703.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(dataset, names=column_names, delim_whitespace=True)
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      Model Year  Origin                   Car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement       Weight  Acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        Model Year      Origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['Horsepower'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Horsepower'].astype(float)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '?'

# %%
df[df['Horsepower']=="?"]
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0          ?  2046.0          19.0
# 126  21.0          6         200.0          ?  2875.0          17.0
# 330  40.9          4          85.0          ?  1835.0          17.3
# 336  23.6          4         140.0          ?  2905.0          14.3
# 354  34.5          4         100.0          ?  2320.0          15.8
# 374  23.0          4         151.0          ?  3035.0          20.5
#
#      Model Year  Origin              Car name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
df['Horsepower'] = np.where(df['Horsepower']=="?", np.nan, df['Horsepower'])
df['Horsepower'] = df['Horsepower'].astype(float)
df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB
# C:\Users\hegoi\AppData\Local\Temp\ipykernel_1556\353453926.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)

# %%
df['Origin'].value_counts()
# Out:
# Origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
# df[df['Origin']==1] # Americano
# df[df['Origin']==2] # Europeo
# df[df['Origin']==3] # Japoneses

# %%
# df[df['Origin']==3]['MPG'].mean()

# %%
df['USA'] = np.where(df['Origin']==1, 1,0)
df['Europe'] = np.where(df['Origin']==2, 1,0)
df['Japan'] = np.where(df['Origin']==3, 1,0)
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin                   Car name  USA  Europe  Japan
# 0          70       1  chevrolet chevelle malibu    1       0      0
# 1          70       1          buick skylark 320    1       0      0
# 2          70       1         plymouth satellite    1       0      0
# 3          70       1              amc rebel sst    1       0      0
# 4          70       1                ford torino    1       0      0

# %%
lista_marcas = df['Car name'].str.split(expand=True, n=1)[0]
lista_marcas.value_counts()
# Out:
# 0
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# oldsmobile       10
# mazda            10
# peugeot           8
# fiat              8
# audi              7
# vw                6
# volvo             6
# chrysler          6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# cadillac          2
# bmw               2
# mercedes-benz     2
# maxda             2
# hi                1
# toyouta           1
# chevroelt         1
# capri             1
# mercedes          1
# vokswagen         1
# triumph           1
# nissan            1
# Name: count, dtype: int64

# %%
df['Marca'] = lista_marcas.copy()
orden = df.groupby("Marca")['MPG'].mean().sort_values()
orden
# Out:
# Marca
# hi                9.000000
# chevroelt        16.000000
# chrysler         17.266667
# chevy            18.000000
# amc              18.246429
# mercury          19.118182
# buick            19.182353
# ford             19.694118
# cadillac         19.750000
# pontiac          20.012500
# chevrolet        20.472093
# oldsmobile       21.100000
# volvo            21.116667
# plymouth         21.703226
# dodge            22.060714
# toyouta          23.000000
# mercedes-benz    23.250000
# peugeot          23.687500
# bmw              23.750000
# saab             23.900000
# capri            25.000000
# mercedes         25.400000
# opel             25.750000
# maxda            26.050000
# audi             26.714286
# toyota           28.372000
# fiat             28.912500
# volkswagen       29.106667
# vokswagen        29.800000
# subaru           30.525000
# mazda            30.860000
# datsun           31.113043
# renault          32.880000
# honda            33.761538
# triumph          35.000000
# nissan           36.000000
# vw               39.016667
# Name: MPG, dtype: float64

# %%
len(orden)
# Out:
# 37

# %%
le = pd.DataFrame(np.arange(1,38), columns=["le_marca"], index=orden.index)
le
# Out:
#                le_marca
# Marca
# hi                    1
# chevroelt             2
# chrysler              3
# chevy                 4
# amc                   5
# mercury               6
# buick                 7
# ford                  8
# cadillac              9
# pontiac              10
# chevrolet            11
# oldsmobile           12
# volvo                13
# plymouth             14
# dodge                15
# toyouta              16
# mercedes-benz        17
# peugeot              18
# bmw                  19
# saab                 20
# capri                21
# mercedes             22
# opel                 23
# maxda                24
# audi                 25
# toyota               26
# fiat                 27
# volkswagen           28
# vokswagen            29
# subaru               30
# mazda                31
# datsun               32
# renault              33
# honda                34
# triumph              35
# nissan               36
# vw                   37

# %%
df = pd.merge(df, le, left_on="Marca", right_index=True)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin                   Car name  USA  Europe  Japan  \
# 0            70       1  chevrolet chevelle malibu    1       0      0
# 1            70       1          buick skylark 320    1       0      0
# 2            70       1         plymouth satellite    1       0      0
# 3            70       1              amc rebel sst    1       0      0
# 4            70       1                ford torino    1       0      0
# ..          ...     ...                        ...  ...     ...    ...
# 393          82       1            ford mustang gl    1       0      0
# 394          82       2                  vw pickup    0       1      0
# 395          82       1              dodge rampage    1       0      0
# 396          82       1                ford ranger    1       0      0
# 397          82       1                 chevy s-10    1       0      0
#
#          Marca  le_marca
# 0    chevrolet        11
# 1        buick         7
# 2     plymouth        14
# 3          amc         5
# 4         ford         8
# ..         ...       ...
# 393       ford         8
# 394         vw        37
# 395      dodge        15
# 396       ford         8
# 397      chevy         4
#
# [398 rows x 14 columns]

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
# df.drop(columns=["Car name", "Origin", "Marca"], inplace=True)
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin                   Car name  USA  Europe  Japan  \
# 0          70       1  chevrolet chevelle malibu    1       0      0
# 1          70       1          buick skylark 320    1       0      0
# 2          70       1         plymouth satellite    1       0      0
# 3          70       1              amc rebel sst    1       0      0
# 4          70       1                ford torino    1       0      0
#
#        Marca  le_marca
# 0  chevrolet        11
# 1      buick         7
# 2   plymouth        14
# 3        amc         5
# 4       ford         8

# %%
df.drop(columns=["Car name","Marca"],inplace=True)

# %%
df.shape
# Out:
# (398, 12)

# %%
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

# %%
print(train.shape)
print(test.shape)
# Out:
# (318, 12)
# (80, 12)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
sns.pairplot(df)

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin         USA      Europe  \
# count    398.000000  398.000000  398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864    0.625628    0.175879
# std        2.757689    3.697627    0.802055    0.484569    0.381197
# min        8.000000   70.000000    1.000000    0.000000    0.000000
# 25%       13.825000   73.000000    1.000000    0.000000    0.000000
# 50%       15.500000   76.000000    1.000000    1.000000    0.000000
# 75%       17.175000   79.000000    2.000000    1.000000    0.000000
# max       24.800000   82.000000    3.000000    1.000000    1.000000
#
#             Japan    le_marca
# count  398.000000  398.000000
# mean     0.198492   16.381910
# std      0.399367    9.771179
# min      0.000000    1.000000
# 25%      0.000000    8.000000
# 50%      0.000000   14.000000
# 75%      0.000000   26.000000
# max      1.000000   37.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
X_train = train.drop(columns="MPG")
X_test = test.drop(columns="MPG")
y_train = train['MPG']
y_test = test['MPG']

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (318, 11)
# (80, 11)
# (318,)
# (80,)

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_trian_scal = scaler.fit_transform(X_train)
X_test_scal = scaler.transform(X_test)

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
X_train.shape[1:]
# Out:
# (11,)

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(16),
    keras.layers.Dense(1)
])

model.compile(
    loss="mse",
    optimizer= keras.optimizers.RMSprop(0.001),
    metrics=['mae','mse']
)
# Out:
# C:\Users\hegoi\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,825 (7.13 KB)
#  Trainable params: 1,825 (7.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
10*64 + 64
# Out:
# 704

# %%
64*16 + 16
# Out:
# 1040

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
X_trian_scal.shape
# Out:
# (318, 11)

# %%
early_stopping = keras.callbacks.EarlyStopping(patience=10)
history = model.fit(X_trian_scal, y_train, epochs=1000, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 610.7365 - mae: 23.3944 - mse: 610.7365 - val_loss: 504.9647 - val_mae: 20.9490 - val_mse: 504.9647
# Epoch 2/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 524.8369 - mae: 21.5812 - mse: 524.8369 - val_loss: 461.7854 - val_mae: 19.9291 - val_mse: 461.7854
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 508.5429 - mae: 21.2177 - mse: 508.5429 - val_loss: 418.5753 - val_mae: 18.8647 - val_mse: 418.5753
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 457.1654 - mae: 19.9399 - mse: 457.1654 - val_loss: 373.1379 - val_mae: 17.6797 - val_mse: 373.1379
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 417.8602 - mae: 19.2009 - mse: 417.8602 - val_loss: 326.2598 - val_mae: 16.3844 - val_mse: 326.2598
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 324.5723 - mae: 16.6462 - mse: 324.5723 - val_loss: 277.7422 - val_mae: 14.9685 - val_mse: 277.7422
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 292.0979 - mae: 15.6943 - mse: 292.0979 - val_loss: 230.6770 - val_mae: 13.4936 - val_mse: 230.6770
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 233.7679 - mae: 13.8616 - mse: 233.7679 - val_loss: 184.9296 - val_mae: 11.9369 - val_mse: 184.9296
# Epoch 9/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 196.4692 - mae: 12.5772 - mse: 196.4692 - val_loss: 143.4354 - val_mae: 10.3534 - val_mse: 143.4354
# Epoch 10/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 142.5462 - mae: 10.4602 - mse: 142.5462 - val_loss: 106.5774 - val_mae: 8.7513 - val_mse: 106.5774
# Epoch 11/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 101.3407 - mae: 8.5741 - mse: 101.3407 - val_loss: 76.5065 - val_mae: 7.2372 - val_mse: 76.5065
# Epoch 12/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 67.5218 - mae: 6.7331 - mse: 67.5218 - val_loss: 53.4667 - val_mae: 5.8663 - val_mse: 53.4667
# Epoch 13/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 46.0073 - mae: 5.3938 - mse: 46.0073 - val_loss: 37.9991 - val_mae: 4.8251 - val_mse: 37.9991
# Epoch 14/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.4898 - mae: 4.7191 - mse: 36.4898 - val_loss: 28.1730 - val_mae: 4.0557 - val_mse: 28.1730
# Epoch 15/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.4538 - mae: 4.4002 - mse: 31.4538 - val_loss: 22.1530 - val_mae: 3.5690 - val_mse: 22.1530
# Epoch 16/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.8359 - mae: 3.6822 - mse: 21.8359 - val_loss: 18.2088 - val_mae: 3.1581 - val_mse: 18.2088
# Epoch 17/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.4564 - mae: 3.4663 - mse: 19.4564 - val_loss: 16.6175 - val_mae: 2.9733 - val_mse: 16.6175
# Epoch 18/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6311 - mae: 2.8673 - mse: 13.6311 - val_loss: 14.9452 - val_mae: 2.7374 - val_mse: 14.9452
# Epoch 19/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.4949 - mae: 2.9487 - mse: 14.4949 - val_loss: 14.4682 - val_mae: 2.6460 - val_mse: 14.4682
# Epoch 20/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.7278 - mae: 2.9214 - mse: 14.7278 - val_loss: 14.1566 - val_mae: 2.5773 - val_mse: 14.1566
# Epoch 21/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.3290 - mae: 2.6900 - mse: 12.3290 - val_loss: 13.2953 - val_mae: 2.4912 - val_mse: 13.2953
# Epoch 22/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.9433 - mae: 2.4684 - mse: 10.9433 - val_loss: 13.8614 - val_mae: 2.4975 - val_mse: 13.8614
# Epoch 23/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.5919 - mae: 2.5989 - mse: 11.5919 - val_loss: 13.5260 - val_mae: 2.4496 - val_mse: 13.5260
# Epoch 24/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.3207 - mae: 2.4844 - mse: 11.3207 - val_loss: 13.4601 - val_mae: 2.4174 - val_mse: 13.4601
# Epoch 25/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0654 - mae: 2.2519 - mse: 9.0654 - val_loss: 13.5358 - val_mae: 2.3961 - val_mse: 13.5358
# Epoch 26/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.2407 - mae: 2.4340 - mse: 10.2407 - val_loss: 12.8731 - val_mae: 2.3550 - val_mse: 12.8731
# Epoch 27/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3916 - mae: 2.3182 - mse: 9.3916 - val_loss: 12.8521 - val_mae: 2.3214 - val_mse: 12.8521
# Epoch 28/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1893 - mae: 2.1623 - mse: 8.1893 - val_loss: 13.0731 - val_mae: 2.3692 - val_mse: 13.0731
# Epoch 29/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2350 - mae: 2.1964 - mse: 8.2350 - val_loss: 12.1674 - val_mae: 2.3020 - val_mse: 12.1674
# Epoch 30/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3110 - mae: 2.1593 - mse: 8.3110 - val_loss: 12.1653 - val_mae: 2.2987 - val_mse: 12.1653
# Epoch 31/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7092 - mae: 2.0809 - mse: 7.7092 - val_loss: 12.6322 - val_mae: 2.3119 - val_mse: 12.6322
# Epoch 32/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6641 - mae: 2.0928 - mse: 7.6641 - val_loss: 12.3425 - val_mae: 2.3010 - val_mse: 12.3425
# Epoch 33/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9278 - mae: 2.2590 - mse: 8.9278 - val_loss: 11.6797 - val_mae: 2.2600 - val_mse: 11.6797
# Epoch 34/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6060 - mae: 2.0576 - mse: 7.6060 - val_loss: 11.6035 - val_mae: 2.2413 - val_mse: 11.6035
# Epoch 35/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9323 - mae: 2.0529 - mse: 7.9323 - val_loss: 11.7005 - val_mae: 2.1972 - val_mse: 11.7005
# Epoch 36/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0124 - mae: 2.0959 - mse: 8.0124 - val_loss: 11.5836 - val_mae: 2.2101 - val_mse: 11.5836
# Epoch 37/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9154 - mae: 1.9306 - mse: 6.9154 - val_loss: 11.2463 - val_mae: 2.1697 - val_mse: 11.2463
# Epoch 38/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2037 - mae: 1.8641 - mse: 6.2037 - val_loss: 11.2459 - val_mae: 2.1588 - val_mse: 11.2459
# Epoch 39/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7050 - mae: 1.9422 - mse: 6.7050 - val_loss: 11.6098 - val_mae: 2.1675 - val_mse: 11.6098
# Epoch 40/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4810 - mae: 2.1139 - mse: 8.4810 - val_loss: 10.8010 - val_mae: 2.1368 - val_mse: 10.8010
# Epoch 41/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6479 - mae: 1.9270 - mse: 6.6479 - val_loss: 11.2052 - val_mae: 2.1258 - val_mse: 11.2052
# Epoch 42/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5395 - mae: 1.8887 - mse: 6.5395 - val_loss: 10.9686 - val_mae: 2.0982 - val_mse: 10.9686
# Epoch 43/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0699 - mae: 1.8315 - mse: 6.0699 - val_loss: 11.1042 - val_mae: 2.0981 - val_mse: 11.1042
# Epoch 44/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4157 - mae: 1.8886 - mse: 6.4157 - val_loss: 11.0471 - val_mae: 2.0923 - val_mse: 11.0471
# Epoch 45/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3343 - mae: 1.7458 - mse: 5.3343 - val_loss: 10.6505 - val_mae: 2.0459 - val_mse: 10.6505
# Epoch 46/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9494 - mae: 1.8563 - mse: 5.9494 - val_loss: 10.3559 - val_mae: 2.0452 - val_mse: 10.3559
# Epoch 47/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9414 - mae: 1.7907 - mse: 5.9414 - val_loss: 10.4277 - val_mae: 2.0368 - val_mse: 10.4277
# Epoch 48/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2156 - mae: 1.7130 - mse: 5.2156 - val_loss: 10.2028 - val_mae: 2.0454 - val_mse: 10.2028
# Epoch 49/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7716 - mae: 1.8410 - mse: 6.7716 - val_loss: 10.5905 - val_mae: 2.0261 - val_mse: 10.5905
# Epoch 50/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1286 - mae: 1.8214 - mse: 6.1286 - val_loss: 10.2806 - val_mae: 2.0103 - val_mse: 10.2806
# Epoch 51/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3028 - mae: 1.6960 - mse: 5.3028 - val_loss: 10.4030 - val_mae: 1.9991 - val_mse: 10.4030
# Epoch 52/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7286 - mae: 1.8624 - mse: 6.7286 - val_loss: 10.4540 - val_mae: 2.0106 - val_mse: 10.4540
# Epoch 53/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3898 - mae: 1.8065 - mse: 6.3898 - val_loss: 10.0369 - val_mae: 1.9981 - val_mse: 10.0369
# Epoch 54/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4291 - mae: 1.6722 - mse: 5.4291 - val_loss: 10.1461 - val_mae: 1.9809 - val_mse: 10.1461
# Epoch 55/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8722 - mae: 1.6353 - mse: 4.8722 - val_loss: 10.0593 - val_mae: 1.9923 - val_mse: 10.0593
# Epoch 56/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7134 - mae: 1.8013 - mse: 6.7134 - val_loss: 10.3272 - val_mae: 1.9847 - val_mse: 10.3272
# Epoch 57/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2090 - mae: 1.6674 - mse: 5.2090 - val_loss: 10.2207 - val_mae: 1.9726 - val_mse: 10.2207
# Epoch 58/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8985 - mae: 1.7825 - mse: 5.8985 - val_loss: 9.8790 - val_mae: 1.9488 - val_mse: 9.8790
# Epoch 59/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6861 - mae: 1.7308 - mse: 5.6861 - val_loss: 9.9740 - val_mae: 1.9630 - val_mse: 9.9740
# Epoch 60/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4022 - mae: 1.6534 - mse: 5.4022 - val_loss: 9.8318 - val_mae: 1.9924 - val_mse: 9.8318
# Epoch 61/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1191 - mae: 1.7075 - mse: 5.1191 - val_loss: 10.0538 - val_mae: 1.9500 - val_mse: 10.0538
# Epoch 62/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4594 - mae: 1.7072 - mse: 5.4594 - val_loss: 10.0361 - val_mae: 2.0636 - val_mse: 10.0361
# Epoch 63/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2747 - mae: 1.6773 - mse: 5.2747 - val_loss: 9.8546 - val_mae: 1.9531 - val_mse: 9.8546
# Epoch 64/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1083 - mae: 1.8373 - mse: 6.1083 - val_loss: 9.7300 - val_mae: 1.9566 - val_mse: 9.7300
# Epoch 65/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7197 - mae: 1.7816 - mse: 5.7197 - val_loss: 9.6647 - val_mae: 1.9305 - val_mse: 9.6647
# Epoch 66/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0519 - mae: 1.6302 - mse: 5.0519 - val_loss: 9.7117 - val_mae: 2.0139 - val_mse: 9.7117
# Epoch 67/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7307 - mae: 1.7633 - mse: 5.7307 - val_loss: 10.0768 - val_mae: 1.9527 - val_mse: 10.0768
# Epoch 68/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8823 - mae: 1.5899 - mse: 4.8823 - val_loss: 9.6560 - val_mae: 1.9264 - val_mse: 9.6560
# Epoch 69/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1642 - mae: 1.6588 - mse: 5.1642 - val_loss: 9.7949 - val_mae: 1.9369 - val_mse: 9.7949
# Epoch 70/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9853 - mae: 1.6779 - mse: 4.9853 - val_loss: 9.8687 - val_mae: 1.9177 - val_mse: 9.8687
# Epoch 71/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6134 - mae: 1.5861 - mse: 4.6134 - val_loss: 9.7259 - val_mae: 1.9780 - val_mse: 9.7259
# Epoch 72/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1312 - mae: 1.6314 - mse: 5.1312 - val_loss: 9.5648 - val_mae: 1.9343 - val_mse: 9.5648
# Epoch 73/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5696 - mae: 1.7239 - mse: 5.5696 - val_loss: 9.8364 - val_mae: 1.9266 - val_mse: 9.8364
# Epoch 74/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9288 - mae: 1.6402 - mse: 4.9288 - val_loss: 9.9789 - val_mae: 1.9685 - val_mse: 9.9789
# Epoch 75/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9787 - mae: 1.6984 - mse: 4.9787 - val_loss: 9.7246 - val_mae: 1.9047 - val_mse: 9.7246
# Epoch 76/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8733 - mae: 1.5749 - mse: 4.8733 - val_loss: 9.7424 - val_mae: 1.9174 - val_mse: 9.7424
# Epoch 77/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0574 - mae: 1.6145 - mse: 5.0574 - val_loss: 10.0295 - val_mae: 1.9429 - val_mse: 10.0295
# Epoch 78/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8076 - mae: 1.6613 - mse: 4.8076 - val_loss: 9.6130 - val_mae: 1.9025 - val_mse: 9.6130
# Epoch 79/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0948 - mae: 1.6900 - mse: 5.0948 - val_loss: 9.7886 - val_mae: 1.9205 - val_mse: 9.7886
# Epoch 80/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9919 - mae: 1.6346 - mse: 4.9919 - val_loss: 9.9793 - val_mae: 1.9248 - val_mse: 9.9793
# Epoch 81/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss:
#   1.9263757467269897,
#   1.9369386434555054,
#   1.917705774307251,
#   1.977992057800293,
#   1.9342796802520752,
#   1.926630973815918,
#   1.9685144424438477,
#   1.9046969413757324,
#   1.9173532724380493,
#   1.9429336786270142,
#   1.9024683237075806,
#   1.920510172843933,
#   1.924757719039917,
#   1.9378117322921753,
#   1.9340683221817017],
#  'val_mse': [504.9647216796875,
#   461.785400390625,
#   418.5753479003906,
#   373.137939453125,
#   326.25982666015625,
#   277.7422180175781,
#   230.677001953125,
#   184.92955017089844,
#   143.43540954589844,
#   106.5774154663086,
#   76.5064697265625,
#   53.46673583984375,
#   37.999053955078125,
#   28.173036575317383,
#   22.153047561645508,
#   18.208789825439453,
#   16.617542266845703,
#   14.945219039916992,
#   14.468168258666992,
#   14.15661334991455,
#   13.295316696166992,
#   13.861430168151855,
#   13.526025772094727,
#   13.46010971069336,
#   13.535845756530762,
#   12.87308406829834,
#   12.852108001708984,
#   13.07313346862793,
#   12.167394638061523,
#   12.165334701538086,
#   12.632244110107422,
#   12.3424711227417,
#   11.679693222045898,
#   11.603511810302734,
#   11.700508117675781,
#   11.583580017089844,
#   11.246295928955078,
#   11.245929718017578,
#   11.609827995300293,
#   10.801013946533203,
#   11.205177307128906,
#   10.968612670898438,
#   11.104231834411621,
#   11.047118186950684,
#   10.650472640991211,
#   10.355868339538574,
#   10.427655220031738,
#   10.202759742736816,
#   10.590469360351562,
#   10.280586242675781,
#   10.402973175048828,
#   10.454002380371094,
#   10.036882400512695,
#   10.146064758300781,
#   10.0592622756958,
#   10.32720947265625,
#   10.22067642211914,
#   9.87901496887207,
#   9.973982810974121,
#   9.831785202026367,
#   10.053820610046387,
#   10.036145210266113,
#   9.854612350463867,
#   9.730036735534668,
#   9.664661407470703,
#   9.711682319641113,
#   10.076831817626953,
#   9.655976295471191,
#   9.794853210449219,
#   9.868659973144531,
#   9.725898742675781,
#   9.5648193359375,
#   9.836396217346191,
#   9.978859901428223,
#   9.724559783935547,
#   9.742414474487305,
#   10.029546737670898,
#   9.613036155700684,
#   9.788636207580566,
#   9.979293823242188,
#   9.86473560333252,
#   9.661172866821289]}

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %% [markdown]
# Earlystopping me ha ayudado a detener el entrenamiento para no caer en overfitting, también para ahorrar recursos innecesarios.

# %% [markdown]
# Observamos que si le damos muchas epochs al entrenamiento tiende a un overfitting, siendo el error en validación cada vez más alto. Sería interesante utilizar un número aprox de 30 epochs

# %% [markdown]
# Añade un early stopping al modelo. Pon el argumento `callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]` dentro del fit().
#
# Visualiza el progreso de entrenamiento.

# %% [markdown]
# Interpreta el gráfico

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de test y llama a` model.predict`.

# %%
model.evaluate(X_test_scal, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5231 - mae: 2.1306 - mse: 7.5231
# [7.5211992263793945, 2.152320623397827, 7.5211992263793945]

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
model.predict(X_test_scal[:10])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# array([[15.091662],
#        [15.125852],
#        [20.43342 ],
#        [23.814169],
#        [17.234877],
#        [12.744517],
#        [18.70186 ],
#        [27.004261],
#        [24.752594],
#        [27.304958]], dtype=float32)

# %%
y_pred = model.predict(X_test_scal)
y_pred
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# array([[15.091662 ],
#        [15.125852 ],
#        [20.43342  ],
#        [23.814169 ],
#        [17.234877 ],
#        [12.744517 ],
#        [18.70186  ],
#        [27.004261 ],
#        [24.752594 ],
#        [27.304958 ],
#        [28.057142 ],
#        [29.610796 ],
#        [26.455662 ],
#        [25.890059 ],
#        [24.682528 ],
#        [14.804029 ],
#        [14.825753 ],
#        [14.10781  ],
#        [18.8125   ],
#        [28.817575 ],
#        [13.257092 ],
#        [13.4600725],
#        [17.147295 ],
#        [24.647486 ],
#        [16.06712  ],
#        [25.932837 ],
#        [28.221186 ],
#        [15.892277 ],
#        [16.017996 ],
#        [18.760538 ],
#        [19.604761 ],
#        [21.388838 ],
#        [16.278383 ],
#        [16.086983 ],
#        [16.943403 ],
#        [15.244796 ],
#        [19.672283 ],
#        [17.632362 ],
#        [28.81127  ],
#        [19.565607 ],
#        [14.676503 ],
#        [16.437788 ],
#        [28.957914 ],
#        [29.369844 ],
#        [25.615614 ],
#        [27.29327  ],
#        [18.494616 ],
#        [18.112696 ],
#        [20.072739 ],
#        [21.231596 ],
#        [18.55264  ],
#        [19.959063 ],
#        [31.450157 ],
#        [27.05766  ],
#        [29.162453 ],
#        [23.383207 ],
#        [35.645245 ],
#        [33.817684 ],
#        [34.618256 ],
#        [26.269726 ],
#        [27.830088 ],
#        [35.740883 ],
#        [25.836132 ],
#        [22.614374 ],
#        [31.672787 ],
#        [29.312109 ],
#        [35.158405 ],
#        [27.062368 ],
#        [36.36187  ],
#        [36.476326 ],
#        [34.741547 ],
#        [29.740072 ],
#        [27.450258 ],
#        [21.181116 ],
#        [26.783623 ],
#        [35.71808  ],
#        [28.315928 ],
#        [33.78961  ],
#        [35.28528  ],
#        [27.657999 ]], dtype=float32)

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
plt.scatter(y_test, y_pred)

# %%
error = y_pred.ravel() - y_test
plt.hist(error, bins=15)
plt.title("Distribución errores");

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# Guarda tu modelo en un archivo.

# %%
model.save("final_model.keras")

# %%
imported_model = keras.models.load_model("final_model.keras")
imported_model
# Out:
# <Sequential name=sequential, built=True>

# %% [markdown]
# ## Conclusion
