# %%
# Variables:

# Board size:

board_size = 10

# Ships:

size_of_ships = {'ship1': 1,
         'ship2': 2,
         'ship3': 3,
         'ship4': 4,
         }

number_of_ships = {'ship1': 4,
         'ship2': 3,
         'ship3': 2,
         'ship4': 1,
         }

# %%
# Empty boards
board_10x10_computer = []
outgoing_board_10x10_computer = []
board_10x10_user = []
outgoing_board_10x10_user = []

#Create a board with dimensions 'rows' x 'columns' and fill it with the value '_'
def create_board(rows, columns, fill='_'):
    
    board = []
    for i in range(rows):
        row = []
        for j in range(columns):
            row.append(fill)
        board.append(row)
    return board

import pprint

board_10x10_computer = create_board(10,10)
pprint.pprint(board_10x10_computer)
print()
outgoing_board_10x10_computer = create_board(10,10)
pprint.pprint(outgoing_board_10x10_computer)
print()
board_10x10_user = create_board(10,10)
pprint.pprint(board_10x10_user)
print()
outgoing_board_10x10_user = create_board(10,10)
pprint.pprint(outgoing_board_10x10_user)
# Out:
# [['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']]
#
# [['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
# ...

# %%
# Ship placement computer

board_10x10_computer[0][0]='b'

board_10x10_computer[0][2]='b'

board_10x10_computer[0][4]='b'

board_10x10_computer[0][6]='b'

board_10x10_computer[3][1]='b'
board_10x10_computer[3][2]='b'

board_10x10_computer[3][4]='b'
board_10x10_computer[3][5]='b'

board_10x10_computer[3][7]='b'
board_10x10_computer[3][8]='b'

board_10x10_computer[4][6]='b'
board_10x10_computer[5][6]='b'
board_10x10_computer[6][6]='b'

board_10x10_computer[6][0]='b'
board_10x10_computer[7][0]='b'
board_10x10_computer[8][0]='b'

board_10x10_computer[6][9]='b'
board_10x10_computer[7][9]='b'
board_10x10_computer[8][9]='b'
board_10x10_computer[9][9]='b'


pprint.pprint(board_10x10_computer)
# Out:
# [['b', '_', 'b', '_', 'b', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', 'b', 'b', '_', 'b', 'b', '_', 'b', 'b', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['b', '_', '_', '_', '_', '_', 'b', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', 'b']]

# %%
# Ship placement user

board_10x10_user[0][0]='b'

board_10x10_user[0][2]='b'

board_10x10_user[0][4]='b'

board_10x10_user[0][6]='b'

board_10x10_user[2][1]='b'
board_10x10_user[2][2]='b'

board_10x10_user[2][4]='b'
board_10x10_user[2][5]='b'

board_10x10_user[2][7]='b'
board_10x10_user[2][8]='b'

board_10x10_user[4][6]='b'
board_10x10_user[5][6]='b'
board_10x10_user[6][6]='b'

board_10x10_user[6][0]='b'
board_10x10_user[7][0]='b'
board_10x10_user[8][0]='b'

board_10x10_user[6][9]='b'
board_10x10_user[7][9]='b'
board_10x10_user[8][9]='b'
board_10x10_user[9][9]='b'

pprint.pprint(board_10x10_user)
# Out:
# [['b', '_', 'b', '_', 'b', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', 'b', 'b', '_', 'b', 'b', '_', 'b', 'b', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['b', '_', '_', '_', '_', '_', 'b', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', 'b']]

# %%
def shot (row,column):
    if board_10x10_computer[row][column] == 'b':
        print('Hit')
        board_10x10_computer[row][column] = 'x'
        return True
    else:
        print('Miss')
        return False
    
def player_turn():
    while True:
        row = int(input('Introduce una fila del 0-9:'))
        column = int(input('Introduce una columna del 0-9:'))
        result = shot (row,column)
        if result == False:
            print('Turn of player finished')
            break


player_turn()
pprint.pprint(board_10x10_computer)
# Out:
# Hit
# Miss
# Turn of player finished
# [['b', '_', 'b', '_', 'b', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#  ['_', 'b', 'b', '_', 'x', 'b', '_', 'b', 'b', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['_', '_', '_', '_', '_', '_', 'b', '_', '_', '_'],
#  ['b', '_', '_', '_', '_', '_', 'b', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['b', '_', '_', '_', '_', '_', '_', '_', '_', 'b'],
#  ['_', '_', '_', '_', '_', '_', '_', '_', '_', 'b']]
